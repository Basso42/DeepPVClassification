# %% [markdown]
# # Préparation des données

# %% [markdown]
# ## Import et data augmentations

# %%
from  src.dataloader import *
from src.bdappv import *
from src.metrics import *
from src.resnet18 import *
from src.confusion_matrix import make_confusion_matrix
from torch.utils.data import DataLoader, SubsetRandomSampler
import matplotlib.pyplot as plt
from torchvision import transforms, datasets
import torch.nn as nn
import tensorflow as tf
from sklearn.metrics import fbeta_score, make_scorer, f1_score, accuracy_score, recall_score, precision_score, fbeta_score, precision_recall_curve, auc, roc_curve, log_loss, confusion_matrix
import torchvision.models as models
import os
from src.tsne import *
from torch.utils.data import DataLoader
import matplotlib
import torchvision.models as models
from sklearn.manifold import TSNE
import math
# Out:
# c:\Users\yanis\anaconda3\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: [WinError 127] La procédure spécifiée est introuvable
#   warn(f"Failed to load image Python extension: {e}")

# %%
dataset=BDAPPVClassification(img_dir="C:/Users/yanis/OneDrive/Documents/Projet Stat/Données/bdappv/google3", size=None)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
mean, std = batch_mean_and_sd(dataloader)
print("Moyenne par channel: {}".format(mean.tolist()))
print("Ecart-type par channel: {}".format(std.tolist()))
# Out:
# Moyenne par channel: [0.346024751663208, 0.35355815291404724, 0.3038492202758789]
# Ecart-type par channel: [0.20496879518032074, 0.18832367658615112, 0.18234187364578247]

# %%
dataset_crop=BDAPPVClassification(img_dir="C:/Users/yanis/OneDrive/Documents/Projet Stat/Données/bdappv/google3",
                                  size=224,
                                  transform=transforms.Compose([transforms.Normalize(mean = mean,
                                                                    std= std)]))

# %%
seed = 123
torch.manual_seed(seed)
np.random.seed(seed)

dataset_crop=BDAPPVClassification(img_dir="C:/Users/yanis/OneDrive/Documents/Projet Stat/Données/bdappv/google3",
                                  size=224,
                                  transform=transforms.Compose([transforms.Normalize(mean = mean,
                                                                    std= std)]))

# Define the indices for training and testing sets
n = len(dataset)
train_size = int(0.8 * n)
test_size = n - train_size
train_indices = torch.arange(0, train_size)
test_indices = torch.arange(train_size, n)

# Define the samplers for training and testing sets
train_sampler = SubsetRandomSampler(train_indices)
test_sampler = SubsetRandomSampler(test_indices)

# Define the dataloaders for training and testing sets
train_dataloader_augmente = DataLoader(dataset_crop, batch_size=32, sampler=train_sampler)
test_dataloader_augmente = DataLoader(dataset_crop, batch_size=32, sampler=test_sampler)

print(len(train_dataloader_augmente))
batch = next(iter(train_dataloader_augmente))
print(batch[0].shape)
plt.imshow(batch[0][0].permute(1, 2, 0))
print(batch[1][0])
# Out:
# 716
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([32, 3, 224, 224])
# tensor(0)

# %% [markdown]
# # Import du modèle

# %%
resnet18 = models.resnet18(pretrained=True)

#Furthermore, in feature extracting, we don't need to calculate gradient for any layers except 
# the last layer that we initialize. For this we need to set .requires_grad to False
def set_parameter_requires_grad(model, feature_extracting=True):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False
            
set_parameter_requires_grad(resnet18)


nr_filters = resnet18.fc.in_features  #number of input features of last layer
#On ne met pas de sigmoid dans la dernière couche. C'est composé par la loss BCEWithLogitsLoss qui applique une sigmoid afin de calculer la cross-enthropy
resnet18.fc = nn.Linear(nr_filters, 1)

# %% [markdown]
# # Choix du Learning Rate

# %%
params_to_update = []
for name,param in resnet18.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name)
# Out:
# 	 fc.weight
# 	 fc.bias

# %%
def find_lr(train_loader=train_dataloader_augmente, optimizer=torch.optim.SGD(params_to_update, lr = 0.01, momentum=0.9, weight_decay=1e-4), init_value = 1e-8, final_value=10., beta = 0.98, criterion=nn.BCEWithLogitsLoss()):
    #Adapté de https://sgugger.github.io/how-do-you-find-a-good-learning-rate.html
    num = len(train_loader)-1
    mult = (final_value / init_value) ** (1/num)
    lr = init_value
    optimizer.param_groups[0]['lr'] = lr
    avg_loss = 0.
    best_loss = 0.
    batch_num = 0
    losses = []
    log_lrs = []
    for data, label in train_loader:
        batch_num += 1
        #As before, get theloss for this mini-batch of inputs/outputs
        optimizer.zero_grad()
        output = resnet18(data)
            
        loss = criterion(output,label.unsqueeze(1).float()) #loss sur le batch i.e 1/32*sum...
        #Compute the smoothed loss
        avg_loss = beta * avg_loss + (1-beta) *loss.item()
        smoothed_loss = avg_loss / (1 - beta**batch_num)
        #Stop if the loss is exploding
        if batch_num > 1 and smoothed_loss > 4 * best_loss:
            return log_lrs, losses
        #Record the best loss
        if smoothed_loss < best_loss or batch_num==1:
            best_loss = smoothed_loss
        #Store the values
        losses.append(smoothed_loss)
        log_lrs.append(math.log10(lr))
        #Do the SGD step
        loss.backward()
        optimizer.step()
        #Update the lr for the next step
        lr *= mult
        optimizer.param_groups[0]['lr'] = lr
    return log_lrs, losses

# %%
seed = 123
torch.manual_seed(seed)
np.random.seed(seed)

log_lrs, losses=find_lr(train_loader=train_dataloader_augmente, optimizer=torch.optim.SGD(params_to_update, lr = 0.01, momentum=0.9, weight_decay=1e-4), init_value = 1e-8, final_value=10., beta = 0.98, criterion=nn.BCEWithLogitsLoss())

# %%
lrs=[10**k for k in log_lrs]
fig, ax = plt.subplots()

ax.plot(lrs[10:-5], losses[10:-5], 'b',label="Loss en fonction du learning rate", color="blue")
ax.set_xlabel("Learning rate")
ax.set_ylabel("Loss")
ax.set_xscale('log')
plt.show()

# %% [markdown]
# Le minimum de la loss est atteint pour un learning rate environ égal à 0,01. On remarque que la courbe de loss décroit le plus rapidement vers ce minimum pour un learning rate environ égal à 0,001. Cela semble être un bon choix.

# %% [markdown]
# # Fit et predict

# %%
def sig(x):
    return 1/(1 + np.exp(-x))

def train_model(model, train_loader, valid_loader, criterion, n_epochs, path_save_model, device=None):
    """Pour entrainer le modèle 
    /!\ certains commentaires sont à passer en code pour passer sur GPU
    """
    # number of epochs to train the model

    train_losses= []
    train_f1s=[]
    train_accuracys=[]
    train_recalls=[]
    train_precisions=[]
    train_f2s=[]

    valid_loss_min = np.Inf  # set initial "min" to infinity
    val_losses= []
    val_f1s=[]
    val_accuracys=[]
    val_recalls=[]
    val_precisions=[]
    val_f2s=[]

    # Here we only want to update the gradient for the classifier layer that we initialized.
    params_to_update = []
    for name,param in model.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            print("\t",name)

    optimizer=torch.optim.SGD(params_to_update, lr = 0.001, momentum=0.9, weight_decay=1e-4)
    
    for epoch in range(n_epochs):

        # monitor losses
        train_loss = 0
        train_f1=0
        train_accuracy=0
        train_recall=0
        train_precision=0
        train_f2=0

        valid_loss=0
        valid_f1=0
        valid_accuracy=0
        valid_recall=0
        valid_precision=0
        valid_f2=0

        iter_train=0
        iter_val=0
        ###################
        # train the model #
        ###################
        model.train() # prep model for training

        for data,label in train_loader:
            iter_train+=1

            # Pour utiliser GPU

            # inputs = inputs.to(device)
            # labels = labels.to(device)
            # model.to(device)

            # clear the gradients of all optimized variables
            optimizer.zero_grad()
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            output_detach = output.detach()

            # calculate the loss
            preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
            for i in range(len(output_detach)):
                if sig(output_detach[i])>0.5:
                    preds[i]=1
                else: preds[i]=0

            loss = criterion(output,label.unsqueeze(1).float()) #loss sur le batch i.e 1/32*sum...
            f1 = f1_score(label.numpy(), preds.T.numpy()[0])
            accuracy= accuracy_score(label.numpy(), preds.T.numpy()[0])
            recall= recall_score(label.numpy(), preds.T.numpy()[0])
            precision=precision_score(label.numpy(), preds.T.numpy()[0])
            f2=fbeta_score(label.numpy(), preds.T.numpy()[0], beta=2)

            # backward pass: compute gradient of the loss with respect to model parameters
            loss.backward()
            # perform a single optimization step (parameter update)
            optimizer.step()
            # update running training loss

            #loss.item(): retourne la valeur numérique de la loss transférée au CPU
            #loss.item() retourne la loss moyenne sur le mini-batch, d'où la multiplication
            #par data.size(0)
            train_loss += loss.item() * data.size(0)
            train_f1+=f1
            train_accuracy+=accuracy
            train_recall+=recall
            train_precision+=precision
            train_f2+=f2

        # print training/validation statistics 
        # calculate average loss over an epoch
        train_loss = train_loss / len(train_loader.sampler) 
        train_f1=train_f1/iter_train
        train_accuracy=train_accuracy/iter_train
        train_recall=train_recall/iter_train
        train_precision=train_precision/iter_train
        train_f2=train_f2/iter_train


        train_losses.append(train_loss)
        train_f1s.append(train_f1)
        train_accuracys.append(train_accuracy)
        train_recalls.append(train_recall)
        train_precisions.append(train_precision)
        train_f2s.append(train_f2)

        model.eval()

        for data,label in valid_loader:
            iter_val+=1

            # Pour utiliser GPU

            # inputs = inputs.to(device)
            # labels = labels.to(device)
            # model.to(device)

            with torch.no_grad():
                output = model(data)
                
            output_detach = output.detach()

            # calculate the loss
            preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
            for i in range(len(output_detach)):
                if sig(output_detach[i])>0.5:
                    preds[i]=1
                else: preds[i]=0
            
            loss = criterion(output,label.unsqueeze(1).float())
            f1 = f1_score(label.numpy(), preds.T.numpy()[0])
            accuracy= accuracy_score(label.numpy(), preds.T.numpy()[0])
            recall= recall_score(label.numpy(), preds.T.numpy()[0])
            precision= precision_score(label.numpy(), preds.T.numpy()[0])
            f2=fbeta_score(label.numpy(), preds.T.numpy()[0], beta=2)

            # update running validation loss 
            valid_loss+=loss.item() * data.size(0)
            valid_f1+=f1
            valid_accuracy+=accuracy
            valid_recall+=recall
            valid_precision+=precision
            valid_f2+=f2

        valid_loss=valid_loss/len(valid_loader.sampler)
        valid_f1=valid_f1/iter_val
        valid_accuracy=valid_accuracy/iter_val
        valid_recall=valid_recall/iter_val
        valid_precision=valid_precision/iter_val
        valid_f2=valid_f2/iter_val

        val_losses.append(valid_loss)
        val_f1s.append(valid_f1)
        val_accuracys.append(valid_accuracy)
        val_recalls.append(valid_recall)
        val_precisions.append(valid_precision)
        val_f2s.append(valid_f2)



        print('Epoch: {} \tTraining Loss: {:.6f} \tTraining F1-score: {:.6f} \tTraining accuracy: {:.6f} \tTraining recall: {:.6f} \tTraining precision: {:.6f} \tTraining F2-score: {:.6f} \tValidation Loss: {:.6f} \tValidation F1-score: {:.6f} \tValidation accuracy: {:.6f} \tValidation recall: {:.6f} \tValidation precision: {:.6f} \tValidation F2-score: {:.6f}'.format(
            epoch+1, 
            train_loss,
            train_f1,
            train_accuracy,
            train_recall,
            train_precision,
            train_f2,
            valid_loss,
            valid_f1,
            valid_accuracy,
            valid_recall,
            valid_precision,
            valid_f2
            ))
        
    torch.save(model.state_dict(), os.path.join(path_save_model,"trained_resnet18_autocrop.pth"))

    return train_losses, train_f1s, train_accuracys, train_recalls, train_precisions, train_f2s, val_losses, val_f1s, val_accuracys, val_recalls, val_precisions, val_f2s


def eval_model(model, path_model, valid_loader, criterion, n_epochs, device=None):
    """Pour voir les performances du modèle entraîné sur l'échantillon de validation
       /!\ certains commentaires sont à passer en code pour passer sur GPU

    """
    ######################    
    # validate the model #
    ######################
    valid_loss_min = np.Inf  # set initial "min" to infinity
    val_losses= []
    val_f1s=[]
    val_accuracys=[]
    val_recalls=[]
    val_precisions=[]
    val_f2s=[]

    model.load_state_dict(torch.load(path_model))
    model.eval()  # prep model for evaluation

    #model.to(device)

    for epoch in range(n_epochs):
        valid_loss=0
        valid_f1=0
        valid_accuracy=0
        valid_recall=0
        valid_precision=0
        valid_f2=0
        iter=0
        for data,label in valid_loader:

            # Pour utiliser GPU

            # inputs = inputs.to(device)
            # labels = labels.to(device)
            # model.to(device)

            with torch.no_grad():
                output = model(data)
                
            output_detach = output.detach()

            # calculate the loss
            preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
            for i in range(len(output_detach)):
                if sig(output_detach[i])>0.5:
                    preds[i]=1
                else: preds[i]=0
            
            loss = criterion(output,label.unsqueeze(1).float())
            f1 = f1_score(label.numpy(), preds.T.numpy()[0])
            accuracy= accuracy_score(label.numpy(), preds.T.numpy()[0])
            recall= recall_score(label.numpy(), preds.T.numpy()[0])
            precision= precision_score(label.numpy(), preds.T.numpy()[0])
            f2=fbeta_score(label.numpy(), preds.T.numpy()[0], beta=2)

            # update running validation loss 
            valid_loss+=loss.item() * data.size(0)
            valid_f1+=f1
            valid_accuracy+=accuracy
            valid_recall+=recall
            valid_precision+=precision
            valid_f2+=f2
            iter+=1

        valid_loss=valid_loss/len(valid_loader.sampler)
        valid_f1=valid_f1/iter
        valid_accuracy=valid_accuracy/iter
        valid_recall=valid_recall/iter
        valid_precision=valid_precision/iter
        valid_f2=valid_f2/iter

        val_losses.append(valid_loss)
        val_f1s.append(valid_f1)
        val_accuracys.append(valid_accuracy)
        val_recalls.append(valid_recall)
        val_precisions.append(valid_precision)
        val_f2s.append(valid_f2)

        print('Epoch: {} \tValidation Loss: {:.6f} \tValidation F1-score: {:.6f} \tValidation accuracy: {:.6f} \tValidation recall: {:.6f} \tValidation precision: {:.6f} \tValidation F2-score: {:.6f}'.format(
            epoch+1,
            valid_loss,
            valid_f1,
            valid_accuracy,
            valid_recall,
            valid_precision,
            valid_f2
            ))
        
    return val_losses, val_f1s, val_accuracys, val_recalls, val_precisions, val_f2s


def predict(model, path_model, valid_loader, device=None):
    """Pour prédire 0/1 à partir de l'échantillon de validation
       /!\ certains commentaires sont à passer en code pour passer sur GPU

    """
    model.load_state_dict(torch.load(path_model))
    model.eval()

    array_labels=np.array([])
    array_preds=np.array([])
    probas_pred=np.array([])

    for data,label in valid_loader:
        # Pour utiliser GPU

        # inputs = inputs.to(device)
        # labels = labels.to(device)
        # model.to(device)

        with torch.no_grad():
            output = model(data)
        output_detach = output.detach()

        # calculate the loss
        preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
        probas=torch.zeros(output_detach.shape[0], output_detach.shape[1])

        for i in range(len(output_detach)):
            if sig(output_detach[i])>0.5:
                preds[i]=1
            else: preds[i]=0
            probas[i]=sig(output_detach[i])
        probas_pred=np.append(probas_pred, probas.T.numpy()[0])
        array_preds=np.append(array_preds,preds.T.numpy()[0])
        array_labels=np.append(array_labels, label.numpy())

    return array_labels, array_preds, probas_pred

# %%
seed = 123
torch.manual_seed(seed)
np.random.seed(seed)

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
loss=nn.BCEWithLogitsLoss()
# Train model
train_losses, train_f1s, train_accuracys, train_recalls, train_precisions, train_f2s, val_losses, val_f1s, val_accuracys, val_recalls, val_precisions, val_f2s = train_model(model=resnet18, 
                                                                                 train_loader=train_dataloader_augmente,
                                                                                 valid_loader=test_dataloader_augmente, 
                                                                                 criterion=loss, 
                                                                                 n_epochs=40, 
                                                                                 path_save_model="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps",
                                                                                 device=None)
# Out:
# 	 fc.weight
# 	 fc.bias
# Epoch: 1 	Training Loss: 1.918183 	Training F1-score: 0.795797 	Training accuracy: 0.786014 	Training recall: 0.802887 	Training precision: 0.800824 	Training F2-score: 0.798497 	Validation Loss: 1.533892 	Validation F1-score: 0.806889 	Validation accuracy: 0.800420 	Validation recall: 0.824018 	Validation precision: 0.800666 	Validation F2-score: 0.815745
# Epoch: 2 	Training Loss: 1.436101 	Training F1-score: 0.796649 	Training accuracy: 0.787026 	Training recall: 0.801302 	Training precision: 0.804214 	Training F2-score: 0.797945 	Validation Loss: 1.285759 	Validation F1-score: 0.800477 	Validation accuracy: 0.790649 	Validation recall: 0.827764 	Validation precision: 0.783989 	Validation F2-score: 0.815330
# Epoch: 3 	Training Loss: 1.102132 	Training F1-score: 0.795940 	Training accuracy: 0.786125 	Training recall: 0.802044 	Training precision: 0.802400 	Training F2-score: 0.798001 	Validation Loss: 0.951937 	Validation F1-score: 0.797289 	Validation accuracy: 0.795177 	Validation recall: 0.795160 	Validation precision: 0.809176 	Validation F2-score: 0.794873
# Epoch: 4 	Training Loss: 0.917255 	Training F1-score: 0.795587 	Training accuracy: 0.786387 	Training recall: 0.802545 	Training precision: 0.802479 	Training F2-score: 0.797980 	Validation Loss: 0.765737 	Validation F1-score: 0.808940 	Validation accuracy: 0.800781 	Validation recall: 0.828495 	Validation precision: 0.800318 	Validation F2-score: 0.819167
# Epoch: 5 	Training Loss: 0.748197 	Training F1-score: 0.798024 	Training accuracy: 0.788193 	Training recall: 0.806474 	Training precision: 0.802678 	Training F2-score: 0.801375 	Validation Loss: 0.671605 	Validation F1-score: 0.803407 	Validation accuracy: 0.797982 	Validation recall: 0.815869 	Validation precision: 0.800617 	Validation F2-score: 0.809667
# Epoch: 6 	Training Loss: 0.646881 	Training F1-score: 0.796888 	Training accuracy: 0.787216 	Training recall: 0.805457 	Training precision: 0.804656 	Training F2-score: 0.799944 	Validation Loss: 0.555436 	Validation F1-score: 0.807891 	Validation accuracy: 0.803022 	Validation recall: 0.816061 	Validation precision: 0.811569 	Validation F2-score: 0.811302
# Epoch: 7 	Training Loss: 0.571145 	Training F1-score: 0.799102 	Training accuracy: 0.789415 	Training recall: 0.807636 	Training precision: 0.806361 	Training F2-score: 0.802204 	Validation Loss: 0.516198 	Validation F1-score: 0.801551 	Validation accuracy: 0.795002 	Validation recall: 0.825940 	Validation precision: 0.788425 	Validation F2-score: 0.814631
# Epoch: 8 	Training Loss: 0.520129 	Training F1-score: 0.800376 	Training accuracy: 0.790141 	Training recall: 0.811530 	Training precision: 0.806632 	Training F2-score: 0.804788 	Validation Loss: 0.487139 	Validation F1-score: 0.812104 	Validation accuracy: 0.799356 	Validation recall: 0.858778 	Validation precision: 0.777425 	Validation F2-score: 0.838346
# Epoch: 9 	Training Loss: 0.476752 	Training F1-score: 0.805586 	Training accuracy: 0.796414 	Training recall: 0.816045 	Training precision: 0.810456 	Training F2-score: 0.809890 	Validation Loss: 0.456671 	Validation F1-score: 0.820750 	Validation accuracy: 0.805489 	Validation recall: 0.880569 	Validation precision: 0.775899 	Validation F2-score: 0.854391
# Epoch: 10 	Training Loss: 0.452762 	Training F1-score: 0.807238 	Training accuracy: 0.797454 	Training recall: 0.821137 	Training precision: 0.810263 	Training F2-score: 0.813315 	Validation Loss: 0.460755 	Validation F1-score: 0.817954 	Validation accuracy: 0.797103 	Validation recall: 0.895104 	Validation precision: 0.758794 	Validation F2-score: 0.861537
# Epoch: 11 	Training Loss: 0.440799 	Training F1-score: 0.810365 	Training accuracy: 0.800231 	Training recall: 0.825121 	Training precision: 0.811268 	Training F2-score: 0.817180 	Validation Loss: 0.428834 	Validation F1-score: 0.810979 	Validation accuracy: 0.805494 	Validation recall: 0.829941 	Validation precision: 0.800950 	Validation F2-score: 0.821167
# Epoch: 12 	Training Loss: 0.439347 	Training F1-score: 0.807552 	Training accuracy: 0.797691 	Training recall: 0.822908 	Training precision: 0.809528 	Training F2-score: 0.814528 	Validation Loss: 0.420873 	Validation F1-score: 0.813804 	Validation accuracy: 0.807933 	Validation recall: 0.839968 	Validation precision: 0.795428 	Validation F2-score: 0.828480
# Epoch: 13 	Training Loss: 0.430804 	Training F1-score: 0.814714 	Training accuracy: 0.804274 	Training recall: 0.831553 	Training precision: 0.814089 	Training F2-score: 0.822649 	Validation Loss: 0.410640 	Validation F1-score: 0.816824 	Validation accuracy: 0.810895 	Validation recall: 0.831992 	Validation precision: 0.811208 	Validation F2-score: 0.824722
# Epoch: 14 	Training Loss: 0.431596 	Training F1-score: 0.807913 	Training accuracy: 0.798005 	Training recall: 0.824487 	Training precision: 0.809484 	Training F2-score: 0.815482 	Validation Loss: 0.418161 	Validation F1-score: 0.827649 	Validation accuracy: 0.812990 	Validation recall: 0.884101 	Validation precision: 0.785008 	Validation F2-score: 0.859429
# Epoch: 15 	Training Loss: 0.425731 	Training F1-score: 0.813019 	Training accuracy: 0.803092 	Training recall: 0.828710 	Training precision: 0.813341 	Training F2-score: 0.820272 	Validation Loss: 0.413185 	Validation F1-score: 0.810730 	Validation accuracy: 0.809842 	Validation recall: 0.806866 	Validation precision: 0.826377 	Validation F2-score: 0.807055
# Epoch: 16 	Training Loss: 0.423942 	Training F1-score: 0.812661 	Training accuracy: 0.802195 	Training recall: 0.828340 	Training precision: 0.813760 	Training F2-score: 0.819781 	Validation Loss: 0.411086 	Validation F1-score: 0.810587 	Validation accuracy: 0.804447 	Validation recall: 0.826241 	Validation precision: 0.801822 	Validation F2-score: 0.819106
# Epoch: 17 	Training Loss: 0.422380 	Training F1-score: 0.813256 	Training accuracy: 0.803016 	Training recall: 0.830740 	Training precision: 0.813083 	Training F2-score: 0.821465 	Validation Loss: 0.410162 	Validation F1-score: 0.816693 	Validation accuracy: 0.808068 	Validation recall: 0.849244 	Validation precision: 0.795254 	Validation F2-score: 0.834625
# Epoch: 18 	Training Loss: 0.424896 	Training F1-score: 0.813169 	Training accuracy: 0.802290 	Training recall: 0.832257 	Training precision: 0.811062 	Training F2-score: 0.822346 	Validation Loss: 0.402386 	Validation F1-score: 0.819451 	Validation accuracy: 0.812630 	Validation recall: 0.834868 	Validation precision: 0.812951 	Validation F2-score: 0.827566
# Epoch: 19 	Training Loss: 0.417440 	Training F1-score: 0.817925 	Training accuracy: 0.807151 	Training recall: 0.836499 	Training precision: 0.814686 	Training F2-score: 0.827046 	Validation Loss: 0.400213 	Validation F1-score: 0.815735 	Validation accuracy: 0.814403 	Validation recall: 0.814914 	Validation precision: 0.826611 	Validation F2-score: 0.814073
# Epoch: 20 	Training Loss: 0.424279 	Training F1-score: 0.812551 	Training accuracy: 0.801671 	Training recall: 0.831555 	Training precision: 0.811532 	Training F2-score: 0.821584 	Validation Loss: 0.397524 	Validation F1-score: 0.818664 	Validation accuracy: 0.817017 	Validation recall: 0.819262 	Validation precision: 0.829430 	Validation F2-score: 0.817652
# Epoch: 21 	Training Loss: 0.417690 	Training F1-score: 0.817700 	Training accuracy: 0.806655 	Training recall: 0.835226 	Training precision: 0.815623 	Training F2-score: 0.826133 	Validation Loss: 0.413895 	Validation F1-score: 0.799281 	Validation accuracy: 0.808963 	Validation recall: 0.756908 	Validation precision: 0.860404 	Validation F2-score: 0.772069
# Epoch: 22 	Training Loss: 0.421124 	Training F1-score: 0.814918 	Training accuracy: 0.804194 	Training recall: 0.834056 	Training precision: 0.812371 	Training F2-score: 0.824212 	Validation Loss: 0.398095 	Validation F1-score: 0.822523 	Validation accuracy: 0.814387 	Validation recall: 0.842967 	Validation precision: 0.810266 	Validation F2-score: 0.833664
# Epoch: 23 	Training Loss: 0.415979 	Training F1-score: 0.817688 	Training accuracy: 0.806770 	Training recall: 0.837081 	Training precision: 0.814699 	Training F2-score: 0.827147 	Validation Loss: 0.397521 	Validation F1-score: 0.825807 	Validation accuracy: 0.818402 	Validation recall: 0.851001 	Validation precision: 0.809776 	Validation F2-score: 0.839611
# Epoch: 24 	Training Loss: 0.418591 	Training F1-score: 0.816727 	Training accuracy: 0.806142 	Training recall: 0.835571 	Training precision: 0.814718 	Training F2-score: 0.825769 	Validation Loss: 0.398874 	Validation F1-score: 0.820427 	Validation accuracy: 0.819078 	Validation recall: 0.819313 	Validation precision: 0.829108 	Validation F2-score: 0.818837
# Epoch: 25 	Training Loss: 0.421955 	Training F1-score: 0.813518 	Training accuracy: 0.802989 	Training recall: 0.832663 	Training precision: 0.812653 	Training F2-score: 0.822549 	Validation Loss: 0.399695 	Validation F1-score: 0.818475 	Validation accuracy: 0.813311 	Validation recall: 0.824507 	Validation precision: 0.820922 	Validation F2-score: 0.821013
# Epoch: 26 	Training Loss: 0.419506 	Training F1-score: 0.813619 	Training accuracy: 0.802536 	Training recall: 0.832225 	Training precision: 0.811404 	Training F2-score: 0.822648 	Validation Loss: 0.407968 	Validation F1-score: 0.805017 	Validation accuracy: 0.809341 	Validation recall: 0.779846 	Validation precision: 0.842757 	Validation F2-score: 0.788652
# Epoch: 27 	Training Loss: 0.414774 	Training F1-score: 0.817349 	Training accuracy: 0.807072 	Training recall: 0.834316 	Training precision: 0.816037 	Training F2-score: 0.825474 	Validation Loss: 0.407623 	Validation F1-score: 0.827599 	Validation accuracy: 0.816662 	Validation recall: 0.877462 	Validation precision: 0.789936 	Validation F2-score: 0.855727
# Epoch: 28 	Training Loss: 0.414705 	Training F1-score: 0.816733 	Training accuracy: 0.806147 	Training recall: 0.835266 	Training precision: 0.813966 	Training F2-score: 0.825809 	Validation Loss: 0.411383 	Validation F1-score: 0.813226 	Validation accuracy: 0.813852 	Validation recall: 0.800283 	Validation precision: 0.834855 	Validation F2-score: 0.804545
# Epoch: 29 	Training Loss: 0.419425 	Training F1-score: 0.815363 	Training accuracy: 0.804552 	Training recall: 0.833247 	Training precision: 0.813350 	Training F2-score: 0.824031 	Validation Loss: 0.416283 	Validation F1-score: 0.821108 	Validation accuracy: 0.804441 	Validation recall: 0.886424 	Validation precision: 0.771455 	Validation F2-score: 0.857930
# Epoch: 30 	Training Loss: 0.413983 	Training F1-score: 0.818940 	Training accuracy: 0.808242 	Training recall: 0.839014 	Training precision: 0.815036 	Training F2-score: 0.828843 	Validation Loss: 0.393526 	Validation F1-score: 0.833425 	Validation accuracy: 0.821713 	Validation recall: 0.873937 	Validation precision: 0.803767 	Validation F2-score: 0.856132
# Epoch: 31 	Training Loss: 0.419578 	Training F1-score: 0.816705 	Training accuracy: 0.806123 	Training recall: 0.834752 	Training precision: 0.814356 	Training F2-score: 0.825426 	Validation Loss: 0.417004 	Validation F1-score: 0.825678 	Validation accuracy: 0.807921 	Validation recall: 0.896575 	Validation precision: 0.771173 	Validation F2-score: 0.865740
# Epoch: 32 	Training Loss: 0.421785 	Training F1-score: 0.813072 	Training accuracy: 0.802263 	Training recall: 0.833228 	Training precision: 0.809653 	Training F2-score: 0.822983 	Validation Loss: 0.399949 	Validation F1-score: 0.805781 	Validation accuracy: 0.809842 	Validation recall: 0.780451 	Validation precision: 0.843374 	Validation F2-score: 0.789357
# Epoch: 33 	Training Loss: 0.418709 	Training F1-score: 0.817150 	Training accuracy: 0.805171 	Training recall: 0.837158 	Training precision: 0.813945 	Training F2-score: 0.826969 	Validation Loss: 0.397918 	Validation F1-score: 0.829948 	Validation accuracy: 0.816307 	Validation recall: 0.879261 	Validation precision: 0.792928 	Validation F2-score: 0.857686
# Epoch: 34 	Training Loss: 0.424163 	Training F1-score: 0.814172 	Training accuracy: 0.802465 	Training recall: 0.836931 	Training precision: 0.810243 	Training F2-score: 0.825307 	Validation Loss: 0.404281 	Validation F1-score: 0.799424 	Validation accuracy: 0.804424 	Validation recall: 0.771249 	Validation precision: 0.839899 	Validation F2-score: 0.781273
# Epoch: 35 	Training Loss: 0.416978 	Training F1-score: 0.817162 	Training accuracy: 0.807187 	Training recall: 0.835509 	Training precision: 0.815632 	Training F2-score: 0.825846 	Validation Loss: 0.406890 	Validation F1-score: 0.825260 	Validation accuracy: 0.814054 	Validation recall: 0.869210 	Validation precision: 0.794624 	Validation F2-score: 0.849676
# Epoch: 36 	Training Loss: 0.417307 	Training F1-score: 0.817234 	Training accuracy: 0.806139 	Training recall: 0.836727 	Training precision: 0.813951 	Training F2-score: 0.826718 	Validation Loss: 0.395421 	Validation F1-score: 0.820474 	Validation accuracy: 0.817349 	Validation recall: 0.829881 	Validation precision: 0.819894 	Validation F2-score: 0.825054
# Epoch: 37 	Training Loss: 0.409731 	Training F1-score: 0.821577 	Training accuracy: 0.811246 	Training recall: 0.840932 	Training precision: 0.818572 	Training F2-score: 0.830973 	Validation Loss: 0.396963 	Validation F1-score: 0.823118 	Validation accuracy: 0.817715 	Validation recall: 0.839346 	Validation precision: 0.816815 	Validation F2-score: 0.831554
# Epoch: 38 	Training Loss: 0.414127 	Training F1-score: 0.821614 	Training accuracy: 0.810591 	Training recall: 0.837889 	Training precision: 0.820393 	Training F2-score: 0.829421 	Validation Loss: 0.394542 	Validation F1-score: 0.825338 	Validation accuracy: 0.820677 	Validation recall: 0.837452 	Validation precision: 0.822609 	Validation F2-score: 0.831389
# Epoch: 39 	Training Loss: 0.416583 	Training F1-score: 0.814287 	Training accuracy: 0.803933 	Training recall: 0.831642 	Training precision: 0.814451 	Training F2-score: 0.822390 	Validation Loss: 0.405342 	Validation F1-score: 0.807472 	Validation accuracy: 0.812309 	Validation recall: 0.783870 	Validation precision: 0.843933 	Validation F2-score: 0.791973
# Epoch: 40 	Training Loss: 0.417786 	Training F1-score: 0.817898 	Training accuracy: 0.807869 	Training recall: 0.837439 	Training precision: 0.815781 	Training F2-score: 0.827301 	Validation Loss: 0.445937 	Validation F1-score: 0.766653 	Validation accuracy: 0.791685 	Validation recall: 0.680313 	Validation precision: 0.894365 	Validation F2-score: 0.711401

# %%
dict_train_losses={}
dict_train_f1s={}
dict_train_accuracys={}
dict_train_recalls={}
dict_train_precisions={}
dict_train_f2s={}

dict_val_losses={}
dict_val_f1s={}
dict_val_accuracys={}
dict_val_recalls={}
dict_val_precisions={}
dict_val_f2s={}

for i in range(0,40):
    dict_train_losses[i+1]=train_losses[i]
    dict_train_f1s[i+1]=train_f1s[i]
    dict_train_accuracys[i+1]=train_accuracys[i]
    dict_train_recalls[i+1]=train_recalls[i]
    dict_train_precisions[i+1]=train_precisions[i]
    dict_train_f2s[i+1]=train_f2s[i]

    dict_val_losses[i+1]=val_losses[i]
    dict_val_f1s[i+1]=val_f1s[i]
    dict_val_accuracys[i+1]=val_accuracys[i]
    dict_val_recalls[i+1]=val_recalls[i]
    dict_val_precisions[i+1]=val_precisions[i]
    dict_val_f2s[i+1]=val_f2s[i]

sorted_train_losses = sorted(dict_train_losses.items())
sorted_train_f1s = sorted(dict_train_f1s.items())
sorted_train_accuracys = sorted(dict_train_accuracys.items())
sorted_train_recalls = sorted(dict_train_recalls.items())
sorted_train_precisions = sorted(dict_train_precisions.items())
sorted_train_f2s = sorted(dict_train_f2s.items())

sorted_val_losses = sorted(dict_val_losses.items())
sorted_val_f1s = sorted(dict_val_f1s.items())
sorted_val_accuracys = sorted(dict_val_accuracys.items())
sorted_val_recalls = sorted(dict_val_recalls.items())
sorted_val_precisions = sorted(dict_val_precisions.items())
sorted_val_f2s = sorted(dict_val_f2s.items())

epochs, loss_train = zip(*sorted_train_losses)
epochs, f1_train = zip(*sorted_train_f1s)
epochs, acc_train = zip(*sorted_train_accuracys)
epochs, recall_train = zip(*sorted_train_recalls)
epochs, precision_train =zip(*sorted_train_precisions)
epochs, f2_train = zip(*sorted_train_f2s)

epochs, loss_val = zip(*sorted_val_losses)
epochs, f1_val = zip(*sorted_val_f1s)
epochs, acc_val = zip(*sorted_val_accuracys)
epochs, recall_val = zip(*sorted_val_recalls)
epochs, precision_val =zip(*sorted_val_precisions)
epochs, f2_val = zip(*sorted_val_f2s)


fig, axs = plt.subplots(3, 2, figsize=(15, 15))

axs[0,0].plot(epochs, loss_train, 'b',label="Loss sur l'échantillon d'apprentissage", color="blue")
axs[0,0].plot(epochs, loss_val, 'b',label="Loss sur l'échantillon de validation", color="red")
axs[0,0].legend()

axs[0,1].plot(epochs, acc_train, 'b',label="Accuracy sur l'échantillon d'apprentissage", color="blue")
axs[0,1].plot(epochs, acc_val, 'b',label="Accuracy sur l'échantillon de validation", color="red")
axs[0,1].legend()

axs[1,0].plot(epochs, precision_train, 'b',label="Precision sur l'échantillon d'apprentissage", color="blue")
axs[1,0].plot(epochs, precision_val, 'b',label="Precision sur l'échantillon de validation", color="red")
axs[1,0].legend()

axs[1,1].plot(epochs, recall_train, 'b',label="Recall sur l'échantillon d'apprentissage", color="blue")
axs[1,1].plot(epochs, recall_val, 'b',label="Recall sur l'échantillon de validation", color="red")
axs[1,1].legend()

axs[2,0].plot(epochs, f1_train, 'b',label="F1-score sur l'échantillon d'apprentissage", color="blue")
axs[2,0].plot(epochs, f1_val, 'b',label="F1-score sur l'échantillon de validation", color="red")
axs[2,0].legend()

axs[2,1].plot(epochs, f2_train, 'b',label="F2-score sur l'échantillon d'apprentissage", color="blue")
axs[2,1].plot(epochs, f2_val, 'b',label="F2-score sur l'échantillon de validation", color="red")
axs[2,1].legend()

plt.savefig('courbes_loss_resnet18_transfertlearning.png')
plt.show()

# %%
seed = 123
torch.manual_seed(seed)
np.random.seed(seed)

y_true_train, y_pred_train, proba_pred_train=predict(model=resnet18, path_model="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps/trained_resnet18_autocrop.pth", valid_loader=train_dataloader_augmente, device=None)
y_true_val, y_pred_val, proba_pred_val=predict(model=resnet18, path_model="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps/trained_resnet18_autocrop.pth", valid_loader=test_dataloader_augmente, device=None)

# %%
print("Loss sur l'échantillon train: {}".format(round(log_loss(y_true_train, proba_pred_train),2)))
print("Accuracy sur l'échantillon train: {}".format(round(accuracy_score(y_true_train, y_pred_train),2)))
print("Recall sur l'échantillon train: {}".format(round(recall_score(y_true_train, y_pred_train),2)))
print("Precision sur l'échantillon train: {}".format(round(precision_score(y_true_train, y_pred_train),2)))
print("F1-score sur l'échantillon train: {}".format(round(f1_score(y_true_train, y_pred_train),2)))
print("F2-score sur l'échantillon train: {} \n".format(round(fbeta_score(y_true_train, y_pred_train, beta=2),2)))

print("Loss sur l'échantillon test: {}".format(round(log_loss(y_true_val, proba_pred_val),2)))
print("Accuracy sur l'échantillon test: {}".format(round(accuracy_score(y_true_val, y_pred_val),2)))
print("Recall sur l'échantillon test: {}".format(round(recall_score(y_true_val, y_pred_val),2)))
print("Precision sur l'échantillon test: {}".format(round(precision_score(y_true_val, y_pred_val),2)))
print("F1-score sur l'échantillon test: {}".format(round(f1_score(y_true_val, y_pred_val),2)))
print("F2-score sur l'échantillon test: {}".format(round(fbeta_score(y_true_val, y_pred_val, beta=2),2)))

FP_rate, TP_rate, thresholds_keras = roc_curve(y_true_val, proba_pred_val)
AUC= auc(FP_rate, TP_rate)
print("AUC: {}".format(round(AUC, 2)))

plt.title('Courbe ROC:  ResNet-18 transfert learning')
plt.plot(FP_rate, TP_rate, label="AUC="+str(round(AUC, 2)))
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0], c=".7"), plt.plot([1, 1], c=".7")
plt.ylabel('Taux de vrais positifs')
plt.xlabel('Taux de faux positifs')
plt.legend(loc=4)
plt.savefig('ROC_resnet18_transfertlearning_crop.png')
plt.show()

prec, rec, thresholds_keras = precision_recall_curve(y_true_val, proba_pred_val)

fig, ax = plt.subplots()
ax.plot(rec, prec)

#add axis labels to plot
ax.set_title('Courbe Precision-Recall: ResNet 18 transfert learning')
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')

#display plot
plt.savefig('prec_recall_resnet18_transfertlearning_crop.png')
plt.show()

r = confusion_matrix(y_true_val, y_pred_val)

labels = ["Vrais négatifs", "Faux Positifs", "Faux négatifs", "Vrais positifs"]
categories = ["0", "1"]
make_confusion_matrix(r,
                      group_names=labels,
                      categories=categories,
                      )
# Out:
# Loss sur l'échantillon train: 0.44
# Accuracy sur l'échantillon train: 0.79
# Recall sur l'échantillon train: 0.69
# Precision sur l'échantillon train: 0.89
# F1-score sur l'échantillon train: 0.78
# F2-score sur l'échantillon train: 0.72
#
# Loss sur l'échantillon test: 0.44
# Accuracy sur l'échantillon test: 0.79
# Recall sur l'échantillon test: 0.68
# Precision sur l'échantillon test: 0.9
# F1-score sur l'échantillon test: 0.77
# F2-score sur l'échantillon test: 0.71
# AUC: 0.9

# %% [markdown]
# # Visualisation TSNE

# %%
seed = 123
torch.manual_seed(seed)
np.random.seed(seed)

dataset_tsne=BDAPPVClassification_path(img_dir="C:/Users/yanis/OneDrive/Documents/Projet Stat/Données/bdappv/google3",
                                  size=224,
                                  transform=transforms.Compose([transforms.Normalize(mean = mean,
                                                                    std= std)]))


# Define the samplers for training and testing sets
test_sampler_tsne = SubsetRandomSampler(test_indices)

# Define the dataloaders for training and testing sets
test_dataloader_tsne = DataLoader(dataset_tsne, batch_size=32, sampler=test_sampler_tsne)

# %%
def embedding(data):
    resnet18.eval()
    out = resnet18.conv1(data) #pass through CNN
    out= resnet18.bn1(out)
    out=resnet18.relu(out)
    out=resnet18.maxpool(out)
    out=resnet18.layer1(out)
    out=resnet18.layer2(out)
    out=resnet18.layer3(out)
    out=resnet18.layer4(out)
    out=torch.flatten(out, 1)
    return out

# %%
features = None
labels = None
image_paths = None

for data in test_dataloader_tsne:
    inputs=data[0]
    targets=data[1]
    paths=data[2]
    
    output = embedding(inputs)
    current_features = output.detach().numpy()
    if features is not None:
        features = np.concatenate((features, current_features))
    else:
        features = current_features

    if labels is not None:
        labels = np.concatenate((labels, targets))
    else:
        labels = targets
    
    if image_paths is not None:
        image_paths = np.concatenate((image_paths, paths))
    else:
        image_paths = paths

# %%
import itertools
fig, ax = plt.subplots(1, 3, figsize=(20,7), constrained_layout=True)

for c, per in zip(itertools.count(), [5, 30, 50]):
    tsne = TSNE(n_components=2,
                perplexity=per)
    tsne = tsne.fit_transform(features)
    scatter = ax[c].scatter(tsne[:, 0], tsne[:, 1], c=labels, cmap=matplotlib.colors.ListedColormap(["red", "blue"]), s=0.3)
    ax[c].set_title(f'Perplexity: {per}', fontsize=16)

# %%
tsne = TSNE(n_components=2, perplexity=30).fit_transform(features)
visualize_tsne(tsne, image_paths, labels)
# Out:
# Building the T-SNE plot: 100%|██████████| 5727/5727 [00:23<00:00, 241.00it/s]
