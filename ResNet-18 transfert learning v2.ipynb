# %% [markdown]
# # Préparation des données

# %% [markdown]
# ## Import et data augmentations

# %%
from  src.dataloader import *
from src.bdappv import *
from src.metrics import *
from src.resnet18 import *
from src.confusion_matrix import make_confusion_matrix
from torch.utils.data import DataLoader, SubsetRandomSampler
import matplotlib.pyplot as plt
from torchvision import transforms, datasets
import torch.nn as nn
import tensorflow as tf
from sklearn.metrics import fbeta_score, make_scorer, f1_score, accuracy_score, recall_score, precision_score, fbeta_score, precision_recall_curve, auc, roc_curve, log_loss, confusion_matrix
import torchvision.models as models
import os
from src.tsne import *
from torch.utils.data import DataLoader
import matplotlib
import torchvision.models as models
from sklearn.manifold import TSNE
import math
# Out:
# c:\Users\yanis\anaconda3\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: [WinError 127] La procédure spécifiée est introuvable
#   warn(f"Failed to load image Python extension: {e}")

# %%
dataset=BDAPPVClassification(img_dir="C:/Users/yanis/OneDrive/Documents/Projet Stat/Données/bdappv/google3", size=None)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
mean, std = batch_mean_and_sd(dataloader)
print("Moyenne par channel: {}".format(mean.tolist()))
print("Ecart-type par channel: {}".format(std.tolist()))

# %%
dataset_crop=BDAPPVClassification(img_dir="C:/Users/yanis/OneDrive/Documents/Projet Stat/Données/bdappv/google3",
                                  size=224,
                                  transform=transforms.Compose([transforms.Normalize(mean = mean,
                                                                    std= std)]))

# %%
seed = 123
torch.manual_seed(seed)
np.random.seed(seed)

dataset_crop=BDAPPVClassification(img_dir="C:/Users/yanis/OneDrive/Documents/Projet Stat/Données/bdappv/google3",
                                  size=224,
                                  transform=transforms.Compose([transforms.Normalize(mean = mean,
                                                                    std= std)]))

# Define the indices for training and testing sets
n = len(dataset)
train_size = int(0.8 * n)
test_size = n - train_size
train_indices = torch.arange(0, train_size)
test_indices = torch.arange(train_size, n)

# Define the samplers for training and testing sets
train_sampler = SubsetRandomSampler(train_indices)
test_sampler = SubsetRandomSampler(test_indices)

# Define the dataloaders for training and testing sets
train_dataloader_augmente = DataLoader(dataset_crop, batch_size=32, sampler=train_sampler)
test_dataloader_augmente = DataLoader(dataset_crop, batch_size=32, sampler=test_sampler)

print(len(train_dataloader_augmente))
batch = next(iter(train_dataloader_augmente))
print(batch[0].shape)
plt.imshow(batch[0][0].permute(1, 2, 0))
print(batch[1][0])
# Out:
# 716
# torch.Size([32, 3, 224, 224])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tensor(0)

# %% [markdown]
# # Import du modèle

# %%
resnet18 = models.resnet18(pretrained=True)

#Furthermore, in feature extracting, we don't need to calculate gradient for any layers except 
# the last layer that we initialize. For this we need to set .requires_grad to False
def set_parameter_requires_grad(model, feature_extracting=True):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False
            
set_parameter_requires_grad(resnet18)


nr_filters = resnet18.fc.in_features  #number of input features of last layer
#On ne met pas de sigmoid dans la dernière couche. C'est composé par la loss BCEWithLogitsLoss qui applique une sigmoid afin de calculer la cross-enthropy
resnet18.fc = nn.Linear(nr_filters, 1)

# %% [markdown]
# # Choix du Learning Rate

# %%
params_to_update = []
for name,param in resnet18.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name)
# Out:
# 	 fc.weight
# 	 fc.bias

# %%
def find_lr(train_loader=train_dataloader_augmente, optimizer=torch.optim.SGD(params_to_update, lr = 0.01, momentum=0.9, weight_decay=1e-4), init_value = 1e-8, final_value=10., beta = 0.98, criterion=nn.BCEWithLogitsLoss()):
    #Adapté de https://sgugger.github.io/how-do-you-find-a-good-learning-rate.html
    num = len(train_loader)-1
    mult = (final_value / init_value) ** (1/num)
    lr = init_value
    optimizer.param_groups[0]['lr'] = lr
    avg_loss = 0.
    best_loss = 0.
    batch_num = 0
    losses = []
    log_lrs = []
    for data, label in train_loader:
        batch_num += 1
        #As before, get theloss for this mini-batch of inputs/outputs
        optimizer.zero_grad()
        output = resnet18(data)
            
        loss = criterion(output,label.unsqueeze(1).float()) #loss sur le batch i.e 1/32*sum...
        #Compute the smoothed loss
        avg_loss = beta * avg_loss + (1-beta) *loss.item()
        smoothed_loss = avg_loss / (1 - beta**batch_num)
        #Stop if the loss is exploding
        if batch_num > 1 and smoothed_loss > 4 * best_loss:
            return log_lrs, losses
        #Record the best loss
        if smoothed_loss < best_loss or batch_num==1:
            best_loss = smoothed_loss
        #Store the values
        losses.append(smoothed_loss)
        log_lrs.append(math.log10(lr))
        #Do the SGD step
        loss.backward()
        optimizer.step()
        #Update the lr for the next step
        lr *= mult
        optimizer.param_groups[0]['lr'] = lr
    return log_lrs, losses

# %%
seed = 123
torch.manual_seed(seed)
np.random.seed(seed)

log_lrs, losses=find_lr(train_loader=train_dataloader_augmente, optimizer=torch.optim.SGD(params_to_update, lr = 0.01, momentum=0.9, weight_decay=1e-4), init_value = 1e-8, final_value=10., beta = 0.98, criterion=nn.BCEWithLogitsLoss())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_183184\1475732557.py in <module>
#       3 np.random.seed(seed)
#       4
# ----> 5 log_lrs, losses=find_lr(train_loader=train_dataloader_augmente, optimizer=torch.optim.SGD(params_to_update, lr = 0.01, momentum=0.9, weight_decay=1e-4), init_value = 1e-8, final_value=10., beta = 0.98, criterion=nn.BCEWithLogitsLoss())
#
# ~\AppData\Local\Temp\ipykernel_183184\649926335.py in find_lr(train_loader, optimizer, init_value, final_value, beta, criterion)
#      10     losses = []
#      11     log_lrs = []
# ---> 12     for data, label in train_loader:
#      13         batch_num += 1
#      14         #As before, get theloss for this mini-batch of inputs/outputs
#
# c:\Users\yanis\anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     679                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680                 self._reset()  # type: ignore[call-arg]
# --> 681             data = self._next_data()
#     682             self._num_yielded += 1
#     683             if self._dataset_kind == _DatasetKind.Iterable and \
#
# c:\Users\yanis\anaconda3\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     719     def _next_data(self):
#     720         index = self._next_index()  # may raise StopIteration
# --> 721         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     722         if self._pin_memory:
#     723             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# c:\Users\yanis\anaconda3\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# c:\Users\yanis\anaconda3\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# c:\Users\yanis\OneDrive\Documents\Projet Stat\statapps\src\bdappv.py in __getitem__(self, idx)
#     161             # apply crop transforms.
#     162             # updates the label if necessary.
# --> 163             image, label = self.crop(image, label)
#     164
#     165         # apply the additional transforms to the image.
#
# c:\Users\yanis\OneDrive\Documents\Projet Stat\statapps\src\bdappv.py in crop(self, image, label)
#     187
#     188             # check that the label does not change.
# --> 189             label = update_label(x, y, self.name, self.size, self.mask_dir)
#     190
#     191         return image, label
#
# c:\Users\yanis\OneDrive\Documents\Projet Stat\statapps\src\bdappv.py in update_label(x, y, name, size, mask_dir)
#      85
#      86     # open the mask
# ---> 87     mask = transforms.ToTensor()(Image.open(os.path.join(mask_dir, name)).convert("RGB"))
#      88     mask_cropped = torchvision.transforms.functional.crop(mask, y, x, size, size)
#      89
#
# c:\Users\yanis\anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    3090
#    3091     if filename:
# -> 3092         fp = builtins.open(filename, "rb")
#    3093         exclusive_fp = True
#    3094
#
# KeyboardInterrupt:

# %%
lrs=[10**k for k in log_lrs]
fig, ax = plt.subplots()

ax.plot(lrs[10:-5], losses[10:-5], 'b',label="Loss en fonction du learning rate", color="blue")
ax.set_xlabel("Learning rate")
ax.set_ylabel("Loss")
ax.set_xscale('log')
plt.show()

# %% [markdown]
# Le minimum de la loss est atteint pour un learning rate environ égal à 0,01. On remarque que la courbe de loss décroit le plus rapidement vers ce minimum pour un learning rate environ égal à 0,001. Cela semble être un bon choix.

# %% [markdown]
# # Fit et predict

# %%
def sig(x):
    return 1/(1 + np.exp(-x))

def train_model(model, train_loader, valid_loader, criterion, n_epochs, path_save_model, device=None):
    """Pour entrainer le modèle 
    /!\ certains commentaires sont à passer en code pour passer sur GPU
    """
    # number of epochs to train the model

    train_losses= []
    train_f1s=[]
    train_accuracys=[]
    train_recalls=[]
    train_precisions=[]
    train_f2s=[]

    valid_loss_min = np.Inf  # set initial "min" to infinity
    val_losses= []
    val_f1s=[]
    val_accuracys=[]
    val_recalls=[]
    val_precisions=[]
    val_f2s=[]

    # Here we only want to update the gradient for the classifier layer that we initialized.
    params_to_update = []
    for name,param in model.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            print("\t",name)

    optimizer=torch.optim.SGD(params_to_update, lr = 0.001, momentum=0.9, weight_decay=1e-4)
    
    for epoch in range(n_epochs):

        # monitor losses
        train_loss = 0
        train_f1=0
        train_accuracy=0
        train_recall=0
        train_precision=0
        train_f2=0

        valid_loss=0
        valid_f1=0
        valid_accuracy=0
        valid_recall=0
        valid_precision=0
        valid_f2=0

        iter_train=0
        iter_val=0
        ###################
        # train the model #
        ###################
        model.train() # prep model for training

        for data,label in train_loader:
            iter_train+=1

            # Pour utiliser GPU

            # inputs = inputs.to(device)
            # labels = labels.to(device)
            # model.to(device)

            # clear the gradients of all optimized variables
            optimizer.zero_grad()
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            output_detach = output.detach()

            # calculate the loss
            preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
            for i in range(len(output_detach)):
                if sig(output_detach[i])>0.5:
                    preds[i]=1
                else: preds[i]=0

            loss = criterion(output,label.unsqueeze(1).float()) #loss sur le batch i.e 1/32*sum...
            f1 = f1_score(label.numpy(), preds.T.numpy()[0])
            accuracy= accuracy_score(label.numpy(), preds.T.numpy()[0])
            recall= recall_score(label.numpy(), preds.T.numpy()[0])
            precision=precision_score(label.numpy(), preds.T.numpy()[0])
            f2=fbeta_score(label.numpy(), preds.T.numpy()[0], beta=2)

            # backward pass: compute gradient of the loss with respect to model parameters
            loss.backward()
            # perform a single optimization step (parameter update)
            optimizer.step()
            # update running training loss

            #loss.item(): retourne la valeur numérique de la loss transférée au CPU
            #loss.item() retourne la loss moyenne sur le mini-batch, d'où la multiplication
            #par data.size(0)
            train_loss += loss.item() * data.size(0)
            train_f1+=f1
            train_accuracy+=accuracy
            train_recall+=recall
            train_precision+=precision
            train_f2+=f2

        # print training/validation statistics 
        # calculate average loss over an epoch
        train_loss = train_loss / len(train_loader.sampler) 
        train_f1=train_f1/iter_train
        train_accuracy=train_accuracy/iter_train
        train_recall=train_recall/iter_train
        train_precision=train_precision/iter_train
        train_f2=train_f2/iter_train


        train_losses.append(train_loss)
        train_f1s.append(train_f1)
        train_accuracys.append(train_accuracy)
        train_recalls.append(train_recall)
        train_precisions.append(train_precision)
        train_f2s.append(train_f2)

        model.eval()

        for data,label in valid_loader:
            iter_val+=1

            # Pour utiliser GPU

            # inputs = inputs.to(device)
            # labels = labels.to(device)
            # model.to(device)

            with torch.no_grad():
                output = model(data)
                
            output_detach = output.detach()

            # calculate the loss
            preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
            for i in range(len(output_detach)):
                if sig(output_detach[i])>0.5:
                    preds[i]=1
                else: preds[i]=0
            
            loss = criterion(output,label.unsqueeze(1).float())
            f1 = f1_score(label.numpy(), preds.T.numpy()[0])
            accuracy= accuracy_score(label.numpy(), preds.T.numpy()[0])
            recall= recall_score(label.numpy(), preds.T.numpy()[0])
            precision= precision_score(label.numpy(), preds.T.numpy()[0])
            f2=fbeta_score(label.numpy(), preds.T.numpy()[0], beta=2)

            # update running validation loss 
            valid_loss+=loss.item() * data.size(0)
            valid_f1+=f1
            valid_accuracy+=accuracy
            valid_recall+=recall
            valid_precision+=precision
            valid_f2+=f2

        valid_loss=valid_loss/len(valid_loader.sampler)
        valid_f1=valid_f1/iter_val
        valid_accuracy=valid_accuracy/iter_val
        valid_recall=valid_recall/iter_val
        valid_precision=valid_precision/iter_val
        valid_f2=valid_f2/iter_val

        val_losses.append(valid_loss)
        val_f1s.append(valid_f1)
        val_accuracys.append(valid_accuracy)
        val_recalls.append(valid_recall)
        val_precisions.append(valid_precision)
        val_f2s.append(valid_f2)



        print('Epoch: {} \tTraining Loss: {:.6f} \tTraining F1-score: {:.6f} \tTraining accuracy: {:.6f} \tTraining recall: {:.6f} \tTraining precision: {:.6f} \tTraining F2-score: {:.6f} \tValidation Loss: {:.6f} \tValidation F1-score: {:.6f} \tValidation accuracy: {:.6f} \tValidation recall: {:.6f} \tValidation precision: {:.6f} \tValidation F2-score: {:.6f}'.format(
            epoch+1, 
            train_loss,
            train_f1,
            train_accuracy,
            train_recall,
            train_precision,
            train_f2,
            valid_loss,
            valid_f1,
            valid_accuracy,
            valid_recall,
            valid_precision,
            valid_f2
            ))
        
    torch.save(model.state_dict(), os.path.join(path_save_model,"trained_resnet18_autocrop.pth"))

    return train_losses, train_f1s, train_accuracys, train_recalls, train_precisions, train_f2s, val_losses, val_f1s, val_accuracys, val_recalls, val_precisions, val_f2s


def eval_model(model, path_model, valid_loader, criterion, n_epochs, device=None):
    """Pour voir les performances du modèle entraîné sur l'échantillon de validation
       /!\ certains commentaires sont à passer en code pour passer sur GPU

    """
    ######################    
    # validate the model #
    ######################
    valid_loss_min = np.Inf  # set initial "min" to infinity
    val_losses= []
    val_f1s=[]
    val_accuracys=[]
    val_recalls=[]
    val_precisions=[]
    val_f2s=[]

    model.load_state_dict(torch.load(path_model))
    model.eval()  # prep model for evaluation

    #model.to(device)

    for epoch in range(n_epochs):
        valid_loss=0
        valid_f1=0
        valid_accuracy=0
        valid_recall=0
        valid_precision=0
        valid_f2=0
        iter=0
        for data,label in valid_loader:

            # Pour utiliser GPU

            # inputs = inputs.to(device)
            # labels = labels.to(device)
            # model.to(device)

            with torch.no_grad():
                output = model(data)
                
            output_detach = output.detach()

            # calculate the loss
            preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
            for i in range(len(output_detach)):
                if sig(output_detach[i])>0.5:
                    preds[i]=1
                else: preds[i]=0
            
            loss = criterion(output,label.unsqueeze(1).float())
            f1 = f1_score(label.numpy(), preds.T.numpy()[0])
            accuracy= accuracy_score(label.numpy(), preds.T.numpy()[0])
            recall= recall_score(label.numpy(), preds.T.numpy()[0])
            precision= precision_score(label.numpy(), preds.T.numpy()[0])
            f2=fbeta_score(label.numpy(), preds.T.numpy()[0], beta=2)

            # update running validation loss 
            valid_loss+=loss.item() * data.size(0)
            valid_f1+=f1
            valid_accuracy+=accuracy
            valid_recall+=recall
            valid_precision+=precision
            valid_f2+=f2
            iter+=1

        valid_loss=valid_loss/len(valid_loader.sampler)
        valid_f1=valid_f1/iter
        valid_accuracy=valid_accuracy/iter
        valid_recall=valid_recall/iter
        valid_precision=valid_precision/iter
        valid_f2=valid_f2/iter

        val_losses.append(valid_loss)
        val_f1s.append(valid_f1)
        val_accuracys.append(valid_accuracy)
        val_recalls.append(valid_recall)
        val_precisions.append(valid_precision)
        val_f2s.append(valid_f2)

        print('Epoch: {} \tValidation Loss: {:.6f} \tValidation F1-score: {:.6f} \tValidation accuracy: {:.6f} \tValidation recall: {:.6f} \tValidation precision: {:.6f} \tValidation F2-score: {:.6f}'.format(
            epoch+1,
            valid_loss,
            valid_f1,
            valid_accuracy,
            valid_recall,
            valid_precision,
            valid_f2
            ))
        
    return val_losses, val_f1s, val_accuracys, val_recalls, val_precisions, val_f2s


def predict(model, path_model, valid_loader, device=None):
    """Pour prédire 0/1 à partir de l'échantillon de validation
       /!\ certains commentaires sont à passer en code pour passer sur GPU

    """
    model.load_state_dict(torch.load(path_model))
    model.eval()

    array_labels=np.array([])
    array_preds=np.array([])
    probas_pred=np.array([])

    for data,label in valid_loader:
        # Pour utiliser GPU

        # inputs = inputs.to(device)
        # labels = labels.to(device)
        # model.to(device)

        with torch.no_grad():
            output = model(data)
        output_detach = output.detach()

        # calculate the loss
        preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
        probas=torch.zeros(output_detach.shape[0], output_detach.shape[1])

        for i in range(len(output_detach)):
            if sig(output_detach[i])>0.5:
                preds[i]=1
            else: preds[i]=0
            probas[i]=sig(output_detach[i])
        probas_pred=np.append(probas_pred, probas.T.numpy()[0])
        array_preds=np.append(array_preds,preds.T.numpy()[0])
        array_labels=np.append(array_labels, label.numpy())

    return array_labels, array_preds, probas_pred

# %%
seed = 123
torch.manual_seed(seed)
np.random.seed(seed)

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
loss=nn.BCEWithLogitsLoss()
# Train model
train_losses, train_f1s, train_accuracys, train_recalls, train_precisions, train_f2s, val_losses, val_f1s, val_accuracys, val_recalls, val_precisions, val_f2s = train_model(model=resnet18, 
                                                                                 train_loader=train_dataloader_augmente,
                                                                                 valid_loader=test_dataloader_augmente, 
                                                                                 criterion=loss, 
                                                                                 n_epochs=40, 
                                                                                 path_save_model="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps",
                                                                                 device=None)
# Out:
# 	 fc.weight
# 	 fc.bias
# Epoch: 1 	Training Loss: 0.474485 	Training F1-score: 0.789843 	Training accuracy: 0.769270 	Training recall: 0.839610 	Training precision: 0.765546 	Training F2-score: 0.816037 	Validation Loss: 0.481203 	Validation F1-score: 0.808010 	Validation accuracy: 0.773000 	Validation recall: 0.916110 	Validation precision: 0.730061 	Validation F2-score: 0.867986
# Epoch: 2 	Training Loss: 0.433088 	Training F1-score: 0.811643 	Training accuracy: 0.796565 	Training recall: 0.843514 	Training precision: 0.796314 	Training F2-score: 0.828393 	Validation Loss: 0.482687 	Validation F1-score: 0.807987 	Validation accuracy: 0.772155 	Validation recall: 0.916598 	Validation precision: 0.728921 	Validation F2-score: 0.868437
# Epoch: 3 	Training Loss: 0.428906 	Training F1-score: 0.807674 	Training accuracy: 0.793807 	Training recall: 0.834182 	Training precision: 0.799270 	Training F2-score: 0.821129 	Validation Loss: 0.518005 	Validation F1-score: 0.807417 	Validation accuracy: 0.764445 	Validation recall: 0.945139 	Validation precision: 0.710832 	Validation F2-score: 0.883309
# Epoch: 4 	Training Loss: 0.423802 	Training F1-score: 0.815852 	Training accuracy: 0.802457 	Training recall: 0.842503 	Training precision: 0.805868 	Training F2-score: 0.829505 	Validation Loss: 0.468241 	Validation F1-score: 0.807869 	Validation accuracy: 0.777747 	Validation recall: 0.888894 	Validation precision: 0.746116 	Validation F2-score: 0.853542
# Epoch: 5 	Training Loss: 0.427096 	Training F1-score: 0.812081 	Training accuracy: 0.800072 	Training recall: 0.835064 	Training precision: 0.807229 	Training F2-score: 0.823420 	Validation Loss: 0.558685 	Validation F1-score: 0.804736 	Validation accuracy: 0.755367 	Validation recall: 0.961090 	Validation precision: 0.697582 	Validation F2-score: 0.890374
# Epoch: 6 	Training Loss: 0.425436 	Training F1-score: 0.812718 	Training accuracy: 0.799890 	Training recall: 0.838518 	Training precision: 0.804619 	Training F2-score: 0.825775 	Validation Loss: 0.486479 	Validation F1-score: 0.807378 	Validation accuracy: 0.771811 	Validation recall: 0.913837 	Validation precision: 0.729345 	Validation F2-score: 0.866705
# Epoch: 7 	Training Loss: 0.421939 	Training F1-score: 0.815274 	Training accuracy: 0.802929 	Training recall: 0.840174 	Training precision: 0.807615 	Training F2-score: 0.827859 	Validation Loss: 0.474974 	Validation F1-score: 0.808659 	Validation accuracy: 0.776497 	Validation recall: 0.903280 	Validation precision: 0.738454 	Validation F2-score: 0.861595
# Epoch: 8 	Training Loss: 0.422875 	Training F1-score: 0.815580 	Training accuracy: 0.803120 	Training recall: 0.837355 	Training precision: 0.810705 	Training F2-score: 0.826380 	Validation Loss: 0.471224 	Validation F1-score: 0.806842 	Validation accuracy: 0.777184 	Validation recall: 0.892232 	Validation precision: 0.742816 	Validation F2-score: 0.854724
# Epoch: 9 	Training Loss: 0.422320 	Training F1-score: 0.814240 	Training accuracy: 0.801115 	Training recall: 0.838513 	Training precision: 0.807719 	Training F2-score: 0.826395 	Validation Loss: 0.484480 	Validation F1-score: 0.804577 	Validation accuracy: 0.771935 	Validation recall: 0.906104 	Validation precision: 0.729373 	Validation F2-score: 0.861341
# Epoch: 10 	Training Loss: 0.419792 	Training F1-score: 0.815483 	Training accuracy: 0.803111 	Training recall: 0.837892 	Training precision: 0.809151 	Training F2-score: 0.826751 	Validation Loss: 0.506713 	Validation F1-score: 0.806541 	Validation accuracy: 0.767255 	Validation recall: 0.930941 	Validation precision: 0.716998 	Validation F2-score: 0.875528
# Epoch: 11 	Training Loss: 0.419636 	Training F1-score: 0.819637 	Training accuracy: 0.806758 	Training recall: 0.845561 	Training precision: 0.810020 	Training F2-score: 0.832967 	Validation Loss: 0.475535 	Validation F1-score: 0.807241 	Validation accuracy: 0.777195 	Validation recall: 0.896827 	Validation precision: 0.741752 	Validation F2-score: 0.857122
# Epoch: 12 	Training Loss: 0.418516 	Training F1-score: 0.816392 	Training accuracy: 0.804099 	Training recall: 0.839574 	Training precision: 0.809640 	Training F2-score: 0.828124 	Validation Loss: 0.460392 	Validation F1-score: 0.805894 	Validation accuracy: 0.782438 	Validation recall: 0.866722 	Validation precision: 0.761578 	Validation F2-score: 0.839856
# Epoch: 13 	Training Loss: 0.417263 	Training F1-score: 0.817172 	Training accuracy: 0.804473 	Training recall: 0.839634 	Training precision: 0.810799 	Training F2-score: 0.828479 	Validation Loss: 0.463665 	Validation F1-score: 0.809292 	Validation accuracy: 0.783846 	Validation recall: 0.877766 	Validation precision: 0.757618 	Validation F2-score: 0.847841
# Epoch: 14 	Training Loss: 0.420732 	Training F1-score: 0.816848 	Training accuracy: 0.803659 	Training recall: 0.840601 	Training precision: 0.809861 	Training F2-score: 0.828814 	Validation Loss: 0.539227 	Validation F1-score: 0.806846 	Validation accuracy: 0.761995 	Validation recall: 0.949062 	Validation precision: 0.706741 	Validation F2-score: 0.885320
# Epoch: 15 	Training Loss: 0.417593 	Training F1-score: 0.820596 	Training accuracy: 0.808460 	Training recall: 0.845335 	Training precision: 0.811224 	Training F2-score: 0.833294 	Validation Loss: 0.472591 	Validation F1-score: 0.809849 	Validation accuracy: 0.780501 	Validation recall: 0.895384 	Validation precision: 0.746218 	Validation F2-score: 0.857751
# Epoch: 16 	Training Loss: 0.417522 	Training F1-score: 0.817803 	Training accuracy: 0.806567 	Training recall: 0.840210 	Training precision: 0.812090 	Training F2-score: 0.828988 	Validation Loss: 0.487775 	Validation F1-score: 0.808697 	Validation accuracy: 0.775956 	Validation recall: 0.912277 	Validation precision: 0.733997 	Validation F2-score: 0.866109
# Epoch: 17 	Training Loss: 0.419988 	Training F1-score: 0.817898 	Training accuracy: 0.805040 	Training recall: 0.841194 	Training precision: 0.810770 	Training F2-score: 0.829634 	Validation Loss: 0.488890 	Validation F1-score: 0.806273 	Validation accuracy: 0.772110 	Validation recall: 0.911282 	Validation precision: 0.729436 	Validation F2-score: 0.864790
# Epoch: 18 	Training Loss: 0.415813 	Training F1-score: 0.818301 	Training accuracy: 0.806071 	Training recall: 0.840820 	Training precision: 0.812431 	Training F2-score: 0.829563 	Validation Loss: 0.512453 	Validation F1-score: 0.806848 	Validation accuracy: 0.767075 	Validation recall: 0.930013 	Validation precision: 0.718007 	Validation F2-score: 0.875229
# Epoch: 19 	Training Loss: 0.422866 	Training F1-score: 0.815338 	Training accuracy: 0.803103 	Training recall: 0.838641 	Training precision: 0.809650 	Training F2-score: 0.826887 	Validation Loss: 0.526258 	Validation F1-score: 0.807016 	Validation accuracy: 0.762851 	Validation recall: 0.944646 	Validation precision: 0.709754 	Validation F2-score: 0.883012
# Epoch: 20 	Training Loss: 0.419499 	Training F1-score: 0.815141 	Training accuracy: 0.802457 	Training recall: 0.838993 	Training precision: 0.808823 	Training F2-score: 0.827090 	Validation Loss: 0.469244 	Validation F1-score: 0.805443 	Validation accuracy: 0.779290 	Validation recall: 0.877786 	Validation precision: 0.751968 	Validation F2-score: 0.845946
# Epoch: 21 	Training Loss: 0.416506 	Training F1-score: 0.817532 	Training accuracy: 0.805754 	Training recall: 0.839985 	Training precision: 0.810295 	Training F2-score: 0.828985 	Validation Loss: 0.560540 	Validation F1-score: 0.806551 	Validation accuracy: 0.760447 	Validation recall: 0.956277 	Validation precision: 0.702584 	Validation F2-score: 0.888820
# Epoch: 22 	Training Loss: 0.417284 	Training F1-score: 0.816946 	Training accuracy: 0.804246 	Training recall: 0.840418 	Training precision: 0.810403 	Training F2-score: 0.828758 	Validation Loss: 0.466323 	Validation F1-score: 0.804667 	Validation accuracy: 0.779470 	Validation recall: 0.865852 	Validation precision: 0.759973 	Validation F2-score: 0.838795
# Epoch: 23 	Training Loss: 0.418509 	Training F1-score: 0.816397 	Training accuracy: 0.804350 	Training recall: 0.839302 	Training precision: 0.811532 	Training F2-score: 0.827734 	Validation Loss: 0.488229 	Validation F1-score: 0.803964 	Validation accuracy: 0.770916 	Validation recall: 0.908579 	Validation precision: 0.727610 	Validation F2-score: 0.862151
# Epoch: 24 	Training Loss: 0.423447 	Training F1-score: 0.815523 	Training accuracy: 0.802901 	Training recall: 0.840139 	Training precision: 0.807787 	Training F2-score: 0.827995 	Validation Loss: 0.464589 	Validation F1-score: 0.806863 	Validation accuracy: 0.784004 	Validation recall: 0.864199 	Validation precision: 0.763559 	Validation F2-score: 0.839203
# Epoch: 25 	Training Loss: 0.413256 	Training F1-score: 0.819687 	Training accuracy: 0.807642 	Training recall: 0.840311 	Training precision: 0.813729 	Training F2-score: 0.830061 	Validation Loss: 0.539187 	Validation F1-score: 0.807442 	Validation accuracy: 0.762874 	Validation recall: 0.946633 	Validation precision: 0.709171 	Validation F2-score: 0.884276
# Epoch: 26 	Training Loss: 0.417146 	Training F1-score: 0.816375 	Training accuracy: 0.803968 	Training recall: 0.839709 	Training precision: 0.809189 	Training F2-score: 0.828137 	Validation Loss: 0.463475 	Validation F1-score: 0.805354 	Validation accuracy: 0.782433 	Validation recall: 0.862970 	Validation precision: 0.763657 	Validation F2-score: 0.837478
# Epoch: 27 	Training Loss: 0.420711 	Training F1-score: 0.815550 	Training accuracy: 0.804587 	Training recall: 0.837382 	Training precision: 0.811142 	Training F2-score: 0.826253 	Validation Loss: 0.464739 	Validation F1-score: 0.806067 	Validation accuracy: 0.782450 	Validation recall: 0.870818 	Validation precision: 0.756801 	Validation F2-score: 0.842565
# Epoch: 28 	Training Loss: 0.416287 	Training F1-score: 0.819749 	Training accuracy: 0.808000 	Training recall: 0.841066 	Training precision: 0.813903 	Training F2-score: 0.830487 	Validation Loss: 0.464760 	Validation F1-score: 0.808804 	Validation accuracy: 0.784021 	Validation recall: 0.873471 	Validation precision: 0.761104 	Validation F2-score: 0.845029
# Epoch: 29 	Training Loss: 0.417001 	Training F1-score: 0.818939 	Training accuracy: 0.807253 	Training recall: 0.842682 	Training precision: 0.812432 	Training F2-score: 0.830826 	Validation Loss: 0.485115 	Validation F1-score: 0.808968 	Validation accuracy: 0.773354 	Validation recall: 0.915919 	Validation precision: 0.731946 	Validation F2-score: 0.868335
# Epoch: 30 	Training Loss: 0.417518 	Training F1-score: 0.818932 	Training accuracy: 0.806873 	Training recall: 0.841854 	Training precision: 0.812590 	Training F2-score: 0.830435 	Validation Loss: 0.547235 	Validation F1-score: 0.807143 	Validation accuracy: 0.762699 	Validation recall: 0.951886 	Validation precision: 0.706615 	Validation F2-score: 0.886602
# Epoch: 31 	Training Loss: 0.415390 	Training F1-score: 0.819007 	Training accuracy: 0.807326 	Training recall: 0.840274 	Training precision: 0.813306 	Training F2-score: 0.829745 	Validation Loss: 0.544425 	Validation F1-score: 0.807906 	Validation accuracy: 0.764789 	Validation recall: 0.948962 	Validation precision: 0.708710 	Validation F2-score: 0.885666
# Epoch: 32 	Training Loss: 0.422574 	Training F1-score: 0.814345 	Training accuracy: 0.802441 	Training recall: 0.837516 	Training precision: 0.809129 	Training F2-score: 0.825776 	Validation Loss: 0.462987 	Validation F1-score: 0.805275 	Validation accuracy: 0.780152 	Validation recall: 0.868606 	Validation precision: 0.757482 	Validation F2-score: 0.840938
# Epoch: 33 	Training Loss: 0.418698 	Training F1-score: 0.817956 	Training accuracy: 0.805965 	Training recall: 0.842275 	Training precision: 0.810870 	Training F2-score: 0.830154 	Validation Loss: 0.485478 	Validation F1-score: 0.806114 	Validation accuracy: 0.772138 	Validation recall: 0.906236 	Validation precision: 0.731933 	Validation F2-score: 0.862147
# Epoch: 34 	Training Loss: 0.419924 	Training F1-score: 0.815690 	Training accuracy: 0.803870 	Training recall: 0.838777 	Training precision: 0.810493 	Training F2-score: 0.827080 	Validation Loss: 0.477462 	Validation F1-score: 0.807461 	Validation accuracy: 0.775979 	Validation recall: 0.898246 	Validation precision: 0.739618 	Validation F2-score: 0.858322
# Epoch: 35 	Training Loss: 0.416378 	Training F1-score: 0.818249 	Training accuracy: 0.806044 	Training recall: 0.841338 	Training precision: 0.813062 	Training F2-score: 0.829720 	Validation Loss: 0.464768 	Validation F1-score: 0.805568 	Validation accuracy: 0.781036 	Validation recall: 0.868528 	Validation precision: 0.758926 	Validation F2-score: 0.840838
# Epoch: 36 	Training Loss: 0.412763 	Training F1-score: 0.819134 	Training accuracy: 0.806826 	Training recall: 0.840421 	Training precision: 0.813172 	Training F2-score: 0.829839 	Validation Loss: 0.462936 	Validation F1-score: 0.808075 	Validation accuracy: 0.786273 	Validation recall: 0.857807 	Validation precision: 0.772160 	Validation F2-score: 0.835765
# Epoch: 37 	Training Loss: 0.420752 	Training F1-score: 0.816811 	Training accuracy: 0.805171 	Training recall: 0.839114 	Training precision: 0.812787 	Training F2-score: 0.827712 	Validation Loss: 0.475426 	Validation F1-score: 0.807378 	Validation accuracy: 0.777342 	Validation recall: 0.891736 	Validation precision: 0.743459 	Validation F2-score: 0.854834
# Epoch: 38 	Training Loss: 0.420500 	Training F1-score: 0.815853 	Training accuracy: 0.803485 	Training recall: 0.840685 	Training precision: 0.808962 	Training F2-score: 0.828339 	Validation Loss: 0.475044 	Validation F1-score: 0.807682 	Validation accuracy: 0.778581 	Validation recall: 0.888918 	Validation precision: 0.747521 	Validation F2-score: 0.853091
# Epoch: 39 	Training Loss: 0.415831 	Training F1-score: 0.819016 	Training accuracy: 0.806837 	Training recall: 0.841893 	Training precision: 0.812184 	Training F2-score: 0.830545 	Validation Loss: 0.468963 	Validation F1-score: 0.808711 	Validation accuracy: 0.780343 	Validation recall: 0.891949 	Validation precision: 0.746265 	Validation F2-score: 0.855436
# Epoch: 40 	Training Loss: 0.420543 	Training F1-score: 0.817185 	Training accuracy: 0.805179 	Training recall: 0.838900 	Training precision: 0.811177 	Training F2-score: 0.828034 	Validation Loss: 0.462172 	Validation F1-score: 0.804117 	Validation accuracy: 0.781554 	Validation recall: 0.857047 	Validation precision: 0.764980 	Validation F2-score: 0.833867

# %%
dict_train_losses={}
dict_train_f1s={}
dict_train_accuracys={}
dict_train_recalls={}
dict_train_precisions={}
dict_train_f2s={}

dict_val_losses={}
dict_val_f1s={}
dict_val_accuracys={}
dict_val_recalls={}
dict_val_precisions={}
dict_val_f2s={}

for i in range(0,40):
    dict_train_losses[i+1]=train_losses[i]
    dict_train_f1s[i+1]=train_f1s[i]
    dict_train_accuracys[i+1]=train_accuracys[i]
    dict_train_recalls[i+1]=train_recalls[i]
    dict_train_precisions[i+1]=train_precisions[i]
    dict_train_f2s[i+1]=train_f2s[i]

    dict_val_losses[i+1]=val_losses[i]
    dict_val_f1s[i+1]=val_f1s[i]
    dict_val_accuracys[i+1]=val_accuracys[i]
    dict_val_recalls[i+1]=val_recalls[i]
    dict_val_precisions[i+1]=val_precisions[i]
    dict_val_f2s[i+1]=val_f2s[i]

sorted_train_losses = sorted(dict_train_losses.items())
sorted_train_f1s = sorted(dict_train_f1s.items())
sorted_train_accuracys = sorted(dict_train_accuracys.items())
sorted_train_recalls = sorted(dict_train_recalls.items())
sorted_train_precisions = sorted(dict_train_precisions.items())
sorted_train_f2s = sorted(dict_train_f2s.items())

sorted_val_losses = sorted(dict_val_losses.items())
sorted_val_f1s = sorted(dict_val_f1s.items())
sorted_val_accuracys = sorted(dict_val_accuracys.items())
sorted_val_recalls = sorted(dict_val_recalls.items())
sorted_val_precisions = sorted(dict_val_precisions.items())
sorted_val_f2s = sorted(dict_val_f2s.items())

epochs, loss_train = zip(*sorted_train_losses)
epochs, f1_train = zip(*sorted_train_f1s)
epochs, acc_train = zip(*sorted_train_accuracys)
epochs, recall_train = zip(*sorted_train_recalls)
epochs, precision_train =zip(*sorted_train_precisions)
epochs, f2_train = zip(*sorted_train_f2s)

epochs, loss_val = zip(*sorted_val_losses)
epochs, f1_val = zip(*sorted_val_f1s)
epochs, acc_val = zip(*sorted_val_accuracys)
epochs, recall_val = zip(*sorted_val_recalls)
epochs, precision_val =zip(*sorted_val_precisions)
epochs, f2_val = zip(*sorted_val_f2s)


fig, axs = plt.subplots(3, 2, figsize=(15, 15))

axs[0,0].plot(epochs, loss_train, 'b',label="Loss sur l'échantillon d'apprentissage", color="blue")
axs[0,0].plot(epochs, loss_val, 'b',label="Loss sur l'échantillon de validation", color="red")
axs[0,0].legend()

axs[0,1].plot(epochs, acc_train, 'b',label="Accuracy sur l'échantillon d'apprentissage", color="blue")
axs[0,1].plot(epochs, acc_val, 'b',label="Accuracy sur l'échantillon de validation", color="red")
axs[0,1].legend()

axs[1,0].plot(epochs, precision_train, 'b',label="Precision sur l'échantillon d'apprentissage", color="blue")
axs[1,0].plot(epochs, precision_val, 'b',label="Precision sur l'échantillon de validation", color="red")
axs[1,0].legend()

axs[1,1].plot(epochs, recall_train, 'b',label="Recall sur l'échantillon d'apprentissage", color="blue")
axs[1,1].plot(epochs, recall_val, 'b',label="Recall sur l'échantillon de validation", color="red")
axs[1,1].legend()

axs[2,0].plot(epochs, f1_train, 'b',label="F1-score sur l'échantillon d'apprentissage", color="blue")
axs[2,0].plot(epochs, f1_val, 'b',label="F1-score sur l'échantillon de validation", color="red")
axs[2,0].legend()

axs[2,1].plot(epochs, f2_train, 'b',label="F2-score sur l'échantillon d'apprentissage", color="blue")
axs[2,1].plot(epochs, f2_val, 'b',label="F2-score sur l'échantillon de validation", color="red")
axs[2,1].legend()

plt.savefig('courbes_loss_resnet18_transfertlearning.png')
plt.show()

# %%
seed = 123
torch.manual_seed(seed)
np.random.seed(seed)

y_true_train, y_pred_train, proba_pred_train=predict(model=resnet18, path_model="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps/trained_resnet18_autocrop.pth", valid_loader=train_dataloader_augmente, device=None)
y_true_val, y_pred_val, proba_pred_val=predict(model=resnet18, path_model="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps/trained_resnet18_autocrop.pth", valid_loader=test_dataloader_augmente, device=None)

# %%
print("Loss sur l'échantillon train: {}".format(round(log_loss(y_true_train, proba_pred_train),2)))
print("Accuracy sur l'échantillon train: {}".format(round(accuracy_score(y_true_train, y_pred_train),2)))
print("Recall sur l'échantillon train: {}".format(round(recall_score(y_true_train, y_pred_train),2)))
print("Precision sur l'échantillon train: {}".format(round(precision_score(y_true_train, y_pred_train),2)))
print("F1-score sur l'échantillon train: {}".format(round(f1_score(y_true_train, y_pred_train),2)))
print("F2-score sur l'échantillon train: {} \n".format(round(fbeta_score(y_true_train, y_pred_train, beta=2),2)))

print("Loss sur l'échantillon test: {}".format(round(log_loss(y_true_val, proba_pred_val),2)))
print("Accuracy sur l'échantillon test: {}".format(round(accuracy_score(y_true_val, y_pred_val),2)))
print("Recall sur l'échantillon test: {}".format(round(recall_score(y_true_val, y_pred_val),2)))
print("Precision sur l'échantillon test: {}".format(round(precision_score(y_true_val, y_pred_val),2)))
print("F1-score sur l'échantillon test: {}".format(round(f1_score(y_true_val, y_pred_val),2)))
print("F2-score sur l'échantillon test: {}".format(round(fbeta_score(y_true_val, y_pred_val, beta=2),2)))

FP_rate, TP_rate, thresholds_keras = roc_curve(y_true_val, proba_pred_val)
AUC= auc(FP_rate, TP_rate)
print("AUC: {}".format(round(AUC, 2)))

plt.title('Courbe ROC:  ResNet-18 transfert learning')
plt.plot(FP_rate, TP_rate, label="AUC="+str(round(AUC, 2)))
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0], c=".7"), plt.plot([1, 1], c=".7")
plt.ylabel('Taux de vrais positifs')
plt.xlabel('Taux de faux positifs')
plt.legend(loc=4)
plt.savefig('ROC_resnet18_transfertlearning.png')
plt.show()

prec, rec, thresholds_keras = precision_recall_curve(y_true_val, proba_pred_val)

fig, ax = plt.subplots()
ax.plot(rec, prec)

#add axis labels to plot
ax.set_title('Courbe Precision-Recall: ResNet 18 transfert learning')
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')

#display plot
plt.savefig('prec_recall_resnet18_transfertlearning.png')
plt.show()

r = confusion_matrix(y_true_val, y_pred_val)

labels = ["Vrais négatifs", "Faux Positifs", "Faux négatifs", "Vrais positifs"]
categories = ["0", "1"]
make_confusion_matrix(r,
                      group_names=labels,
                      categories=categories,
                      )
# Out:
# Loss sur l'échantillon train: 0.4
# Accuracy sur l'échantillon train: 0.81
# Recall sur l'échantillon train: 0.79
# Precision sur l'échantillon train: 0.85
# F1-score sur l'échantillon train: 0.82
# F2-score sur l'échantillon train: 0.8
#
# Loss sur l'échantillon test: 0.46
# Accuracy sur l'échantillon test: 0.78
# Recall sur l'échantillon test: 0.86
# Precision sur l'échantillon test: 0.76
# F1-score sur l'échantillon test: 0.81
# F2-score sur l'échantillon test: 0.84
# AUC: 0.86

# %% [markdown]
# # Visualisation TSNE

# %%
seed = 123
torch.manual_seed(seed)
np.random.seed(seed)

dataset_tsne=BDAPPVClassification_path(img_dir="C:/Users/yanis/OneDrive/Documents/Projet Stat/Données/bdappv/google3",
                                  size=224,
                                  transform=transforms.Compose([transforms.Normalize(mean = mean,
                                                                    std= std)]))


# Define the samplers for training and testing sets
test_sampler_tsne = SubsetRandomSampler(test_indices)

# Define the dataloaders for training and testing sets
test_dataloader_tsne = DataLoader(dataset_tsne, batch_size=32, sampler=test_sampler_tsne)

# %%
def embedding(data):
    resnet18.eval()
    out = resnet18.conv1(data) #pass through CNN
    out= resnet18.bn1(out)
    out=resnet18.relu(out)
    out=resnet18.maxpool(out)
    out=resnet18.layer1(out)
    out=resnet18.layer2(out)
    out=resnet18.layer3(out)
    out=resnet18.layer4(out)
    out=torch.flatten(out, 1)
    return out

# %%
features = None
labels = None
image_paths = None

for data in test_dataloader_tsne:
    inputs=data[0]
    targets=data[1]
    paths=data[2]
    
    output = embedding(inputs)
    current_features = output.detach().numpy()
    if features is not None:
        features = np.concatenate((features, current_features))
    else:
        features = current_features

    if labels is not None:
        labels = np.concatenate((labels, targets))
    else:
        labels = targets
    
    if image_paths is not None:
        image_paths = np.concatenate((image_paths, paths))
    else:
        image_paths = paths

# %%
import itertools
fig, ax = plt.subplots(1, 3, figsize=(20,7), constrained_layout=True)

for c, per in zip(itertools.count(), [5, 30, 50]):
    tsne = TSNE(n_components=2,
                perplexity=per)
    tsne = tsne.fit_transform(features)
    scatter = ax[c].scatter(tsne[:, 0], tsne[:, 1], c=labels, cmap=matplotlib.colors.ListedColormap(["red", "blue"]), s=0.3)
    ax[c].set_title(f'Perplexity: {per}', fontsize=16)

# %%
tsne = TSNE(n_components=2, perplexity=30).fit_transform(features)
visualize_tsne(tsne, image_paths, labels)
# Out:
# Building the T-SNE plot: 100%|██████████| 5727/5727 [00:17<00:00, 334.97it/s]
