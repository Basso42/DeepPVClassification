# %% [markdown]
# # Préparation des données

# %% [markdown]
# ## Import et data augmentations

# %%
from  src.dataloader import *
from src.metrics import *
from src.resnet18 import *
from src.confusion_matrix import make_confusion_matrix
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from torchvision import transforms, datasets
import torch.nn as nn
import tensorflow as tf
from sklearn.metrics import fbeta_score, make_scorer, f1_score, accuracy_score, recall_score, precision_score, fbeta_score, precision_recall_curve, auc, roc_curve, log_loss, confusion_matrix
import torchvision.models as models
import os
from src.tsne import *
from torch.utils.data import DataLoader
import matplotlib
import torchvision.models as models
from sklearn.manifold import TSNE
import math
# Out:
# c:\Users\yanis\anaconda3\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: [WinError 127] La procédure spécifiée est introuvable
#   warn(f"Failed to load image Python extension: {e}")

# %%
np.random.seed(123)
path_train="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps/train_data.csv"
path_test="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps/test_data.csv"

transformed_train_dataset  = CustomImageDataset(path_train,"C:/Users/yanis/OneDrive/Documents/Projet Stat/Données/bdappv/google2/img/", transform=transforms.Compose([
                                               transforms.Resize(224),
                                               transforms.RandomCrop(190), #On garde environ 75% de l'image
                                               transforms.ColorJitter(brightness=(0.5,1.5),contrast=0,saturation=0,hue=0),                                               transforms.RandomCrop(160),
                                               transforms.Resize(224),
                                               transforms.ToTensor(),
                                               transforms.Normalize(mean = [0.34672418236732483, 0.354153573513031, 0.3043244183063507],
                                                                    std= [0.19679038226604462, 0.17956718802452087, 0.17369826138019562]),

                                           ]))

transformed_test_dataset = CustomImageDataset(path_test,"C:/Users/yanis/OneDrive/Documents/Projet Stat/Données/bdappv/google2/img/",
                                            transform=transforms.Compose([
                                               transforms.Resize(224),
                                               transforms.ToTensor(),
                                               transforms.Normalize(mean = [0.34332898259162903, 0.35128462314605713, 0.30205702781677246],
                                                                    std= [0.1959962248802185, 0.17875953018665314, 0.17301008105278015]),
                                           ]))

train_dataloader_augmente = DataLoader(transformed_train_dataset, batch_size=32, shuffle=True)
test_dataloader_augmente = DataLoader(transformed_test_dataset, batch_size=32, shuffle=True)

print(len(train_dataloader_augmente))
batch = next(iter(train_dataloader_augmente))
print(batch[0].shape)
plt.imshow(batch[0][0].permute(1, 2, 0))
print(batch[1][0])
# Out:
# 716
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([32, 3, 224, 224])
# tensor(1)

# %%
# mean_train, std_train = mean_std(train_dataloader_augmente)
# print("Moyenne par channel: {}".format(mean_train.tolist()))
# print("Ecart-type par channel: {}".format(std_train.tolist()))

# mean_test, std_test = mean_std(test_dataloader_augmente)
# print("Moyenne par channel: {}".format(mean_test.tolist()))
# print("Ecart-type par channel: {}".format(std_test.tolist()))
# Out:
# Moyenne par channel: [0.34672418236732483, 0.354153573513031, 0.3043244183063507]
# Ecart-type par channel: [0.19679038226604462, 0.17956718802452087, 0.17369826138019562]
# Moyenne par channel: [0.34332898259162903, 0.35128462314605713, 0.30205702781677246]
# Ecart-type par channel: [0.1959962248802185, 0.17875953018665314, 0.17301008105278015]

# %% [markdown]
# # Import du modèle

# %%
resnet18 = models.resnet18(pretrained=True)

#Furthermore, in feature extracting, we don't need to calculate gradient for any layers except 
# the last layer that we initialize. For this we need to set .requires_grad to False
def set_parameter_requires_grad(model, feature_extracting=True):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False
            
set_parameter_requires_grad(resnet18)


nr_filters = resnet18.fc.in_features  #number of input features of last layer
#On ne met pas de sigmoid dans la dernière couche. C'est composé par la loss BCEWithLogitsLoss qui applique une sigmoid afin de calculer la cross-enthropy
resnet18.fc = nn.Linear(nr_filters, 1)

# %% [markdown]
# # Choix du Learning Rate

# %%
params_to_update = []
for name,param in resnet18.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name)
# Out:
# 	 fc.weight
# 	 fc.bias

# %%
def find_lr(train_loader=train_dataloader_augmente, optimizer=torch.optim.SGD(params_to_update, lr = 0.01, momentum=0.9, weight_decay=1e-4), init_value = 1e-8, final_value=10., beta = 0.98, criterion=nn.BCEWithLogitsLoss()):
    #Adapté de https://sgugger.github.io/how-do-you-find-a-good-learning-rate.html
    num = len(train_loader)-1
    mult = (final_value / init_value) ** (1/num)
    lr = init_value
    optimizer.param_groups[0]['lr'] = lr
    avg_loss = 0.
    best_loss = 0.
    batch_num = 0
    losses = []
    log_lrs = []
    for data, label in train_loader:
        batch_num += 1
        #As before, get theloss for this mini-batch of inputs/outputs
        optimizer.zero_grad()
        output = resnet18(data)
            
        loss = criterion(output,label.unsqueeze(1).float()) #loss sur le batch i.e 1/32*sum...
        #Compute the smoothed loss
        avg_loss = beta * avg_loss + (1-beta) *loss.item()
        smoothed_loss = avg_loss / (1 - beta**batch_num)
        #Stop if the loss is exploding
        if batch_num > 1 and smoothed_loss > 4 * best_loss:
            return log_lrs, losses
        #Record the best loss
        if smoothed_loss < best_loss or batch_num==1:
            best_loss = smoothed_loss
        #Store the values
        losses.append(smoothed_loss)
        log_lrs.append(math.log10(lr))
        #Do the SGD step
        loss.backward()
        optimizer.step()
        #Update the lr for the next step
        lr *= mult
        optimizer.param_groups[0]['lr'] = lr
    return log_lrs, losses

# %%
np.random.seed(123)
log_lrs, losses=find_lr(train_loader=train_dataloader_augmente, optimizer=torch.optim.SGD(params_to_update, lr = 0.01, momentum=0.9, weight_decay=1e-4), init_value = 1e-8, final_value=10., beta = 0.98, criterion=nn.BCEWithLogitsLoss())

# %%
lrs=[10**k for k in log_lrs]
fig, ax = plt.subplots()

ax.plot(lrs[10:-5], losses[10:-5], 'b',label="Loss en fonction du learning rate", color="blue")
ax.set_xlabel("Learning rate")
ax.set_ylabel("Loss")
ax.set_xscale('log')
plt.show()

# %% [markdown]
# Le minimum de la loss est atteint pour un learning rate environ égal à 0,01. On remarque que la courbe de loss décroit le plus rapidement vers ce minimum pour un learning rate environ égal à 0,001. Cela semble être un bon choix.

# %% [markdown]
# # Fit et predict

# %%
def sig(x):
    return 1/(1 + np.exp(-x))

def train_model(model, train_loader, valid_loader, criterion, n_epochs, path_save_model, device=None):
    """Pour entrainer le modèle 
    /!\ certains commentaires sont à passer en code pour passer sur GPU
    """
    # number of epochs to train the model

    train_losses= []
    train_f1s=[]
    train_accuracys=[]
    train_recalls=[]
    train_precisions=[]
    train_f2s=[]

    valid_loss_min = np.Inf  # set initial "min" to infinity
    val_losses= []
    val_f1s=[]
    val_accuracys=[]
    val_recalls=[]
    val_precisions=[]
    val_f2s=[]

    # Here we only want to update the gradient for the classifier layer that we initialized.
    params_to_update = []
    for name,param in model.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            print("\t",name)

    optimizer=torch.optim.SGD(params_to_update, lr = 0.001, momentum=0.9, weight_decay=1e-4)
    
    for epoch in range(n_epochs):

        # monitor losses
        train_loss = 0
        train_f1=0
        train_accuracy=0
        train_recall=0
        train_precision=0
        train_f2=0

        valid_loss=0
        valid_f1=0
        valid_accuracy=0
        valid_recall=0
        valid_precision=0
        valid_f2=0

        iter_train=0
        iter_val=0
        ###################
        # train the model #
        ###################
        model.train() # prep model for training

        for data,label in train_loader:
            iter_train+=1

            # Pour utiliser GPU

            # inputs = inputs.to(device)
            # labels = labels.to(device)
            # model.to(device)

            # clear the gradients of all optimized variables
            optimizer.zero_grad()
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            output_detach = output.detach()

            # calculate the loss
            preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
            for i in range(len(output_detach)):
                if sig(output_detach[i])>0.5:
                    preds[i]=1
                else: preds[i]=0

            loss = criterion(output,label.unsqueeze(1).float()) #loss sur le batch i.e 1/32*sum...
            f1 = f1_score(label.numpy(), preds.T.numpy()[0])
            accuracy= accuracy_score(label.numpy(), preds.T.numpy()[0])
            recall= recall_score(label.numpy(), preds.T.numpy()[0])
            precision=precision_score(label.numpy(), preds.T.numpy()[0])
            f2=fbeta_score(label.numpy(), preds.T.numpy()[0], beta=2)

            # backward pass: compute gradient of the loss with respect to model parameters
            loss.backward()
            # perform a single optimization step (parameter update)
            optimizer.step()
            # update running training loss

            #loss.item(): retourne la valeur numérique de la loss transférée au CPU
            #loss.item() retourne la loss moyenne sur le mini-batch, d'où la multiplication
            #par data.size(0)
            train_loss += loss.item() * data.size(0)
            train_f1+=f1
            train_accuracy+=accuracy
            train_recall+=recall
            train_precision+=precision
            train_f2+=f2

        # print training/validation statistics 
        # calculate average loss over an epoch
        train_loss = train_loss / len(train_loader.sampler) 
        train_f1=train_f1/iter_train
        train_accuracy=train_accuracy/iter_train
        train_recall=train_recall/iter_train
        train_precision=train_precision/iter_train
        train_f2=train_f2/iter_train


        train_losses.append(train_loss)
        train_f1s.append(train_f1)
        train_accuracys.append(train_accuracy)
        train_recalls.append(train_recall)
        train_precisions.append(train_precision)
        train_f2s.append(train_f2)

        model.eval()

        for data,label in valid_loader:
            iter_val+=1

            # Pour utiliser GPU

            # inputs = inputs.to(device)
            # labels = labels.to(device)
            # model.to(device)

            with torch.no_grad():
                output = model(data)
                
            output_detach = output.detach()

            # calculate the loss
            preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
            for i in range(len(output_detach)):
                if sig(output_detach[i])>0.5:
                    preds[i]=1
                else: preds[i]=0
            
            loss = criterion(output,label.unsqueeze(1).float())
            f1 = f1_score(label.numpy(), preds.T.numpy()[0])
            accuracy= accuracy_score(label.numpy(), preds.T.numpy()[0])
            recall= recall_score(label.numpy(), preds.T.numpy()[0])
            precision= precision_score(label.numpy(), preds.T.numpy()[0])
            f2=fbeta_score(label.numpy(), preds.T.numpy()[0], beta=2)

            # update running validation loss 
            valid_loss+=loss.item() * data.size(0)
            valid_f1+=f1
            valid_accuracy+=accuracy
            valid_recall+=recall
            valid_precision+=precision
            valid_f2+=f2

        valid_loss=valid_loss/len(valid_loader.sampler)
        valid_f1=valid_f1/iter_val
        valid_accuracy=valid_accuracy/iter_val
        valid_recall=valid_recall/iter_val
        valid_precision=valid_precision/iter_val
        valid_f2=valid_f2/iter_val

        val_losses.append(valid_loss)
        val_f1s.append(valid_f1)
        val_accuracys.append(valid_accuracy)
        val_recalls.append(valid_recall)
        val_precisions.append(valid_precision)
        val_f2s.append(valid_f2)



        print('Epoch: {} \tTraining Loss: {:.6f} \tTraining F1-score: {:.6f} \tTraining accuracy: {:.6f} \tTraining recall: {:.6f} \tTraining precision: {:.6f} \tTraining F2-score: {:.6f} \tValidation Loss: {:.6f} \tValidation F1-score: {:.6f} \tValidation accuracy: {:.6f} \tValidation recall: {:.6f} \tValidation precision: {:.6f} \tValidation F2-score: {:.6f}'.format(
            epoch+1, 
            train_loss,
            train_f1,
            train_accuracy,
            train_recall,
            train_precision,
            train_f2,
            valid_loss,
            valid_f1,
            valid_accuracy,
            valid_recall,
            valid_precision,
            valid_f2
            ))
        
    torch.save(model.state_dict(), os.path.join(path_save_model,"trained_resnet18_v3.pth"))

    return train_losses, train_f1s, train_accuracys, train_recalls, train_precisions, train_f2s, val_losses, val_f1s, val_accuracys, val_recalls, val_precisions, val_f2s


def eval_model(model, path_model, valid_loader, criterion, n_epochs, device=None):
    """Pour voir les performances du modèle entraîné sur l'échantillon de validation
       /!\ certains commentaires sont à passer en code pour passer sur GPU

    """
    ######################    
    # validate the model #
    ######################
    valid_loss_min = np.Inf  # set initial "min" to infinity
    val_losses= []
    val_f1s=[]
    val_accuracys=[]
    val_recalls=[]
    val_precisions=[]
    val_f2s=[]

    model.load_state_dict(torch.load(path_model))
    model.eval()  # prep model for evaluation

    #model.to(device)

    for epoch in range(n_epochs):
        valid_loss=0
        valid_f1=0
        valid_accuracy=0
        valid_recall=0
        valid_precision=0
        valid_f2=0
        iter=0
        for data,label in valid_loader:

            # Pour utiliser GPU

            # inputs = inputs.to(device)
            # labels = labels.to(device)
            # model.to(device)

            with torch.no_grad():
                output = model(data)
                
            output_detach = output.detach()

            # calculate the loss
            preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
            for i in range(len(output_detach)):
                if sig(output_detach[i])>0.5:
                    preds[i]=1
                else: preds[i]=0
            
            loss = criterion(output,label.unsqueeze(1).float())
            f1 = f1_score(label.numpy(), preds.T.numpy()[0])
            accuracy= accuracy_score(label.numpy(), preds.T.numpy()[0])
            recall= recall_score(label.numpy(), preds.T.numpy()[0])
            precision= precision_score(label.numpy(), preds.T.numpy()[0])
            f2=fbeta_score(label.numpy(), preds.T.numpy()[0], beta=2)

            # update running validation loss 
            valid_loss+=loss.item() * data.size(0)
            valid_f1+=f1
            valid_accuracy+=accuracy
            valid_recall+=recall
            valid_precision+=precision
            valid_f2+=f2
            iter+=1

        valid_loss=valid_loss/len(valid_loader.sampler)
        valid_f1=valid_f1/iter
        valid_accuracy=valid_accuracy/iter
        valid_recall=valid_recall/iter
        valid_precision=valid_precision/iter
        valid_f2=valid_f2/iter

        val_losses.append(valid_loss)
        val_f1s.append(valid_f1)
        val_accuracys.append(valid_accuracy)
        val_recalls.append(valid_recall)
        val_precisions.append(valid_precision)
        val_f2s.append(valid_f2)

        print('Epoch: {} \tValidation Loss: {:.6f} \tValidation F1-score: {:.6f} \tValidation accuracy: {:.6f} \tValidation recall: {:.6f} \tValidation precision: {:.6f} \tValidation F2-score: {:.6f}'.format(
            epoch+1,
            valid_loss,
            valid_f1,
            valid_accuracy,
            valid_recall,
            valid_precision,
            valid_f2
            ))
        
    return val_losses, val_f1s, val_accuracys, val_recalls, val_precisions, val_f2s


def predict(model, path_model, valid_loader, device=None):
    """Pour prédire 0/1 à partir de l'échantillon de validation
       /!\ certains commentaires sont à passer en code pour passer sur GPU

    """
    model.load_state_dict(torch.load(path_model))
    model.eval()

    array_labels=np.array([])
    array_preds=np.array([])
    probas_pred=np.array([])

    for data,label in valid_loader:
        # Pour utiliser GPU

        # inputs = inputs.to(device)
        # labels = labels.to(device)
        # model.to(device)

        with torch.no_grad():
            output = model(data)
        output_detach = output.detach()

        # calculate the loss
        preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
        probas=torch.zeros(output_detach.shape[0], output_detach.shape[1])

        for i in range(len(output_detach)):
            if sig(output_detach[i])>0.5:
                preds[i]=1
            else: preds[i]=0
            probas[i]=sig(output_detach[i])
        probas_pred=np.append(probas_pred, probas.T.numpy()[0])
        array_preds=np.append(array_preds,preds.T.numpy()[0])
        array_labels=np.append(array_labels, label.numpy())

    return array_labels, array_preds, probas_pred

# %%
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
loss=nn.BCEWithLogitsLoss()
# Train model
train_losses, train_f1s, train_accuracys, train_recalls, train_precisions, train_f2s, val_losses, val_f1s, val_accuracys, val_recalls, val_precisions, val_f2s = train_model(model=resnet18, 
                                                                                 train_loader=train_dataloader_augmente,
                                                                                 valid_loader=test_dataloader_augmente, 
                                                                                 criterion=loss, 
                                                                                 n_epochs=40, 
                                                                                 path_save_model="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps",
                                                                                 device=None)
# Out:
# 	 fc.weight
# 	 fc.bias
# Epoch: 1 	Training Loss: 1.675055 	Training F1-score: 0.793460 	Training accuracy: 0.782099 	Training recall: 0.803803 	Training precision: 0.796515 	Training F2-score: 0.797933 	Validation Loss: 1.518585 	Validation F1-score: 0.783725 	Validation accuracy: 0.763769 	Validation recall: 0.824740 	Validation precision: 0.758148 	Validation F2-score: 0.805836
# Epoch: 2 	Training Loss: 1.045718 	Training F1-score: 0.797458 	Training accuracy: 0.787268 	Training recall: 0.805312 	Training precision: 0.803967 	Training F2-score: 0.800319 	Validation Loss: 1.073080 	Validation F1-score: 0.758031 	Validation accuracy: 0.755919 	Validation recall: 0.736686 	Validation precision: 0.791571 	Validation F2-score: 0.743951
# Epoch: 3 	Training Loss: 0.754189 	Training F1-score: 0.803466 	Training accuracy: 0.793168 	Training recall: 0.812928 	Training precision: 0.808879 	Training F2-score: 0.807252 	Validation Loss: 0.864158 	Validation F1-score: 0.795550 	Validation accuracy: 0.767942 	Validation recall: 0.860370 	Validation precision: 0.747525 	Validation F2-score: 0.831900
# Epoch: 4 	Training Loss: 0.602913 	Training F1-score: 0.804853 	Training accuracy: 0.794652 	Training recall: 0.815604 	Training precision: 0.808808 	Training F2-score: 0.809311 	Validation Loss: 0.725933 	Validation F1-score: 0.795305 	Validation accuracy: 0.764462 	Validation recall: 0.876756 	Validation precision: 0.734950 	Validation F2-score: 0.840858
# Epoch: 5 	Training Loss: 0.516192 	Training F1-score: 0.809204 	Training accuracy: 0.798643 	Training recall: 0.821681 	Training precision: 0.811294 	Training F2-score: 0.814801 	Validation Loss: 0.586728 	Validation F1-score: 0.771640 	Validation accuracy: 0.764969 	Validation recall: 0.764083 	Validation precision: 0.790729 	Validation F2-score: 0.765840
# Epoch: 6 	Training Loss: 0.475591 	Training F1-score: 0.810968 	Training accuracy: 0.800520 	Training recall: 0.823956 	Training precision: 0.813035 	Training F2-score: 0.816776 	Validation Loss: 0.532099 	Validation F1-score: 0.783888 	Validation accuracy: 0.769491 	Validation recall: 0.796355 	Validation precision: 0.781453 	Validation F2-score: 0.790088
# Epoch: 7 	Training Loss: 0.451788 	Training F1-score: 0.809914 	Training accuracy: 0.798466 	Training recall: 0.825302 	Training precision: 0.809550 	Training F2-score: 0.817175 	Validation Loss: 0.514053 	Validation F1-score: 0.800731 	Validation accuracy: 0.775990 	Validation recall: 0.860848 	Validation precision: 0.756991 	Validation F2-score: 0.834311
# Epoch: 8 	Training Loss: 0.430517 	Training F1-score: 0.816533 	Training accuracy: 0.805826 	Training recall: 0.832498 	Training precision: 0.816378 	Training F2-score: 0.824056 	Validation Loss: 0.495470 	Validation F1-score: 0.796300 	Validation accuracy: 0.777894 	Validation recall: 0.831602 	Validation precision: 0.771221 	Validation F2-score: 0.815995
# Epoch: 9 	Training Loss: 0.421243 	Training F1-score: 0.818687 	Training accuracy: 0.807746 	Training recall: 0.838391 	Training precision: 0.813614 	Training F2-score: 0.828486 	Validation Loss: 0.508881 	Validation F1-score: 0.805421 	Validation accuracy: 0.771958 	Validation recall: 0.898779 	Validation precision: 0.736339 	Validation F2-score: 0.857616
# Epoch: 10 	Training Loss: 0.417387 	Training F1-score: 0.820955 	Training accuracy: 0.809876 	Training recall: 0.840049 	Training precision: 0.817907 	Training F2-score: 0.830282 	Validation Loss: 0.477977 	Validation F1-score: 0.799656 	Validation accuracy: 0.778772 	Validation recall: 0.846639 	Validation precision: 0.765235 	Validation F2-score: 0.825966
# Epoch: 11 	Training Loss: 0.419906 	Training F1-score: 0.819111 	Training accuracy: 0.807790 	Training recall: 0.839039 	Training precision: 0.815414 	Training F2-score: 0.828866 	Validation Loss: 0.473448 	Validation F1-score: 0.804673 	Validation accuracy: 0.783852 	Validation recall: 0.850130 	Validation precision: 0.771990 	Validation F2-score: 0.830103
# Epoch: 12 	Training Loss: 0.416153 	Training F1-score: 0.819493 	Training accuracy: 0.807170 	Training recall: 0.840868 	Training precision: 0.812830 	Training F2-score: 0.830337 	Validation Loss: 0.466918 	Validation F1-score: 0.795690 	Validation accuracy: 0.780692 	Validation recall: 0.822541 	Validation precision: 0.780161 	Validation F2-score: 0.810205
# Epoch: 13 	Training Loss: 0.416735 	Training F1-score: 0.816987 	Training accuracy: 0.805381 	Training recall: 0.836691 	Training precision: 0.813564 	Training F2-score: 0.826646 	Validation Loss: 0.474479 	Validation F1-score: 0.806137 	Validation accuracy: 0.779994 	Validation recall: 0.874950 	Validation precision: 0.754987 	Validation F2-score: 0.844664
# Epoch: 14 	Training Loss: 0.413418 	Training F1-score: 0.821984 	Training accuracy: 0.810769 	Training recall: 0.842192 	Training precision: 0.815900 	Training F2-score: 0.832197 	Validation Loss: 0.505606 	Validation F1-score: 0.806962 	Validation accuracy: 0.769345 	Validation recall: 0.918465 	Validation precision: 0.725406 	Validation F2-score: 0.869040
# Epoch: 15 	Training Loss: 0.414205 	Training F1-score: 0.820154 	Training accuracy: 0.808734 	Training recall: 0.838888 	Training precision: 0.816609 	Training F2-score: 0.829382 	Validation Loss: 0.463969 	Validation F1-score: 0.798672 	Validation accuracy: 0.781560 	Validation recall: 0.828664 	Validation precision: 0.780091 	Validation F2-score: 0.815089
# Epoch: 16 	Training Loss: 0.414960 	Training F1-score: 0.820607 	Training accuracy: 0.809361 	Training recall: 0.840385 	Training precision: 0.815452 	Training F2-score: 0.830514 	Validation Loss: 0.465921 	Validation F1-score: 0.806126 	Validation accuracy: 0.783120 	Validation recall: 0.862280 	Validation precision: 0.764509 	Validation F2-score: 0.837685
# Epoch: 17 	Training Loss: 0.413722 	Training F1-score: 0.822085 	Training accuracy: 0.810995 	Training recall: 0.842210 	Training precision: 0.818992 	Training F2-score: 0.831863 	Validation Loss: 0.477621 	Validation F1-score: 0.808222 	Validation accuracy: 0.779285 	Validation recall: 0.891727 	Validation precision: 0.745997 	Validation F2-score: 0.854988
# Epoch: 18 	Training Loss: 0.418173 	Training F1-score: 0.816742 	Training accuracy: 0.805187 	Training recall: 0.838241 	Training precision: 0.813271 	Training F2-score: 0.827165 	Validation Loss: 0.464546 	Validation F1-score: 0.807628 	Validation accuracy: 0.782782 	Validation recall: 0.876212 	Validation precision: 0.757545 	Validation F2-score: 0.845891
# Epoch: 19 	Training Loss: 0.418645 	Training F1-score: 0.819419 	Training accuracy: 0.808008 	Training recall: 0.841111 	Training precision: 0.815940 	Training F2-score: 0.829991 	Validation Loss: 0.466562 	Validation F1-score: 0.807750 	Validation accuracy: 0.781886 	Validation recall: 0.880800 	Validation precision: 0.752389 	Validation F2-score: 0.848885
# Epoch: 20 	Training Loss: 0.414806 	Training F1-score: 0.820803 	Training accuracy: 0.808979 	Training recall: 0.841313 	Training precision: 0.816783 	Training F2-score: 0.830900 	Validation Loss: 0.492299 	Validation F1-score: 0.811151 	Validation accuracy: 0.776305 	Validation recall: 0.917180 	Validation precision: 0.733080 	Validation F2-score: 0.870379
# Epoch: 21 	Training Loss: 0.414088 	Training F1-score: 0.820949 	Training accuracy: 0.808805 	Training recall: 0.842223 	Training precision: 0.815596 	Training F2-score: 0.831518 	Validation Loss: 0.477292 	Validation F1-score: 0.806927 	Validation accuracy: 0.777359 	Validation recall: 0.892686 	Validation precision: 0.742993 	Validation F2-score: 0.854987
# Epoch: 22 	Training Loss: 0.415550 	Training F1-score: 0.818943 	Training accuracy: 0.807056 	Training recall: 0.840447 	Training precision: 0.814525 	Training F2-score: 0.829541 	Validation Loss: 0.461475 	Validation F1-score: 0.791974 	Validation accuracy: 0.779989 	Validation recall: 0.807423 	Validation precision: 0.787189 	Validation F2-score: 0.799833
# Epoch: 23 	Training Loss: 0.411880 	Training F1-score: 0.820567 	Training accuracy: 0.809107 	Training recall: 0.840112 	Training precision: 0.816343 	Training F2-score: 0.830288 	Validation Loss: 0.464874 	Validation F1-score: 0.801706 	Validation accuracy: 0.777894 	Validation recall: 0.859984 	Validation precision: 0.757810 	Validation F2-score: 0.834584
# Epoch: 24 	Training Loss: 0.417004 	Training F1-score: 0.821517 	Training accuracy: 0.809773 	Training recall: 0.842667 	Training precision: 0.818407 	Training F2-score: 0.831836 	Validation Loss: 0.461923 	Validation F1-score: 0.800777 	Validation accuracy: 0.779977 	Validation recall: 0.850197 	Validation precision: 0.765351 	Validation F2-score: 0.828299
# Epoch: 25 	Training Loss: 0.413401 	Training F1-score: 0.820365 	Training accuracy: 0.809257 	Training recall: 0.842182 	Training precision: 0.814805 	Training F2-score: 0.831195 	Validation Loss: 0.470388 	Validation F1-score: 0.810463 	Validation accuracy: 0.781346 	Validation recall: 0.893340 	Validation precision: 0.747772 	Validation F2-score: 0.857043
# Epoch: 26 	Training Loss: 0.417846 	Training F1-score: 0.818526 	Training accuracy: 0.807135 	Training recall: 0.840371 	Training precision: 0.814769 	Training F2-score: 0.829220 	Validation Loss: 0.465883 	Validation F1-score: 0.791364 	Validation accuracy: 0.780873 	Validation recall: 0.800100 	Validation precision: 0.790973 	Validation F2-score: 0.795582
# Epoch: 27 	Training Loss: 0.415614 	Training F1-score: 0.818524 	Training accuracy: 0.807710 	Training recall: 0.839781 	Training precision: 0.814515 	Training F2-score: 0.828903 	Validation Loss: 0.468817 	Validation F1-score: 0.812452 	Validation accuracy: 0.783503 	Validation recall: 0.892978 	Validation precision: 0.752011 	Validation F2-score: 0.857706
# Epoch: 28 	Training Loss: 0.414570 	Training F1-score: 0.820299 	Training accuracy: 0.809151 	Training recall: 0.843322 	Training precision: 0.813788 	Training F2-score: 0.831850 	Validation Loss: 0.491108 	Validation F1-score: 0.810053 	Validation accuracy: 0.774408 	Validation recall: 0.919544 	Validation precision: 0.731184 	Validation F2-score: 0.870771
# Epoch: 29 	Training Loss: 0.413093 	Training F1-score: 0.821266 	Training accuracy: 0.809615 	Training recall: 0.841630 	Training precision: 0.816713 	Training F2-score: 0.831341 	Validation Loss: 0.491937 	Validation F1-score: 0.807440 	Validation accuracy: 0.774396 	Validation recall: 0.911555 	Validation precision: 0.732107 	Validation F2-score: 0.865234
# Epoch: 30 	Training Loss: 0.414174 	Training F1-score: 0.820138 	Training accuracy: 0.809020 	Training recall: 0.842848 	Training precision: 0.814679 	Training F2-score: 0.831380 	Validation Loss: 0.468452 	Validation F1-score: 0.807924 	Validation accuracy: 0.780681 	Validation recall: 0.887071 	Validation precision: 0.750171 	Validation F2-score: 0.852022
# Epoch: 31 	Training Loss: 0.412168 	Training F1-score: 0.822034 	Training accuracy: 0.811099 	Training recall: 0.844235 	Training precision: 0.815523 	Training F2-score: 0.833274 	Validation Loss: 0.499523 	Validation F1-score: 0.811505 	Validation accuracy: 0.775303 	Validation recall: 0.925577 	Validation precision: 0.728616 	Validation F2-score: 0.874893
# Epoch: 32 	Training Loss: 0.409558 	Training F1-score: 0.823114 	Training accuracy: 0.811726 	Training recall: 0.844440 	Training precision: 0.816849 	Training F2-score: 0.833858 	Validation Loss: 0.471764 	Validation F1-score: 0.812386 	Validation accuracy: 0.781194 	Validation recall: 0.899513 	Validation precision: 0.747556 	Validation F2-score: 0.861201
# Epoch: 33 	Training Loss: 0.413668 	Training F1-score: 0.821995 	Training accuracy: 0.809939 	Training recall: 0.845172 	Training precision: 0.815359 	Training F2-score: 0.833623 	Validation Loss: 0.461107 	Validation F1-score: 0.809673 	Validation accuracy: 0.786082 	Validation recall: 0.873048 	Validation precision: 0.763152 	Validation F2-score: 0.845132
# Epoch: 34 	Training Loss: 0.419246 	Training F1-score: 0.817839 	Training accuracy: 0.805921 	Training recall: 0.841164 	Training precision: 0.811998 	Training F2-score: 0.829479 	Validation Loss: 0.473102 	Validation F1-score: 0.808974 	Validation accuracy: 0.779977 	Validation recall: 0.891106 	Validation precision: 0.747994 	Validation F2-score: 0.854938
# Epoch: 35 	Training Loss: 0.410144 	Training F1-score: 0.825391 	Training accuracy: 0.813586 	Training recall: 0.846229 	Training precision: 0.820191 	Training F2-score: 0.835833 	Validation Loss: 0.477750 	Validation F1-score: 0.807977 	Validation accuracy: 0.777201 	Validation recall: 0.893679 	Validation precision: 0.745408 	Validation F2-score: 0.855744
# Epoch: 36 	Training Loss: 0.411245 	Training F1-score: 0.821576 	Training accuracy: 0.809448 	Training recall: 0.843513 	Training precision: 0.815967 	Training F2-score: 0.832519 	Validation Loss: 0.461483 	Validation F1-score: 0.798807 	Validation accuracy: 0.786082 	Validation recall: 0.818757 	Validation precision: 0.787788 	Validation F2-score: 0.809569
# Epoch: 37 	Training Loss: 0.412823 	Training F1-score: 0.821047 	Training accuracy: 0.809265 	Training recall: 0.843158 	Training precision: 0.817663 	Training F2-score: 0.831874 	Validation Loss: 0.468189 	Validation F1-score: 0.810494 	Validation accuracy: 0.781205 	Validation recall: 0.885566 	Validation precision: 0.753435 	Validation F2-score: 0.852793
# Epoch: 38 	Training Loss: 0.412679 	Training F1-score: 0.821251 	Training accuracy: 0.809396 	Training recall: 0.842965 	Training precision: 0.816160 	Training F2-score: 0.832024 	Validation Loss: 0.459158 	Validation F1-score: 0.808196 	Validation accuracy: 0.784342 	Validation recall: 0.865501 	Validation precision: 0.765972 	Validation F2-score: 0.840260
# Epoch: 39 	Training Loss: 0.412815 	Training F1-score: 0.822215 	Training accuracy: 0.810853 	Training recall: 0.846538 	Training precision: 0.813814 	Training F2-score: 0.834622 	Validation Loss: 0.498647 	Validation F1-score: 0.810730 	Validation accuracy: 0.775275 	Validation recall: 0.926754 	Validation precision: 0.727388 	Validation F2-score: 0.875040
# Epoch: 40 	Training Loss: 0.409500 	Training F1-score: 0.819834 	Training accuracy: 0.808540 	Training recall: 0.840679 	Training precision: 0.814649 	Training F2-score: 0.830169 	Validation Loss: 0.510088 	Validation F1-score: 0.809918 	Validation accuracy: 0.769164 	Validation recall: 0.933387 	Validation precision: 0.719445 	Validation F2-score: 0.878757

# %%
dict_train_losses={}
dict_train_f1s={}
dict_train_accuracys={}
dict_train_recalls={}
dict_train_precisions={}
dict_train_f2s={}

dict_val_losses={}
dict_val_f1s={}
dict_val_accuracys={}
dict_val_recalls={}
dict_val_precisions={}
dict_val_f2s={}

for i in range(0,40):
    dict_train_losses[i+1]=train_losses[i]
    dict_train_f1s[i+1]=train_f1s[i]
    dict_train_accuracys[i+1]=train_accuracys[i]
    dict_train_recalls[i+1]=train_recalls[i]
    dict_train_precisions[i+1]=train_precisions[i]
    dict_train_f2s[i+1]=train_f2s[i]

    dict_val_losses[i+1]=val_losses[i]
    dict_val_f1s[i+1]=val_f1s[i]
    dict_val_accuracys[i+1]=val_accuracys[i]
    dict_val_recalls[i+1]=val_recalls[i]
    dict_val_precisions[i+1]=val_precisions[i]
    dict_val_f2s[i+1]=val_f2s[i]

sorted_train_losses = sorted(dict_train_losses.items())
sorted_train_f1s = sorted(dict_train_f1s.items())
sorted_train_accuracys = sorted(dict_train_accuracys.items())
sorted_train_recalls = sorted(dict_train_recalls.items())
sorted_train_precisions = sorted(dict_train_precisions.items())
sorted_train_f2s = sorted(dict_train_f2s.items())

sorted_val_losses = sorted(dict_val_losses.items())
sorted_val_f1s = sorted(dict_val_f1s.items())
sorted_val_accuracys = sorted(dict_val_accuracys.items())
sorted_val_recalls = sorted(dict_val_recalls.items())
sorted_val_precisions = sorted(dict_val_precisions.items())
sorted_val_f2s = sorted(dict_val_f2s.items())

epochs, loss_train = zip(*sorted_train_losses)
epochs, f1_train = zip(*sorted_train_f1s)
epochs, acc_train = zip(*sorted_train_accuracys)
epochs, recall_train = zip(*sorted_train_recalls)
epochs, precision_train =zip(*sorted_train_precisions)
epochs, f2_train = zip(*sorted_train_f2s)

epochs, loss_val = zip(*sorted_val_losses)
epochs, f1_val = zip(*sorted_val_f1s)
epochs, acc_val = zip(*sorted_val_accuracys)
epochs, recall_val = zip(*sorted_val_recalls)
epochs, precision_val =zip(*sorted_val_precisions)
epochs, f2_val = zip(*sorted_val_f2s)


fig, axs = plt.subplots(3, 2, figsize=(15, 15))

axs[0,0].plot(epochs, loss_train, 'b',label="Loss sur l'échantillon d'apprentissage", color="blue")
axs[0,0].plot(epochs, loss_val, 'b',label="Loss sur l'échantillon de validation", color="red")
axs[0,0].legend()

axs[0,1].plot(epochs, acc_train, 'b',label="Accuracy sur l'échantillon d'apprentissage", color="blue")
axs[0,1].plot(epochs, acc_val, 'b',label="Accuracy sur l'échantillon de validation", color="red")
axs[0,1].legend()

axs[1,0].plot(epochs, precision_train, 'b',label="Precision sur l'échantillon d'apprentissage", color="blue")
axs[1,0].plot(epochs, precision_val, 'b',label="Precision sur l'échantillon de validation", color="red")
axs[1,0].legend()

axs[1,1].plot(epochs, recall_train, 'b',label="Recall sur l'échantillon d'apprentissage", color="blue")
axs[1,1].plot(epochs, recall_val, 'b',label="Recall sur l'échantillon de validation", color="red")
axs[1,1].legend()

axs[2,0].plot(epochs, f1_train, 'b',label="F1-score sur l'échantillon d'apprentissage", color="blue")
axs[2,0].plot(epochs, f1_val, 'b',label="F1-score sur l'échantillon de validation", color="red")
axs[2,0].legend()

axs[2,1].plot(epochs, f2_train, 'b',label="F2-score sur l'échantillon d'apprentissage", color="blue")
axs[2,1].plot(epochs, f2_val, 'b',label="F2-score sur l'échantillon de validation", color="red")
axs[2,1].legend()

plt.savefig('courbes_loss_resnet18_transfertlearning.png')
plt.show()

# %%
y_true_train, y_pred_train, proba_pred_train=predict(model=resnet18, path_model="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps/trained_resnet18_v3.pth", valid_loader=train_dataloader_augmente, device=None)
y_true_val, y_pred_val, proba_pred_val=predict(model=resnet18, path_model="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps/trained_resnet18_v3.pth", valid_loader=test_dataloader_augmente, device=None)

# %%
print("Loss sur l'échantillon train: {}".format(round(log_loss(y_true_train, proba_pred_train),2)))
print("Accuracy sur l'échantillon train: {}".format(round(accuracy_score(y_true_train, y_pred_train),2)))
print("Recall sur l'échantillon train: {}".format(round(recall_score(y_true_train, y_pred_train),2)))
print("Precision sur l'échantillon train: {}".format(round(precision_score(y_true_train, y_pred_train),2)))
print("F1-score sur l'échantillon train: {}".format(round(f1_score(y_true_train, y_pred_train),2)))
print("F2-score sur l'échantillon train: {} \n".format(round(fbeta_score(y_true_train, y_pred_train, beta=2),2)))

print("Loss sur l'échantillon test: {}".format(round(log_loss(y_true_val, proba_pred_val),2)))
print("Accuracy sur l'échantillon test: {}".format(round(accuracy_score(y_true_val, y_pred_val),2)))
print("Recall sur l'échantillon test: {}".format(round(recall_score(y_true_val, y_pred_val),2)))
print("Precision sur l'échantillon test: {}".format(round(precision_score(y_true_val, y_pred_val),2)))
print("F1-score sur l'échantillon test: {}".format(round(f1_score(y_true_val, y_pred_val),2)))
print("F2-score sur l'échantillon test: {}".format(round(fbeta_score(y_true_val, y_pred_val, beta=2),2)))

FP_rate, TP_rate, thresholds_keras = roc_curve(y_true_val, proba_pred_val)
AUC= auc(FP_rate, TP_rate)
print("AUC: {}".format(round(AUC, 2)))

plt.title('Courbe ROC:  ResNet-18 transfert learning')
plt.plot(FP_rate, TP_rate, label="AUC="+str(round(AUC, 2)))
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0], c=".7"), plt.plot([1, 1], c=".7")
plt.ylabel('Taux de vrais positifs')
plt.xlabel('Taux de faux positifs')
plt.legend(loc=4)
plt.savefig('ROC_resnet18_transfertlearning.png')
plt.show()

prec, rec, thresholds_keras = precision_recall_curve(y_true_val, proba_pred_val)

fig, ax = plt.subplots()
ax.plot(rec, prec)

#add axis labels to plot
ax.set_title('Courbe Precision-Recall: ResNet 18 transfert learning')
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')

#display plot
plt.savefig('prec_recall_resnet18_transfertlearning.png')
plt.show()

r = confusion_matrix(y_true_val, y_pred_val)

labels = ["Vrais négatifs", "Faux Positifs", "Faux négatifs", "Vrais positifs"]
categories = ["0", "1"]
make_confusion_matrix(r,
                      group_names=labels,
                      categories=categories,
                      )
# Out:
# Loss sur l'échantillon train: 0.42
# Accuracy sur l'échantillon train: 0.8
# Recall sur l'échantillon train: 0.93
# Precision sur l'échantillon train: 0.75
# F1-score sur l'échantillon train: 0.83
# F2-score sur l'échantillon train: 0.89
#
# Loss sur l'échantillon test: 0.51
# Accuracy sur l'échantillon test: 0.77
# Recall sur l'échantillon test: 0.93
# Precision sur l'échantillon test: 0.72
# F1-score sur l'échantillon test: 0.81
# F2-score sur l'échantillon test: 0.88
# AUC: 0.86

# %% [markdown]
# # Visualisation TSNE

# %%
test_dataset_tsne = CustomImageDataset_path(path_test,"C:/Users/yanis/OneDrive/Documents/Projet Stat/Données/bdappv/google2/img/",
                                            transform=transforms.Compose([
                                               transforms.Resize(224),
                                               transforms.ToTensor(),
                                               transforms.Normalize(mean = [0.34332898259162903, 0.35128462314605713, 0.30205702781677246],
                                                                    std= [0.1959962248802185, 0.17875953018665314, 0.17301008105278015]),
                                           ]))

test_dataloader_tsne = DataLoader(test_dataset_tsne, batch_size=32, shuffle=True)

# %%
def embedding(data):
    resnet18.eval()
    out = resnet18.conv1(data) #pass through CNN
    out= resnet18.bn1(out)
    out=resnet18.relu(out)
    out=resnet18.maxpool(out)
    out=resnet18.layer1(out)
    out=resnet18.layer2(out)
    out=resnet18.layer3(out)
    out=resnet18.layer4(out)
    out=torch.flatten(out, 1)
    return out

# %%
features = None
labels = None
image_paths = None

for data in test_dataloader_tsne:
    inputs=data[0]
    targets=data[1]
    paths=data[2]
    
    output = embedding(inputs)
    current_features = output.detach().numpy()
    if features is not None:
        features = np.concatenate((features, current_features))
    else:
        features = current_features

    if labels is not None:
        labels = np.concatenate((labels, targets))
    else:
        labels = targets
    
    if image_paths is not None:
        image_paths = np.concatenate((image_paths, paths))
    else:
        image_paths = paths

# %%
import itertools
fig, ax = plt.subplots(1, 3, figsize=(20,7), constrained_layout=True)

for c, per in zip(itertools.count(), [5, 30, 50]):
    tsne = TSNE(n_components=2,
                perplexity=per)
    tsne = tsne.fit_transform(features)
    scatter = ax[c].scatter(tsne[:, 0], tsne[:, 1], c=labels, cmap=matplotlib.colors.ListedColormap(["red", "blue"]), s=0.3)
    ax[c].set_title(f'Perplexity: {per}', fontsize=16)

# %%
tsne = TSNE(n_components=2, perplexity=30).fit_transform(features)
visualize_tsne(tsne, image_paths, labels)
# Out:
# Building the T-SNE plot: 100%|██████████| 5727/5727 [00:39<00:00, 144.48it/s]
