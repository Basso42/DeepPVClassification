# %% [markdown]
# # Préparation des données

# %% [markdown]
# ## Import et data augmentations

# %%
from  src.dataloader import *
from src.metrics import *
from src.resnet18 import *
from src.confusion_matrix import make_confusion_matrix
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from torchvision import transforms, datasets
import torch.nn as nn
import tensorflow as tf
from sklearn.metrics import fbeta_score, make_scorer, f1_score, accuracy_score, recall_score, precision_score, fbeta_score, precision_recall_curve, auc, roc_curve, log_loss, confusion_matrix
import torchvision.models as models
import os
from src.tsne import *
from torch.utils.data import DataLoader
import matplotlib
import torchvision.models as models
from sklearn.manifold import TSNE

# %%
np.random.seed(123)
path_train="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps/train_data.csv"
path_test="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps/test_data.csv"

transformed_train_dataset  = CustomImageDataset(path_train,"C:/Users/yanis/OneDrive/Documents/Projet Stat/Données/bdappv/google2/img/", transform=transforms.Compose([
                                               transforms.Resize(224),
                                               transforms.RandomCrop(190), #On garde environ 75% de l'image
                                               transforms.ColorJitter(brightness=(0.5,1.5),contrast=0,saturation=0,hue=0),                                               transforms.RandomCrop(160),
                                               transforms.Resize(224),
                                               transforms.ToTensor(),
                                               transforms.Normalize(mean = [0.34672418236732483, 0.354153573513031, 0.3043244183063507],
                                                                    std= [0.19679038226604462, 0.17956718802452087, 0.17369826138019562]),

                                           ]))

transformed_test_dataset = CustomImageDataset(path_test,"C:/Users/yanis/OneDrive/Documents/Projet Stat/Données/bdappv/google2/img/",
                                            transform=transforms.Compose([
                                               transforms.Resize(224),
                                               transforms.ToTensor(),
                                               transforms.Normalize(mean = [0.34332898259162903, 0.35128462314605713, 0.30205702781677246],
                                                                    std= [0.1959962248802185, 0.17875953018665314, 0.17301008105278015]),
                                           ]))

train_dataloader_augmente = DataLoader(transformed_train_dataset, batch_size=32, shuffle=True)
test_dataloader_augmente = DataLoader(transformed_test_dataset, batch_size=32, shuffle=True)

print(len(train_dataloader_augmente))
batch = next(iter(train_dataloader_augmente))
print(batch[0].shape)
plt.imshow(batch[0][0].permute(1, 2, 0))
print(batch[1][0])
# Out:
# 716
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([32, 3, 224, 224])
# tensor(1)

# %%
# mean_train, std_train = mean_std(train_dataloader_augmente)
# print("Moyenne par channel: {}".format(mean_train.tolist()))
# print("Ecart-type par channel: {}".format(std_train.tolist()))

# mean_test, std_test = mean_std(test_dataloader_augmente)
# print("Moyenne par channel: {}".format(mean_test.tolist()))
# print("Ecart-type par channel: {}".format(std_test.tolist()))
# Out:
# Moyenne par channel: [0.34672418236732483, 0.354153573513031, 0.3043244183063507]
# Ecart-type par channel: [0.19679038226604462, 0.17956718802452087, 0.17369826138019562]
# Moyenne par channel: [0.34332898259162903, 0.35128462314605713, 0.30205702781677246]
# Ecart-type par channel: [0.1959962248802185, 0.17875953018665314, 0.17301008105278015]

# %% [markdown]
# # Import du modèle

# %%
resnet18 = models.resnet18(pretrained=True)

#Furthermore, in feature extracting, we don't need to calculate gradient for any layers except 
# the last layer that we initialize. For this we need to set .requires_grad to False
def set_parameter_requires_grad(model, feature_extracting=True):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False
            
set_parameter_requires_grad(resnet18)


nr_filters = resnet18.fc.in_features  #number of input features of last layer
#On ne met pas de sigmoid dans la dernière couche. C'est composé par la loss BCEWithLogitsLoss qui applique une sigmoid afin de calculer la cross-enthropy
resnet18.fc = nn.Linear(nr_filters, 1)

# %%
def sig(x):
    return 1/(1 + np.exp(-x))

def train_model(model, train_loader, valid_loader, criterion, n_epochs, path_save_model, device=None):
    """Pour entrainer le modèle 
    /!\ certains commentaires sont à passer en code pour passer sur GPU
    """
    # number of epochs to train the model

    train_losses= []
    train_f1s=[]
    train_accuracys=[]
    train_recalls=[]
    train_precisions=[]
    train_f2s=[]

    valid_loss_min = np.Inf  # set initial "min" to infinity
    val_losses= []
    val_f1s=[]
    val_accuracys=[]
    val_recalls=[]
    val_precisions=[]
    val_f2s=[]

    # Here we only want to update the gradient for the classifier layer that we initialized.
    params_to_update = []
    for name,param in model.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            print("\t",name)

    optimizer=torch.optim.SGD(params_to_update, lr = 0.01, momentum=0.9, weight_decay=1e-4)
    
    for epoch in range(n_epochs):

        # monitor losses
        train_loss = 0
        train_f1=0
        train_accuracy=0
        train_recall=0
        train_precision=0
        train_f2=0

        valid_loss=0
        valid_f1=0
        valid_accuracy=0
        valid_recall=0
        valid_precision=0
        valid_f2=0

        iter_train=0
        iter_val=0
        ###################
        # train the model #
        ###################
        model.train() # prep model for training

        for data,label in train_loader:
            iter_train+=1

            # Pour utiliser GPU

            # inputs = inputs.to(device)
            # labels = labels.to(device)
            # model.to(device)

            # clear the gradients of all optimized variables
            optimizer.zero_grad()
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            output_detach = output.detach()

            # calculate the loss
            preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
            for i in range(len(output_detach)):
                if sig(output_detach[i])>0.5:
                    preds[i]=1
                else: preds[i]=0

            loss = criterion(output,label.unsqueeze(1).float()) #loss sur le batch i.e 1/32*sum...
            f1 = f1_score(label.numpy(), preds.T.numpy()[0])
            accuracy= accuracy_score(label.numpy(), preds.T.numpy()[0])
            recall= recall_score(label.numpy(), preds.T.numpy()[0])
            precision=precision_score(label.numpy(), preds.T.numpy()[0])
            f2=fbeta_score(label.numpy(), preds.T.numpy()[0], beta=2)

            # backward pass: compute gradient of the loss with respect to model parameters
            loss.backward()
            # perform a single optimization step (parameter update)
            optimizer.step()
            # update running training loss

            #loss.item(): retourne la valeur numérique de la loss transférée au CPU
            #loss.item() retourne la loss moyenne sur le mini-batch, d'où la multiplication
            #par data.size(0)
            train_loss += loss.item() * data.size(0)
            train_f1+=f1
            train_accuracy+=accuracy
            train_recall+=recall
            train_precision+=precision
            train_f2+=f2

        # print training/validation statistics 
        # calculate average loss over an epoch
        train_loss = train_loss / len(train_loader.sampler) 
        train_f1=train_f1/iter_train
        train_accuracy=train_accuracy/iter_train
        train_recall=train_recall/iter_train
        train_precision=train_precision/iter_train
        train_f2=train_f2/iter_train


        train_losses.append(train_loss)
        train_f1s.append(train_f1)
        train_accuracys.append(train_accuracy)
        train_recalls.append(train_recall)
        train_precisions.append(train_precision)
        train_f2s.append(train_f2)

        model.eval()

        for data,label in valid_loader:
            iter_val+=1

            # Pour utiliser GPU

            # inputs = inputs.to(device)
            # labels = labels.to(device)
            # model.to(device)

            with torch.no_grad():
                output = model(data)
                
            output_detach = output.detach()

            # calculate the loss
            preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
            for i in range(len(output_detach)):
                if sig(output_detach[i])>0.5:
                    preds[i]=1
                else: preds[i]=0
            
            loss = criterion(output,label.unsqueeze(1).float())
            f1 = f1_score(label.numpy(), preds.T.numpy()[0])
            accuracy= accuracy_score(label.numpy(), preds.T.numpy()[0])
            recall= recall_score(label.numpy(), preds.T.numpy()[0])
            precision= precision_score(label.numpy(), preds.T.numpy()[0])
            f2=fbeta_score(label.numpy(), preds.T.numpy()[0], beta=2)

            # update running validation loss 
            valid_loss+=loss.item() * data.size(0)
            valid_f1+=f1
            valid_accuracy+=accuracy
            valid_recall+=recall
            valid_precision+=precision
            valid_f2+=f2

        valid_loss=valid_loss/len(valid_loader.sampler)
        valid_f1=valid_f1/iter_val
        valid_accuracy=valid_accuracy/iter_val
        valid_recall=valid_recall/iter_val
        valid_precision=valid_precision/iter_val
        valid_f2=valid_f2/iter_val

        val_losses.append(valid_loss)
        val_f1s.append(valid_f1)
        val_accuracys.append(valid_accuracy)
        val_recalls.append(valid_recall)
        val_precisions.append(valid_precision)
        val_f2s.append(valid_f2)



        print('Epoch: {} \tTraining Loss: {:.6f} \tTraining F1-score: {:.6f} \tTraining accuracy: {:.6f} \tTraining recall: {:.6f} \tTraining precision: {:.6f} \tTraining F2-score: {:.6f} \tValidation Loss: {:.6f} \tValidation F1-score: {:.6f} \tValidation accuracy: {:.6f} \tValidation recall: {:.6f} \tValidation precision: {:.6f} \tValidation F2-score: {:.6f}'.format(
            epoch+1, 
            train_loss,
            train_f1,
            train_accuracy,
            train_recall,
            train_precision,
            train_f2,
            valid_loss,
            valid_f1,
            valid_accuracy,
            valid_recall,
            valid_precision,
            valid_f2
            ))
        
    torch.save(model.state_dict(), os.path.join(path_save_model,"trained_resnet18_v2.pth"))

    return train_losses, train_f1s, train_accuracys, train_recalls, train_precisions, train_f2s, val_losses, val_f1s, val_accuracys, val_recalls, val_precisions, val_f2s


def eval_model(model, path_model, valid_loader, criterion, n_epochs, device=None):
    """Pour voir les performances du modèle entraîné sur l'échantillon de validation
       /!\ certains commentaires sont à passer en code pour passer sur GPU

    """
    ######################    
    # validate the model #
    ######################
    valid_loss_min = np.Inf  # set initial "min" to infinity
    val_losses= []
    val_f1s=[]
    val_accuracys=[]
    val_recalls=[]
    val_precisions=[]
    val_f2s=[]

    model.load_state_dict(torch.load(path_model))
    model.eval()  # prep model for evaluation

    #model.to(device)

    for epoch in range(n_epochs):
        valid_loss=0
        valid_f1=0
        valid_accuracy=0
        valid_recall=0
        valid_precision=0
        valid_f2=0
        iter=0
        for data,label in valid_loader:

            # Pour utiliser GPU

            # inputs = inputs.to(device)
            # labels = labels.to(device)
            # model.to(device)

            with torch.no_grad():
                output = model(data)
                
            output_detach = output.detach()

            # calculate the loss
            preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
            for i in range(len(output_detach)):
                if sig(output_detach[i])>0.5:
                    preds[i]=1
                else: preds[i]=0
            
            loss = criterion(output,label.unsqueeze(1).float())
            f1 = f1_score(label.numpy(), preds.T.numpy()[0])
            accuracy= accuracy_score(label.numpy(), preds.T.numpy()[0])
            recall= recall_score(label.numpy(), preds.T.numpy()[0])
            precision= precision_score(label.numpy(), preds.T.numpy()[0])
            f2=fbeta_score(label.numpy(), preds.T.numpy()[0], beta=2)

            # update running validation loss 
            valid_loss+=loss.item() * data.size(0)
            valid_f1+=f1
            valid_accuracy+=accuracy
            valid_recall+=recall
            valid_precision+=precision
            valid_f2+=f2
            iter+=1

        valid_loss=valid_loss/len(valid_loader.sampler)
        valid_f1=valid_f1/iter
        valid_accuracy=valid_accuracy/iter
        valid_recall=valid_recall/iter
        valid_precision=valid_precision/iter
        valid_f2=valid_f2/iter

        val_losses.append(valid_loss)
        val_f1s.append(valid_f1)
        val_accuracys.append(valid_accuracy)
        val_recalls.append(valid_recall)
        val_precisions.append(valid_precision)
        val_f2s.append(valid_f2)

        print('Epoch: {} \tValidation Loss: {:.6f} \tValidation F1-score: {:.6f} \tValidation accuracy: {:.6f} \tValidation recall: {:.6f} \tValidation precision: {:.6f} \tValidation F2-score: {:.6f}'.format(
            epoch+1,
            valid_loss,
            valid_f1,
            valid_accuracy,
            valid_recall,
            valid_precision,
            valid_f2
            ))
        
    return val_losses, val_f1s, val_accuracys, val_recalls, val_precisions, val_f2s


def predict(model, path_model, valid_loader, device=None):
    """Pour prédire 0/1 à partir de l'échantillon de validation
       /!\ certains commentaires sont à passer en code pour passer sur GPU

    """
    model.load_state_dict(torch.load(path_model))
    model.eval()

    array_labels=np.array([])
    array_preds=np.array([])
    probas_pred=np.array([])

    for data,label in valid_loader:
        # Pour utiliser GPU

        # inputs = inputs.to(device)
        # labels = labels.to(device)
        # model.to(device)

        with torch.no_grad():
            output = model(data)
        output_detach = output.detach()

        # calculate the loss
        preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
        probas=torch.zeros(output_detach.shape[0], output_detach.shape[1])

        for i in range(len(output_detach)):
            if sig(output_detach[i])>0.5:
                preds[i]=1
            else: preds[i]=0
            probas[i]=sig(output_detach[i])
        probas_pred=np.append(probas_pred, probas.T.numpy()[0])
        array_preds=np.append(array_preds,preds.T.numpy()[0])
        array_labels=np.append(array_labels, label.numpy())

    return array_labels, array_preds, probas_pred

# %% [markdown]
# # Fit et predict

# %%
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
loss=nn.BCEWithLogitsLoss()
# Train model
train_losses, train_f1s, train_accuracys, train_recalls, train_precisions, train_f2s, val_losses, val_f1s, val_accuracys, val_recalls, val_precisions, val_f2s = train_model(model=resnet18, 
                                                                                 train_loader=train_dataloader_augmente,
                                                                                 valid_loader=test_dataloader_augmente, 
                                                                                 criterion=loss, 
                                                                                 n_epochs=40, 
                                                                                 path_save_model="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps",
                                                                                 device=None)
# Out:
# 	 fc.weight
# 	 fc.bias
# Epoch: 1 	Training Loss: 0.531998 	Training F1-score: 0.784244 	Training accuracy: 0.777107 	Training recall: 0.802096 	Training precision: 0.809953 	Training F2-score: 0.790278 	Validation Loss: 1.100750 	Validation F1-score: 0.791096 	Validation accuracy: 0.730379 	Validation recall: 0.977790 	Validation precision: 0.670080 	Validation F2-score: 0.891701
# Epoch: 2 	Training Loss: 0.558406 	Training F1-score: 0.778455 	Training accuracy: 0.772497 	Training recall: 0.799742 	Training precision: 0.805473 	Training F2-score: 0.786194 	Validation Loss: 0.580235 	Validation F1-score: 0.811400 	Validation accuracy: 0.777026 	Validation recall: 0.916021 	Validation precision: 0.734911 	Validation F2-score: 0.869643
# Epoch: 3 	Training Loss: 0.537620 	Training F1-score: 0.782917 	Training accuracy: 0.776122 	Training recall: 0.800676 	Training precision: 0.807756 	Training F2-score: 0.788990 	Validation Loss: 0.722732 	Validation F1-score: 0.801107 	Validation accuracy: 0.749437 	Validation recall: 0.959358 	Validation precision: 0.692593 	Validation F2-score: 0.887794
# Epoch: 4 	Training Loss: 0.582035 	Training F1-score: 0.775290 	Training accuracy: 0.770004 	Training recall: 0.795686 	Training precision: 0.806550 	Training F2-score: 0.782256 	Validation Loss: 0.614313 	Validation F1-score: 0.727317 	Validation accuracy: 0.745427 	Validation recall: 0.654950 	Validation precision: 0.834644 	Validation F2-score: 0.680866
# Epoch: 5 	Training Loss: 0.539229 	Training F1-score: 0.784426 	Training accuracy: 0.777778 	Training recall: 0.805553 	Training precision: 0.806314 	Training F2-score: 0.792427 	Validation Loss: 0.517016 	Validation F1-score: 0.775544 	Validation accuracy: 0.765864 	Validation recall: 0.777524 	Validation precision: 0.783368 	Validation F2-score: 0.775574
# Epoch: 6 	Training Loss: 0.526202 	Training F1-score: 0.782490 	Training accuracy: 0.776194 	Training recall: 0.801289 	Training precision: 0.805506 	Training F2-score: 0.789318 	Validation Loss: 0.573797 	Validation F1-score: 0.807746 	Validation accuracy: 0.776829 	Validation recall: 0.905803 	Validation precision: 0.736078 	Validation F2-score: 0.862357
# Epoch: 7 	Training Loss: 0.562003 	Training F1-score: 0.779507 	Training accuracy: 0.773389 	Training recall: 0.800326 	Training precision: 0.805818 	Training F2-score: 0.787022 	Validation Loss: 0.559619 	Validation F1-score: 0.809165 	Validation accuracy: 0.777015 	Validation recall: 0.903685 	Validation precision: 0.738335 	Validation F2-score: 0.862188
# Epoch: 8 	Training Loss: 0.529814 	Training F1-score: 0.785157 	Training accuracy: 0.777710 	Training recall: 0.802469 	Training precision: 0.809321 	Training F2-score: 0.790874 	Validation Loss: 0.525437 	Validation F1-score: 0.789262 	Validation accuracy: 0.773884 	Validation recall: 0.811559 	Validation precision: 0.777298 	Validation F2-score: 0.801266
# Epoch: 9 	Training Loss: 0.507831 	Training F1-score: 0.791686 	Training accuracy: 0.783752 	Training recall: 0.807462 	Training precision: 0.811056 	Training F2-score: 0.797381 	Validation Loss: 0.750841 	Validation F1-score: 0.592557 	Validation accuracy: 0.672604 	Validation recall: 0.461001 	Validation precision: 0.866682 	Validation F2-score: 0.505040
# Epoch: 10 	Training Loss: 0.534144 	Training F1-score: 0.782934 	Training accuracy: 0.775841 	Training recall: 0.804019 	Training precision: 0.806903 	Training F2-score: 0.790828 	Validation Loss: 0.502801 	Validation F1-score: 0.800957 	Validation accuracy: 0.779296 	Validation recall: 0.848777 	Validation precision: 0.765510 	Validation F2-score: 0.827857
# Epoch: 11 	Training Loss: 0.533983 	Training F1-score: 0.782196 	Training accuracy: 0.776313 	Training recall: 0.800699 	Training precision: 0.806470 	Training F2-score: 0.788408 	Validation Loss: 0.886125 	Validation F1-score: 0.791739 	Validation accuracy: 0.729202 	Validation recall: 0.982005 	Validation precision: 0.668531 	Validation F2-score: 0.894262
# Epoch: 12 	Training Loss: 0.524536 	Training F1-score: 0.784488 	Training accuracy: 0.777432 	Training recall: 0.803448 	Training precision: 0.806379 	Training F2-score: 0.791492 	Validation Loss: 0.510882 	Validation F1-score: 0.795256 	Validation accuracy: 0.780343 	Validation recall: 0.817854 	Validation precision: 0.783692 	Validation F2-score: 0.807286
# Epoch: 13 	Training Loss: 0.500453 	Training F1-score: 0.791540 	Training accuracy: 0.784161 	Training recall: 0.808736 	Training precision: 0.810743 	Training F2-score: 0.797906 	Validation Loss: 0.590735 	Validation F1-score: 0.808217 	Validation accuracy: 0.766557 	Validation recall: 0.934144 	Validation precision: 0.718447 	Validation F2-score: 0.877906
# Epoch: 14 	Training Loss: 0.543384 	Training F1-score: 0.780300 	Training accuracy: 0.774373 	Training recall: 0.800449 	Training precision: 0.806350 	Training F2-score: 0.787541 	Validation Loss: 0.523946 	Validation F1-score: 0.808926 	Validation accuracy: 0.781746 	Validation recall: 0.878566 	Validation precision: 0.756992 	Validation F2-score: 0.847958
# Epoch: 15 	Training Loss: 0.526012 	Training F1-score: 0.785046 	Training accuracy: 0.778929 	Training recall: 0.803606 	Training precision: 0.807472 	Training F2-score: 0.791936 	Validation Loss: 0.522373 	Validation F1-score: 0.800551 	Validation accuracy: 0.770708 	Validation recall: 0.884888 	Validation precision: 0.738779 	Validation F2-score: 0.847568
# Epoch: 16 	Training Loss: 0.513866 	Training F1-score: 0.788283 	Training accuracy: 0.780825 	Training recall: 0.806434 	Training precision: 0.808221 	Training F2-score: 0.794982 	Validation Loss: 0.510770 	Validation F1-score: 0.784504 	Validation accuracy: 0.774926 	Validation recall: 0.784482 	Validation precision: 0.794359 	Validation F2-score: 0.783308
# Epoch: 17 	Training Loss: 0.548573 	Training F1-score: 0.780945 	Training accuracy: 0.773703 	Training recall: 0.799863 	Training precision: 0.805955 	Training F2-score: 0.787649 	Validation Loss: 0.678860 	Validation F1-score: 0.801076 	Validation accuracy: 0.754139 	Validation recall: 0.950753 	Validation precision: 0.699083 	Validation F2-score: 0.882819
# Epoch: 18 	Training Loss: 0.522500 	Training F1-score: 0.787028 	Training accuracy: 0.780154 	Training recall: 0.805109 	Training precision: 0.810446 	Training F2-score: 0.793461 	Validation Loss: 0.514753 	Validation F1-score: 0.804715 	Validation accuracy: 0.781233 	Validation recall: 0.860733 	Validation precision: 0.764300 	Validation F2-score: 0.836045
# Epoch: 19 	Training Loss: 0.533855 	Training F1-score: 0.786021 	Training accuracy: 0.778853 	Training recall: 0.806433 	Training precision: 0.808228 	Training F2-score: 0.793810 	Validation Loss: 0.517254 	Validation F1-score: 0.806719 	Validation accuracy: 0.779820 	Validation recall: 0.880665 	Validation precision: 0.752090 	Validation F2-score: 0.848069
# Epoch: 20 	Training Loss: 0.528070 	Training F1-score: 0.786437 	Training accuracy: 0.779480 	Training recall: 0.803604 	Training precision: 0.810122 	Training F2-score: 0.792147 	Validation Loss: 0.754347 	Validation F1-score: 0.794768 	Validation accuracy: 0.739666 	Validation recall: 0.965904 	Validation precision: 0.681174 	Validation F2-score: 0.887596
# Epoch: 21 	Training Loss: 0.511120 	Training F1-score: 0.783869 	Training accuracy: 0.776305 	Training recall: 0.804950 	Training precision: 0.802445 	Training F2-score: 0.792185 	Validation Loss: 0.528773 	Validation F1-score: 0.806419 	Validation accuracy: 0.777888 	Validation recall: 0.880641 	Validation precision: 0.750943 	Validation F2-score: 0.848109
# Epoch: 22 	Training Loss: 0.547957 	Training F1-score: 0.779547 	Training accuracy: 0.772675 	Training recall: 0.799722 	Training precision: 0.805709 	Training F2-score: 0.786665 	Validation Loss: 0.598747 	Validation F1-score: 0.804578 	Validation accuracy: 0.768821 	Validation recall: 0.914085 	Validation precision: 0.725116 	Validation F2-score: 0.865513
# Epoch: 23 	Training Loss: 0.571829 	Training F1-score: 0.775285 	Training accuracy: 0.768271 	Training recall: 0.793081 	Training precision: 0.805317 	Training F2-score: 0.780981 	Validation Loss: 0.608594 	Validation F1-score: 0.800323 	Validation accuracy: 0.753621 	Validation recall: 0.943774 	Validation precision: 0.701395 	Validation F2-score: 0.878901
# Epoch: 24 	Training Loss: 0.534624 	Training F1-score: 0.777474 	Training accuracy: 0.770604 	Training recall: 0.797930 	Training precision: 0.799154 	Training F2-score: 0.785246 	Validation Loss: 0.562194 	Validation F1-score: 0.804237 	Validation accuracy: 0.766039 	Validation recall: 0.920910 	Validation precision: 0.722752 	Validation F2-score: 0.868427
# Epoch: 25 	Training Loss: 0.529191 	Training F1-score: 0.782277 	Training accuracy: 0.776674 	Training recall: 0.799603 	Training precision: 0.808223 	Training F2-score: 0.788012 	Validation Loss: 0.874977 	Validation F1-score: 0.505379 	Validation accuracy: 0.631409 	Validation recall: 0.364208 	Validation precision: 0.884457 	Validation F2-score: 0.409306
# Epoch: 26 	Training Loss: 0.550381 	Training F1-score: 0.779111 	Training accuracy: 0.774024 	Training recall: 0.796402 	Training precision: 0.809136 	Training F2-score: 0.784679 	Validation Loss: 0.543146 	Validation F1-score: 0.806909 	Validation accuracy: 0.777561 	Validation recall: 0.892525 	Validation precision: 0.743689 	Validation F2-score: 0.854697
# Epoch: 27 	Training Loss: 0.504050 	Training F1-score: 0.789242 	Training accuracy: 0.780143 	Training recall: 0.806554 	Training precision: 0.806703 	Training F2-score: 0.795666 	Validation Loss: 0.611200 	Validation F1-score: 0.686001 	Validation accuracy: 0.719589 	Validation recall: 0.593002 	Validation precision: 0.836947 	Validation F2-score: 0.625807
# Epoch: 28 	Training Loss: 0.536534 	Training F1-score: 0.779671 	Training accuracy: 0.775222 	Training recall: 0.798441 	Training precision: 0.807532 	Training F2-score: 0.786077 	Validation Loss: 0.605531 	Validation F1-score: 0.700369 	Validation accuracy: 0.730058 	Validation recall: 0.608374 	Validation precision: 0.846513 	Validation F2-score: 0.640973
# Epoch: 29 	Training Loss: 0.542926 	Training F1-score: 0.780099 	Training accuracy: 0.773416 	Training recall: 0.798365 	Training precision: 0.806339 	Training F2-score: 0.786371 	Validation Loss: 0.552915 	Validation F1-score: 0.806988 	Validation accuracy: 0.774216 	Validation recall: 0.899690 	Validation precision: 0.738279 	Validation F2-score: 0.858860
# Epoch: 30 	Training Loss: 0.548679 	Training F1-score: 0.780948 	Training accuracy: 0.772917 	Training recall: 0.800552 	Training precision: 0.806548 	Training F2-score: 0.787881 	Validation Loss: 0.509581 	Validation F1-score: 0.783794 	Validation accuracy: 0.776655 	Validation recall: 0.778665 	Validation precision: 0.799905 	Validation F2-score: 0.779480
# Epoch: 31 	Training Loss: 0.563716 	Training F1-score: 0.776239 	Training accuracy: 0.770623 	Training recall: 0.797203 	Training precision: 0.808030 	Training F2-score: 0.783550 	Validation Loss: 0.761555 	Validation F1-score: 0.606727 	Validation accuracy: 0.681159 	Validation recall: 0.473347 	Validation precision: 0.875653 	Validation F2-score: 0.518233
# Epoch: 32 	Training Loss: 0.560742 	Training F1-score: 0.777885 	Training accuracy: 0.770989 	Training recall: 0.798718 	Training precision: 0.805875 	Training F2-score: 0.785157 	Validation Loss: 0.531736 	Validation F1-score: 0.784595 	Validation accuracy: 0.773546 	Validation recall: 0.790209 	Validation precision: 0.790218 	Validation F2-score: 0.786583
# Epoch: 33 	Training Loss: 0.538307 	Training F1-score: 0.781815 	Training accuracy: 0.774246 	Training recall: 0.804616 	Training precision: 0.802815 	Training F2-score: 0.790857 	Validation Loss: 0.818263 	Validation F1-score: 0.543146 	Validation accuracy: 0.650945 	Validation recall: 0.400336 	Validation precision: 0.883818 	Validation F2-score: 0.446794
# Epoch: 34 	Training Loss: 0.522138 	Training F1-score: 0.782996 	Training accuracy: 0.776365 	Training recall: 0.801270 	Training precision: 0.805257 	Training F2-score: 0.789705 	Validation Loss: 1.094639 	Validation F1-score: 0.779159 	Validation accuracy: 0.704733 	Validation recall: 0.987821 	Validation precision: 0.649507 	Validation F2-score: 0.890151
# Epoch: 35 	Training Loss: 0.579324 	Training F1-score: 0.771795 	Training accuracy: 0.767827 	Training recall: 0.792037 	Training precision: 0.802415 	Training F2-score: 0.778792 	Validation Loss: 0.517949 	Validation F1-score: 0.786018 	Validation accuracy: 0.768798 	Validation recall: 0.816178 	Validation precision: 0.767579 	Validation F2-score: 0.802469
# Epoch: 36 	Training Loss: 0.541814 	Training F1-score: 0.780560 	Training accuracy: 0.775400 	Training recall: 0.799244 	Training precision: 0.807864 	Training F2-score: 0.786947 	Validation Loss: 0.525888 	Validation F1-score: 0.798990 	Validation accuracy: 0.773546 	Validation recall: 0.873027 	Validation precision: 0.743837 	Validation F2-score: 0.840490
# Epoch: 37 	Training Loss: 0.539844 	Training F1-score: 0.781133 	Training accuracy: 0.775694 	Training recall: 0.796544 	Training precision: 0.810907 	Training F2-score: 0.785611 	Validation Loss: 0.540833 	Validation F1-score: 0.807521 	Validation accuracy: 0.778964 	Validation recall: 0.891765 	Validation precision: 0.745538 	Validation F2-score: 0.854569
# Epoch: 38 	Training Loss: 0.543967 	Training F1-score: 0.780426 	Training accuracy: 0.773730 	Training recall: 0.800278 	Training precision: 0.806300 	Training F2-score: 0.787577 	Validation Loss: 0.544068 	Validation F1-score: 0.763756 	Validation accuracy: 0.766895 	Validation recall: 0.726570 	Validation precision: 0.817656 	Validation F2-score: 0.739888
# Epoch: 39 	Training Loss: 0.539008 	Training F1-score: 0.781420 	Training accuracy: 0.775397 	Training recall: 0.800455 	Training precision: 0.806271 	Training F2-score: 0.788197 	Validation Loss: 0.744529 	Validation F1-score: 0.798267 	Validation accuracy: 0.747854 	Validation recall: 0.961137 	Validation precision: 0.689097 	Validation F2-score: 0.886787
# Epoch: 40 	Training Loss: 0.495827 	Training F1-score: 0.790892 	Training accuracy: 0.781114 	Training recall: 0.809808 	Training precision: 0.805886 	Training F2-score: 0.798295 	Validation Loss: 0.665675 	Validation F1-score: 0.800386 	Validation accuracy: 0.749088 	Validation recall: 0.954323 	Validation precision: 0.694662 	Validation F2-score: 0.884721

# %%
dict_train_losses={}
dict_train_f1s={}
dict_train_accuracys={}
dict_train_recalls={}
dict_train_precisions={}
dict_train_f2s={}

dict_val_losses={}
dict_val_f1s={}
dict_val_accuracys={}
dict_val_recalls={}
dict_val_precisions={}
dict_val_f2s={}

for i in range(0,40):
    dict_train_losses[i+1]=train_losses[i]
    dict_train_f1s[i+1]=train_f1s[i]
    dict_train_accuracys[i+1]=train_accuracys[i]
    dict_train_recalls[i+1]=train_recalls[i]
    dict_train_precisions[i+1]=train_precisions[i]
    dict_train_f2s[i+1]=train_f2s[i]

    dict_val_losses[i+1]=val_losses[i]
    dict_val_f1s[i+1]=val_f1s[i]
    dict_val_accuracys[i+1]=val_accuracys[i]
    dict_val_recalls[i+1]=val_recalls[i]
    dict_val_precisions[i+1]=val_precisions[i]
    dict_val_f2s[i+1]=val_f2s[i]

sorted_train_losses = sorted(dict_train_losses.items())
sorted_train_f1s = sorted(dict_train_f1s.items())
sorted_train_accuracys = sorted(dict_train_accuracys.items())
sorted_train_recalls = sorted(dict_train_recalls.items())
sorted_train_precisions = sorted(dict_train_precisions.items())
sorted_train_f2s = sorted(dict_train_f2s.items())

sorted_val_losses = sorted(dict_val_losses.items())
sorted_val_f1s = sorted(dict_val_f1s.items())
sorted_val_accuracys = sorted(dict_val_accuracys.items())
sorted_val_recalls = sorted(dict_val_recalls.items())
sorted_val_precisions = sorted(dict_val_precisions.items())
sorted_val_f2s = sorted(dict_val_f2s.items())

epochs, loss_train = zip(*sorted_train_losses)
epochs, f1_train = zip(*sorted_train_f1s)
epochs, acc_train = zip(*sorted_train_accuracys)
epochs, recall_train = zip(*sorted_train_recalls)
epochs, precision_train =zip(*sorted_train_precisions)
epochs, f2_train = zip(*sorted_train_f2s)

epochs, loss_val = zip(*sorted_val_losses)
epochs, f1_val = zip(*sorted_val_f1s)
epochs, acc_val = zip(*sorted_val_accuracys)
epochs, recall_val = zip(*sorted_val_recalls)
epochs, precision_val =zip(*sorted_val_precisions)
epochs, f2_val = zip(*sorted_val_f2s)


fig, axs = plt.subplots(3, 2, figsize=(15, 15))

axs[0,0].plot(epochs, loss_train, 'b',label="Loss sur l'échantillon d'apprentissage", color="blue")
axs[0,0].plot(epochs, loss_val, 'b',label="Loss sur l'échantillon de validation", color="red")
axs[0,0].legend()

axs[0,1].plot(epochs, acc_train, 'b',label="Accuracy sur l'échantillon d'apprentissage", color="blue")
axs[0,1].plot(epochs, acc_val, 'b',label="Accuracy sur l'échantillon de validation", color="red")
axs[0,1].legend()

axs[1,0].plot(epochs, precision_train, 'b',label="Precision sur l'échantillon d'apprentissage", color="blue")
axs[1,0].plot(epochs, precision_val, 'b',label="Precision sur l'échantillon de validation", color="red")
axs[1,0].legend()

axs[1,1].plot(epochs, recall_train, 'b',label="Recall sur l'échantillon d'apprentissage", color="blue")
axs[1,1].plot(epochs, recall_val, 'b',label="Recall sur l'échantillon de validation", color="red")
axs[1,1].legend()

axs[2,0].plot(epochs, f1_train, 'b',label="F1-score sur l'échantillon d'apprentissage", color="blue")
axs[2,0].plot(epochs, f1_val, 'b',label="F1-score sur l'échantillon de validation", color="red")
axs[2,0].legend()

axs[2,1].plot(epochs, f2_train, 'b',label="F2-score sur l'échantillon d'apprentissage", color="blue")
axs[2,1].plot(epochs, f2_val, 'b',label="F2-score sur l'échantillon de validation", color="red")
axs[2,1].legend()

plt.savefig('courbes_loss_resnet18_transfertlearning.png')
plt.show()

# %%
y_true_train, y_pred_train, proba_pred_train=predict(model=resnet18, path_model="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps/trained_resnet18_v2.pth", valid_loader=train_dataloader_augmente, device=None)
y_true_val, y_pred_val, proba_pred_val=predict(model=resnet18, path_model="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps/trained_resnet18_v2.pth", valid_loader=test_dataloader_augmente, device=None)

# %%
print("Loss sur l'échantillon train: {}".format(round(log_loss(y_true_train, proba_pred_train),2)))
print("Accuracy sur l'échantillon train: {}".format(round(accuracy_score(y_true_train, y_pred_train),2)))
print("Recall sur l'échantillon train: {}".format(round(recall_score(y_true_train, y_pred_train),2)))
print("Precision sur l'échantillon train: {}".format(round(precision_score(y_true_train, y_pred_train),2)))
print("F1-score sur l'échantillon train: {}".format(round(f1_score(y_true_train, y_pred_train),2)))
print("F2-score sur l'échantillon train: {} \n".format(round(fbeta_score(y_true_train, y_pred_train, beta=2),2)))

print("Loss sur l'échantillon test: {}".format(round(log_loss(y_true_val, proba_pred_val),2)))
print("Accuracy sur l'échantillon test: {}".format(round(accuracy_score(y_true_val, y_pred_val),2)))
print("Recall sur l'échantillon test: {}".format(round(recall_score(y_true_val, y_pred_val),2)))
print("Precision sur l'échantillon test: {}".format(round(precision_score(y_true_val, y_pred_val),2)))
print("F1-score sur l'échantillon test: {}".format(round(f1_score(y_true_val, y_pred_val),2)))
print("F2-score sur l'échantillon test: {}".format(round(fbeta_score(y_true_val, y_pred_val, beta=2),2)))

FP_rate, TP_rate, thresholds_keras = roc_curve(y_true_val, proba_pred_val)
AUC= auc(FP_rate, TP_rate)
print("AUC: {}".format(round(AUC, 2)))

plt.title('Courbe ROC:  ResNet-18 transfert learning')
plt.plot(FP_rate, TP_rate, label="AUC="+str(round(AUC, 2)))
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0], c=".7"), plt.plot([1, 1], c=".7")
plt.ylabel('Taux de vrais positifs')
plt.xlabel('Taux de faux positifs')
plt.legend(loc=4)
plt.savefig('ROC_resnet18_transfertlearning.png')
plt.show()

prec, rec, thresholds_keras = precision_recall_curve(y_true_val, proba_pred_val)

fig, ax = plt.subplots()
ax.plot(rec, prec)

#add axis labels to plot
ax.set_title('Courbe Precision-Recall: ResNet 18 transfert learning')
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')

#display plot
plt.savefig('prec_recall_resnet18_transfertlearning.png')
plt.show()

r = confusion_matrix(y_true_val, y_pred_val)

labels = ["Vrais négatifs", "Faux Positifs", "Faux négatifs", "Vrais positifs"]
categories = ["0", "1"]
make_confusion_matrix(r,
                      group_names=labels,
                      categories=categories,
                      )
# Out:
# Loss sur l'échantillon train: 0.51
# Accuracy sur l'échantillon train: 0.78
# Recall sur l'échantillon train: 0.94
# Precision sur l'échantillon train: 0.72
# F1-score sur l'échantillon train: 0.82
# F2-score sur l'échantillon train: 0.89
#
# Loss sur l'échantillon test: 0.67
# Accuracy sur l'échantillon test: 0.75
# Recall sur l'échantillon test: 0.95
# Precision sur l'échantillon test: 0.69
# F1-score sur l'échantillon test: 0.8
# F2-score sur l'échantillon test: 0.89
# AUC: 0.85

# %% [markdown]
# # Visualisation TSNE

# %%
test_dataset_tsne = CustomImageDataset_path(path_test,"C:/Users/yanis/OneDrive/Documents/Projet Stat/Données/bdappv/google2/img/",
                                            transform=transforms.Compose([
                                               transforms.Resize(224),
                                               transforms.ToTensor(),
                                               transforms.Normalize(mean = [0.34332898259162903, 0.35128462314605713, 0.30205702781677246],
                                                                    std= [0.1959962248802185, 0.17875953018665314, 0.17301008105278015]),
                                           ]))

test_dataloader_tsne = DataLoader(test_dataset_tsne, batch_size=32, shuffle=True)

# %%
def embedding(data):
    resnet18.eval()
    out = resnet18.conv1(data) #pass through CNN
    out= resnet18.bn1(out)
    out=resnet18.relu(out)
    out=resnet18.maxpool(out)
    out=resnet18.layer1(out)
    out=resnet18.layer2(out)
    out=resnet18.layer3(out)
    out=resnet18.layer4(out)
    out=torch.flatten(out, 1)
    return out

# %%
features = None
labels = None
image_paths = None

for data in test_dataloader_tsne:
    inputs=data[0]
    targets=data[1]
    paths=data[2]
    
    output = embedding(inputs)
    current_features = output.detach().numpy()
    if features is not None:
        features = np.concatenate((features, current_features))
    else:
        features = current_features

    if labels is not None:
        labels = np.concatenate((labels, targets))
    else:
        labels = targets
    
    if image_paths is not None:
        image_paths = np.concatenate((image_paths, paths))
    else:
        image_paths = paths

# %%
import itertools
fig, ax = plt.subplots(1, 3, figsize=(20,7), constrained_layout=True)

for c, per in zip(itertools.count(), [5, 30, 50]):
    tsne = TSNE(n_components=2,
                perplexity=per)
    tsne = tsne.fit_transform(features)
    scatter = ax[c].scatter(tsne[:, 0], tsne[:, 1], c=labels, cmap=matplotlib.colors.ListedColormap(["red", "blue"]), s=0.3)
    ax[c].set_title(f'Perplexity: {per}', fontsize=16)

# %%
tsne = TSNE(n_components=2, perplexity=30).fit_transform(features)
visualize_tsne(tsne, image_paths, labels)
# Out:
# Building the T-SNE plot: 100%|██████████| 5727/5727 [00:17<00:00, 322.72it/s]
