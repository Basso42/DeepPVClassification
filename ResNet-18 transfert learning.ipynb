# %% [markdown]
# # Préparation des données

# %% [markdown]
# ## Import et data augmentations

# %%
from  src.dataloader import *
from src.metrics import *
from src.resnet18 import *
from src.confusion_matrix import make_confusion_matrix
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from torchvision import transforms, datasets
import torch.nn as nn
import tensorflow as tf
from sklearn.metrics import fbeta_score, make_scorer, f1_score, accuracy_score, recall_score, precision_score, fbeta_score, precision_recall_curve, auc, roc_curve, log_loss, confusion_matrix
import torchvision.models as models
import os

# %%
np.random.seed(123)
path_train="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps/train_data.csv"
path_test="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps/test_data.csv"

transformed_train_dataset  = CustomImageDataset(path_train,"C:/Users/yanis/OneDrive/Documents/Projet Stat/Données/bdappv/google/img/", transform=transforms.Compose([
                                               transforms.Resize(224),
                                               transforms.RandomCrop(190), #On garde environ 75% de l'image
                                               transforms.ColorJitter(brightness=(0.5,1.5),contrast=0,saturation=0,hue=0),                                               transforms.RandomCrop(160),
                                               transforms.Resize(224),
                                               transforms.ToTensor(),
                                               transforms.Normalize(mean = [0.3492203652858734, 0.3565990626811981, 0.3071053624153137],
                                                                    std= [0.2003859430551529, 0.18338431417942047, 0.17826561629772186]),

                                           ]))

transformed_test_dataset = CustomImageDataset(path_test,"C:/Users/yanis/OneDrive/Documents/Projet Stat/Données/bdappv/google/img/",
                                            transform=transforms.Compose([
                                               transforms.Resize(224),
                                               transforms.ToTensor(),
                                               transforms.Normalize(mean = [0.3498302698135376, 0.3575190603733063, 0.30798372626304626],
                                                                    std= [0.20142625272274017, 0.1843339055776596, 0.17957480251789093]),
                                           ]))

train_dataloader_augmente = DataLoader(transformed_train_dataset, batch_size=32, shuffle=True)
test_dataloader_augmente = DataLoader(transformed_test_dataset, batch_size=32, shuffle=True)

print(len(train_dataloader_augmente))
batch = next(iter(train_dataloader_augmente))
print(batch[0].shape)
plt.imshow(batch[0][0].permute(1, 2, 0))
print(batch[1][0])
# Out:
# 721
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([32, 3, 224, 224])
# tensor(1)

# %%
resnet18 = models.resnet18(pretrained=True)

#Furthermore, in feature extracting, we don't need to calculate gradient for any layers except 
# the last layer that we initialize. For this we need to set .requires_grad to False
def set_parameter_requires_grad(model, feature_extracting=True):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False
            
set_parameter_requires_grad(resnet18)


nr_filters = resnet18.fc.in_features  #number of input features of last layer
#On ne met pas de sigmoid dans la dernière couche. C'est composé par la loss BCEWithLogitsLoss qui applique une sigmoid afin de calculer la cross-enthropy
resnet18.fc = nn.Linear(nr_filters, 1)

# %%
def sig(x):
    return 1/(1 + np.exp(-x))

def train_model(model, train_loader, valid_loader, criterion, n_epochs, path_save_model, device=None):
    """Pour entrainer le modèle 
    /!\ certains commentaires sont à passer en code pour passer sur GPU
    """
    # number of epochs to train the model

    train_losses= []
    train_f1s=[]
    train_accuracys=[]
    train_recalls=[]
    train_precisions=[]
    train_f2s=[]

    valid_loss_min = np.Inf  # set initial "min" to infinity
    val_losses= []
    val_f1s=[]
    val_accuracys=[]
    val_recalls=[]
    val_precisions=[]
    val_f2s=[]

    # Here we only want to update the gradient for the classifier layer that we initialized.
    params_to_update = []
    for name,param in model.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            print("\t",name)

    optimizer=torch.optim.SGD(params_to_update, lr = 0.01, momentum=0.9, weight_decay=1e-4)
    
    for epoch in range(n_epochs):

        # monitor losses
        train_loss = 0
        train_f1=0
        train_accuracy=0
        train_recall=0
        train_precision=0
        train_f2=0
        iter=0

        valid_loss=0
        valid_f1=0
        valid_accuracy=0
        valid_recall=0
        valid_precision=0
        valid_f2=0
        ###################
        # train the model #
        ###################
        model.train() # prep model for training

        for data,label in train_loader:
            
            # Pour utiliser GPU

            # inputs = inputs.to(device)
            # labels = labels.to(device)
            # model.to(device)

            # clear the gradients of all optimized variables
            optimizer.zero_grad()
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            output_detach = output.detach()

            # calculate the loss
            preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
            for i in range(len(output_detach)):
                if sig(output_detach[i])>0.5:
                    preds[i]=1
                else: preds[i]=0

            loss = criterion(output,label.unsqueeze(1).float()) #loss sur le batch i.e 1/32*sum...
            f1 = f1_score(label.numpy(), preds.T.numpy()[0])
            accuracy= accuracy_score(label.numpy(), preds.T.numpy()[0])
            recall= recall_score(label.numpy(), preds.T.numpy()[0])
            precision=precision_score(label.numpy(), preds.T.numpy()[0])
            f2=fbeta_score(label.numpy(), preds.T.numpy()[0], beta=2)
            iter+=1

            # backward pass: compute gradient of the loss with respect to model parameters
            loss.backward()
            # perform a single optimization step (parameter update)
            optimizer.step()
            # update running training loss

            #loss.item(): retourne la valeur numérique de la loss transférée au CPU
            #loss.item() retourne la loss moyenne sur le mini-batch, d'où la multiplication
            #par data.size(0)
            train_loss += loss.item() * data.size(0)
            train_f1+=f1
            train_accuracy+=accuracy
            train_recall+=recall
            train_precision+=precision
            train_f2+=f2
            iter+=1

        # print training/validation statistics 
        # calculate average loss over an epoch
        train_loss = train_loss / len(train_loader.sampler) 
        train_f1=train_f1/iter
        train_accuracy=train_accuracy/iter
        train_recall=train_recall/iter
        train_precision=train_precision/iter
        train_f2=train_f2/iter


        train_losses.append(train_loss)
        train_f1s.append(train_f1)
        train_accuracys.append(train_accuracy)
        train_recalls.append(train_recall)
        train_precisions.append(train_precision)
        train_f2s.append(train_f2)

        model.eval()

        for data,label in valid_loader:

            # Pour utiliser GPU

            # inputs = inputs.to(device)
            # labels = labels.to(device)
            # model.to(device)

            with torch.no_grad():
                output = model(data)
                
            output_detach = output.detach()

            # calculate the loss
            preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
            for i in range(len(output_detach)):
                if sig(output_detach[i])>0.5:
                    preds[i]=1
                else: preds[i]=0
            
            loss = criterion(output,label.unsqueeze(1).float())
            f1 = f1_score(label.numpy(), preds.T.numpy()[0])
            accuracy= accuracy_score(label.numpy(), preds.T.numpy()[0])
            recall= recall_score(label.numpy(), preds.T.numpy()[0])
            precision= precision_score(label.numpy(), preds.T.numpy()[0])
            f2=fbeta_score(label.numpy(), preds.T.numpy()[0], beta=2)

            # update running validation loss 
            valid_loss+=loss.item() * data.size(0)
            valid_f1+=f1
            valid_accuracy+=accuracy
            valid_recall+=recall
            valid_precision+=precision
            valid_f2+=f2
            iter+=1

        valid_loss=valid_loss/len(valid_loader.sampler)
        valid_f1=valid_f1/iter
        valid_accuracy=valid_accuracy/iter
        valid_recall=valid_recall/iter
        valid_precision=valid_precision/iter
        valid_f2=valid_f2/iter

        val_losses.append(valid_loss)
        val_f1s.append(valid_f1)
        val_accuracys.append(valid_accuracy)
        val_recalls.append(valid_recall)
        val_precisions.append(valid_precision)
        val_f2s.append(valid_f2)



        print('Epoch: {} \tTraining Loss: {:.6f} \tTraining F1-score: {:.6f} \tTraining accuracy: {:.6f} \tTraining recall: {:.6f} \tTraining precision: {:.6f} \tTraining F2-score: {:.6f} \tValidation Loss: {:.6f} \tValidation F1-score: {:.6f} \tValidation accuracy: {:.6f} \tValidation recall: {:.6f} \tValidation precision: {:.6f} \tValidation F2-score: {:.6f}'.format(
            epoch+1, 
            train_loss,
            train_f1,
            train_accuracy,
            train_recall,
            train_precision,
            train_f2,
            valid_loss,
            valid_f1,
            valid_accuracy,
            valid_recall,
            valid_precision,
            valid_f2
            ))
        
    torch.save(model.state_dict(), os.path.join(path_save_model,"trained_resnet18.pth"))

    return train_losses, train_f1s, train_accuracys, train_recalls, train_precisions, train_f2s, val_losses, val_f1s, val_accuracys, val_recalls, val_precisions, val_f2s


def eval_model(model, path_model, valid_loader, criterion, n_epochs, device=None):
    """Pour voir les performances du modèle entraîné sur l'échantillon de validation
       /!\ certains commentaires sont à passer en code pour passer sur GPU

    """
    ######################    
    # validate the model #
    ######################
    valid_loss_min = np.Inf  # set initial "min" to infinity
    val_losses= []
    val_f1s=[]
    val_accuracys=[]
    val_recalls=[]
    val_precisions=[]
    val_f2s=[]

    model.load_state_dict(torch.load(path_model))
    model.eval()  # prep model for evaluation

    #model.to(device)

    for epoch in range(n_epochs):
        valid_loss=0
        valid_f1=0
        valid_accuracy=0
        valid_recall=0
        valid_precision=0
        valid_f2=0
        iter=0
        for data,label in valid_loader:

            # Pour utiliser GPU

            # inputs = inputs.to(device)
            # labels = labels.to(device)
            # model.to(device)

            with torch.no_grad():
                output = model(data)
                
            output_detach = output.detach()

            # calculate the loss
            preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
            for i in range(len(output_detach)):
                if sig(output_detach[i])>0.5:
                    preds[i]=1
                else: preds[i]=0
            
            loss = criterion(output,label.unsqueeze(1).float())
            f1 = f1_score(label.numpy(), preds.T.numpy()[0])
            accuracy= accuracy_score(label.numpy(), preds.T.numpy()[0])
            recall= recall_score(label.numpy(), preds.T.numpy()[0])
            precision= precision_score(label.numpy(), preds.T.numpy()[0])
            f2=fbeta_score(label.numpy(), preds.T.numpy()[0], beta=2)

            # update running validation loss 
            valid_loss+=loss.item() * data.size(0)
            valid_f1+=f1
            valid_accuracy+=accuracy
            valid_recall+=recall
            valid_precision+=precision
            valid_f2+=f2
            iter+=1

        valid_loss=valid_loss/len(valid_loader.sampler)
        valid_f1=valid_f1/iter
        valid_accuracy=valid_accuracy/iter
        valid_recall=valid_recall/iter
        valid_precision=valid_precision/iter
        valid_f2=valid_f2/iter

        val_losses.append(valid_loss)
        val_f1s.append(valid_f1)
        val_accuracys.append(valid_accuracy)
        val_recalls.append(valid_recall)
        val_precisions.append(valid_precision)
        val_f2s.append(valid_f2)

        print('Epoch: {} \tValidation Loss: {:.6f} \tValidation F1-score: {:.6f} \tValidation accuracy: {:.6f} \tValidation recall: {:.6f} \tValidation precision: {:.6f} \tValidation F2-score: {:.6f}'.format(
            epoch+1,
            valid_loss,
            valid_f1,
            valid_accuracy,
            valid_recall,
            valid_precision,
            valid_f2
            ))
        
    return val_losses, val_f1s, val_accuracys, val_recalls, val_precisions, val_f2s


def predict(model, path_model, valid_loader, device=None):
    """Pour prédire 0/1 à partir de l'échantillon de validation
       /!\ certains commentaires sont à passer en code pour passer sur GPU

    """
    model.load_state_dict(torch.load(path_model))
    model.eval()

    array_labels=np.array([])
    array_preds=np.array([])
    probas_pred=np.array([])

    for data,label in valid_loader:
        # Pour utiliser GPU

        # inputs = inputs.to(device)
        # labels = labels.to(device)
        # model.to(device)

        with torch.no_grad():
            output = model(data)
        output_detach = output.detach()

        # calculate the loss
        preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
        probas=torch.zeros(output_detach.shape[0], output_detach.shape[1])

        for i in range(len(output_detach)):
            if sig(output_detach[i])>0.5:
                preds[i]=1
            else: preds[i]=0
            probas[i]=sig(output_detach[i])
        probas_pred=np.append(probas_pred, probas.T.numpy()[0])
        array_preds=np.append(array_preds,preds.T.numpy()[0])
        array_labels=np.append(array_labels, label.numpy())

    return array_labels, array_preds, probas_pred

# %%
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
loss=nn.BCEWithLogitsLoss()
# Train model
train_losses, train_f1s, train_accuracys, train_recalls, train_precisions, train_f2s, val_losses, val_f1s, val_accuracys, val_recalls, val_precisions, val_f2s = train_model(model=resnet18, 
                                                                                 train_loader=train_dataloader_augmente,
                                                                                 valid_loader=test_dataloader_augmente, 
                                                                                 criterion=loss, 
                                                                                 n_epochs=40, 
                                                                                 path_save_model="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps",
                                                                                 device=None)
# Out:
# 	 fc.weight
# 	 fc.bias
# Epoch: 1 	Training Loss: 0.542341 	Training F1-score: 0.384301 	Training accuracy: 0.381081 	Training recall: 0.396834 	Training precision: 0.396362 	Training F2-score: 0.389257
# Epoch: 2 	Training Loss: 0.548698 	Training F1-score: 0.387960 	Training accuracy: 0.386156 	Training recall: 0.396914 	Training precision: 0.402820 	Training F2-score: 0.390909
# Epoch: 3 	Training Loss: 0.539411 	Training F1-score: 0.389476 	Training accuracy: 0.387106 	Training recall: 0.399282 	Training precision: 0.402780 	Training F2-score: 0.392959
# Epoch: 4 	Training Loss: 0.551261 	Training F1-score: 0.388260 	Training accuracy: 0.385381 	Training recall: 0.397789 	Training precision: 0.401908 	Training F2-score: 0.391414
# Epoch: 5 	Training Loss: 0.547223 	Training F1-score: 0.388279 	Training accuracy: 0.385437 	Training recall: 0.399670 	Training precision: 0.401076 	Training F2-score: 0.392525
# Epoch: 6 	Training Loss: 0.509540 	Training F1-score: 0.393944 	Training accuracy: 0.390140 	Training recall: 0.403250 	Training precision: 0.403068 	Training F2-score: 0.397450
# Epoch: 7 	Training Loss: 0.521749 	Training F1-score: 0.392055 	Training accuracy: 0.388579 	Training recall: 0.401853 	Training precision: 0.402615 	Training F2-score: 0.395693
# Epoch: 8 	Training Loss: 0.539333 	Training F1-score: 0.388906 	Training accuracy: 0.385987 	Training recall: 0.397512 	Training precision: 0.402767 	Training F2-score: 0.391649
# Epoch: 9 	Training Loss: 0.559292 	Training F1-score: 0.386683 	Training accuracy: 0.383838 	Training recall: 0.396870 	Training precision: 0.400299 	Training F2-score: 0.390178
# Epoch: 10 	Training Loss: 0.563317 	Training F1-score: 0.387999 	Training accuracy: 0.385918 	Training recall: 0.396324 	Training precision: 0.403883 	Training F2-score: 0.390497
# Epoch: 11 	Training Loss: 0.545402 	Training F1-score: 0.388285 	Training accuracy: 0.385719 	Training recall: 0.398433 	Training precision: 0.400581 	Training F2-score: 0.391931
# Epoch: 12 	Training Loss: 0.544130 	Training F1-score: 0.388089 	Training accuracy: 0.386074 	Training recall: 0.396803 	Training precision: 0.402419 	Training F2-score: 0.390983
# Epoch: 13 	Training Loss: 0.526919 	Training F1-score: 0.392479 	Training accuracy: 0.389489 	Training recall: 0.401329 	Training precision: 0.403937 	Training F2-score: 0.395468
# Epoch: 14 	Training Loss: 0.557021 	Training F1-score: 0.387591 	Training accuracy: 0.385818 	Training recall: 0.397089 	Training precision: 0.401386 	Training F2-score: 0.390960
# Epoch: 15 	Training Loss: 0.541645 	Training F1-score: 0.390772 	Training accuracy: 0.388341 	Training recall: 0.399801 	Training precision: 0.404125 	Training F2-score: 0.393849
# Epoch: 16 	Training Loss: 0.529001 	Training F1-score: 0.391962 	Training accuracy: 0.389013 	Training recall: 0.401005 	Training precision: 0.403628 	Training F2-score: 0.395256
# Epoch: 17 	Training Loss: 0.547529 	Training F1-score: 0.389389 	Training accuracy: 0.387049 	Training recall: 0.398550 	Training precision: 0.402312 	Training F2-score: 0.392554
# Epoch: 18 	Training Loss: 0.564349 	Training F1-score: 0.386116 	Training accuracy: 0.384098 	Training recall: 0.395381 	Training precision: 0.401786 	Training F2-score: 0.389194
# Epoch: 19 	Training Loss: 0.539111 	Training F1-score: 0.388511 	Training accuracy: 0.386230 	Training recall: 0.398065 	Training precision: 0.401430 	Training F2-score: 0.391804
# Epoch: 20 	Training Loss: 0.508002 	Training F1-score: 0.395161 	Training accuracy: 0.391362 	Training recall: 0.403442 	Training precision: 0.404847 	Training F2-score: 0.398113
# Epoch: 21 	Training Loss: 0.526060 	Training F1-score: 0.391603 	Training accuracy: 0.388081 	Training recall: 0.401048 	Training precision: 0.402103 	Training F2-score: 0.395136
# Epoch: 22 	Training Loss: 0.591850 	Training F1-score: 0.385540 	Training accuracy: 0.384310 	Training recall: 0.394685 	Training precision: 0.403202 	Training F2-score: 0.388459
# Epoch: 23 	Training Loss: 0.547328 	Training F1-score: 0.390184 	Training accuracy: 0.388016 	Training recall: 0.399745 	Training precision: 0.403346 	Training F2-score: 0.393585
# Epoch: 24 	Training Loss: 0.531987 	Training F1-score: 0.388561 	Training accuracy: 0.385814 	Training recall: 0.398226 	Training precision: 0.400058 	Training F2-score: 0.392148
# Epoch: 25 	Training Loss: 0.550980 	Training F1-score: 0.388818 	Training accuracy: 0.386447 	Training recall: 0.398300 	Training precision: 0.403168 	Training F2-score: 0.391986
# Epoch: 26 	Training Loss: 0.592754 	Training F1-score: 0.386127 	Training accuracy: 0.385190 	Training recall: 0.395848 	Training precision: 0.403371 	Training F2-score: 0.389247
# Epoch: 27 	Training Loss: 0.534413 	Training F1-score: 0.390051 	Training accuracy: 0.386919 	Training recall: 0.400193 	Training precision: 0.400810 	Training F2-score: 0.393861
# Epoch: 28 	Training Loss: 0.559896 	Training F1-score: 0.387846 	Training accuracy: 0.385450 	Training recall: 0.397084 	Training precision: 0.401960 	Training F2-score: 0.390934
# Epoch: 29 	Training Loss: 0.564866 	Training F1-score: 0.386159 	Training accuracy: 0.383695 	Training recall: 0.395975 	Training precision: 0.401404 	Training F2-score: 0.389375
# Epoch: 30 	Training Loss: 0.573408 	Training F1-score: 0.385256 	Training accuracy: 0.383768 	Training recall: 0.394342 	Training precision: 0.401887 	Training F2-score: 0.388020
# Epoch: 31 	Training Loss: 0.566377 	Training F1-score: 0.387547 	Training accuracy: 0.385068 	Training recall: 0.396259 	Training precision: 0.402272 	Training F2-score: 0.390224
# Epoch: 32 	Training Loss: 0.577425 	Training F1-score: 0.386609 	Training accuracy: 0.383920 	Training recall: 0.397096 	Training precision: 0.400948 	Training F2-score: 0.390275
# Epoch: 33 	Training Loss: 0.530447 	Training F1-score: 0.392084 	Training accuracy: 0.389000 	Training recall: 0.400477 	Training precision: 0.404165 	Training F2-score: 0.394930
# Epoch: 34 	Training Loss: 0.565286 	Training F1-score: 0.386140 	Training accuracy: 0.384115 	Training recall: 0.397025 	Training precision: 0.400129 	Training F2-score: 0.390101
# Epoch: 35 	Training Loss: 0.557808 	Training F1-score: 0.388836 	Training accuracy: 0.386260 	Training recall: 0.397991 	Training precision: 0.404161 	Training F2-score: 0.391783
# Epoch: 36 	Training Loss: 0.537020 	Training F1-score: 0.391334 	Training accuracy: 0.388449 	Training recall: 0.400428 	Training precision: 0.403273 	Training F2-score: 0.394530
# Epoch: 37 	Training Loss: 0.557938 	Training F1-score: 0.386873 	Training accuracy: 0.385068 	Training recall: 0.396571 	Training precision: 0.402594 	Training F2-score: 0.390149
# Epoch: 38 	Training Loss: 0.535897 	Training F1-score: 0.390794 	Training accuracy: 0.387405 	Training recall: 0.400404 	Training precision: 0.402239 	Training F2-score: 0.394277
# Epoch: 39 	Training Loss: 0.553448 	Training F1-score: 0.387907 	Training accuracy: 0.385658 	Training recall: 0.397440 	Training precision: 0.401637 	Training F2-score: 0.391130
# Epoch: 40 	Training Loss: 0.521172 	Training F1-score: 0.392785 	Training accuracy: 0.390248 	Training recall: 0.400327 	Training precision: 0.405644 	Training F2-score: 0.395125

# %%
val_losses, val_f1s, val_accuracys, val_recalls, val_precisions, val_f2s = eval_model(model=resnet18
                                                                      , path_model="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps/trained_resnet18.pth"
                                                                      , valid_loader=test_dataloader_augmente
                                                                      , criterion=loss 
                                                                      , n_epochs=40
                                                                      , device=None)
# Out:
# Epoch: 1 	Validation Loss: 0.890635 	Validation F1-score: 0.787926 	Validation accuracy: 0.718750 	Validation recall: 0.988539 	Validation precision: 0.660825 	Validation F2-score: 0.895369
# Epoch: 2 	Validation Loss: 0.890635 	Validation F1-score: 0.786370 	Validation accuracy: 0.716160 	Validation recall: 0.988072 	Validation precision: 0.658843 	Validation F2-score: 0.894309
# Epoch: 3 	Validation Loss: 0.890635 	Validation F1-score: 0.787278 	Validation accuracy: 0.716160 	Validation recall: 0.988220 	Validation precision: 0.658856 	Validation F2-score: 0.895230
# Epoch: 4 	Validation Loss: 0.890635 	Validation F1-score: 0.786637 	Validation accuracy: 0.716160 	Validation recall: 0.988146 	Validation precision: 0.659084 	Validation F2-score: 0.894489
# Epoch: 5 	Validation Loss: 0.890635 	Validation F1-score: 0.782779 	Validation accuracy: 0.716160 	Validation recall: 0.982575 	Validation precision: 0.655607 	Validation F2-score: 0.889819
# Epoch: 6 	Validation Loss: 0.890635 	Validation F1-score: 0.782484 	Validation accuracy: 0.718750 	Validation recall: 0.982456 	Validation precision: 0.655664 	Validation F2-score: 0.889555
# Epoch: 7 	Validation Loss: 0.890635 	Validation F1-score: 0.786598 	Validation accuracy: 0.718750 	Validation recall: 0.987551 	Validation precision: 0.659930 	Validation F2-score: 0.893969
# Epoch: 8 	Validation Loss: 0.890635 	Validation F1-score: 0.785193 	Validation accuracy: 0.716160 	Validation recall: 0.988103 	Validation precision: 0.657504 	Validation F2-score: 0.893528
# Epoch: 9 	Validation Loss: 0.890635 	Validation F1-score: 0.787607 	Validation accuracy: 0.718750 	Validation recall: 0.987416 	Validation precision: 0.660805 	Validation F2-score: 0.894631
# Epoch: 10 	Validation Loss: 0.890635 	Validation F1-score: 0.787953 	Validation accuracy: 0.718750 	Validation recall: 0.988052 	Validation precision: 0.660100 	Validation F2-score: 0.895406
# Epoch: 11 	Validation Loss: 0.890635 	Validation F1-score: 0.788160 	Validation accuracy: 0.718750 	Validation recall: 0.988206 	Validation precision: 0.660449 	Validation F2-score: 0.895561
# Epoch: 12 	Validation Loss: 0.890635 	Validation F1-score: 0.787824 	Validation accuracy: 0.718750 	Validation recall: 0.987278 	Validation precision: 0.660144 	Validation F2-score: 0.894978
# Epoch: 13 	Validation Loss: 0.890635 	Validation F1-score: 0.783022 	Validation accuracy: 0.713570 	Validation recall: 0.982807 	Validation precision: 0.656139 	Validation F2-score: 0.890072
# Epoch: 14 	Validation Loss: 0.890635 	Validation F1-score: 0.783333 	Validation accuracy: 0.716160 	Validation recall: 0.983132 	Validation precision: 0.656193 	Validation F2-score: 0.890443
# Epoch: 15 	Validation Loss: 0.890635 	Validation F1-score: 0.786188 	Validation accuracy: 0.716160 	Validation recall: 0.988399 	Validation precision: 0.658442 	Validation F2-score: 0.894264
# Epoch: 16 	Validation Loss: 0.890635 	Validation F1-score: 0.785509 	Validation accuracy: 0.716160 	Validation recall: 0.988264 	Validation precision: 0.657886 	Validation F2-score: 0.893796
# Epoch: 17 	Validation Loss: 0.890635 	Validation F1-score: 0.782029 	Validation accuracy: 0.718750 	Validation recall: 0.982729 	Validation precision: 0.655294 	Validation F2-score: 0.889287
# Epoch: 18 	Validation Loss: 0.890635 	Validation F1-score: 0.788395 	Validation accuracy: 0.718750 	Validation recall: 0.988099 	Validation precision: 0.661401 	Validation F2-score: 0.895483
# Epoch: 19 	Validation Loss: 0.890635 	Validation F1-score: 0.786108 	Validation accuracy: 0.716160 	Validation recall: 0.988587 	Validation precision: 0.658468 	Validation F2-score: 0.894205
# Epoch: 20 	Validation Loss: 0.890635 	Validation F1-score: 0.787405 	Validation accuracy: 0.718750 	Validation recall: 0.988657 	Validation precision: 0.660404 	Validation F2-score: 0.895000
# Epoch: 21 	Validation Loss: 0.890635 	Validation F1-score: 0.787744 	Validation accuracy: 0.718750 	Validation recall: 0.988071 	Validation precision: 0.660628 	Validation F2-score: 0.895001
# Epoch: 22 	Validation Loss: 0.890635 	Validation F1-score: 0.782777 	Validation accuracy: 0.716160 	Validation recall: 0.982838 	Validation precision: 0.655868 	Validation F2-score: 0.889901
# Epoch: 23 	Validation Loss: 0.890635 	Validation F1-score: 0.785739 	Validation accuracy: 0.716160 	Validation recall: 0.988290 	Validation precision: 0.657956 	Validation F2-score: 0.894012
# Epoch: 24 	Validation Loss: 0.890635 	Validation F1-score: 0.781949 	Validation accuracy: 0.716160 	Validation recall: 0.982506 	Validation precision: 0.656082 	Validation F2-score: 0.888887
# Epoch: 25 	Validation Loss: 0.890635 	Validation F1-score: 0.786117 	Validation accuracy: 0.716160 	Validation recall: 0.987809 	Validation precision: 0.658262 	Validation F2-score: 0.894105
# Epoch: 26 	Validation Loss: 0.890635 	Validation F1-score: 0.787990 	Validation accuracy: 0.718750 	Validation recall: 0.988496 	Validation precision: 0.661683 	Validation F2-score: 0.894939
# Epoch: 27 	Validation Loss: 0.890635 	Validation F1-score: 0.786439 	Validation accuracy: 0.716160 	Validation recall: 0.988272 	Validation precision: 0.658905 	Validation F2-score: 0.894273
# Epoch: 28 	Validation Loss: 0.890635 	Validation F1-score: 0.787689 	Validation accuracy: 0.718750 	Validation recall: 0.988370 	Validation precision: 0.660049 	Validation F2-score: 0.895240
# Epoch: 29 	Validation Loss: 0.890635 	Validation F1-score: 0.782392 	Validation accuracy: 0.713570 	Validation recall: 0.982882 	Validation precision: 0.655800 	Validation F2-score: 0.889521
# Epoch: 30 	Validation Loss: 0.890635 	Validation F1-score: 0.788067 	Validation accuracy: 0.718750 	Validation recall: 0.988475 	Validation precision: 0.661305 	Validation F2-score: 0.895230
# Epoch: 31 	Validation Loss: 0.890635 	Validation F1-score: 0.787203 	Validation accuracy: 0.718750 	Validation recall: 0.987742 	Validation precision: 0.660137 	Validation F2-score: 0.894582
# Epoch: 32 	Validation Loss: 0.890635 	Validation F1-score: 0.783719 	Validation accuracy: 0.716160 	Validation recall: 0.982617 	Validation precision: 0.656415 	Validation F2-score: 0.890611
# Epoch: 33 	Validation Loss: 0.890635 	Validation F1-score: 0.788258 	Validation accuracy: 0.718750 	Validation recall: 0.988449 	Validation precision: 0.660277 	Validation F2-score: 0.895665
# Epoch: 34 	Validation Loss: 0.890635 	Validation F1-score: 0.786588 	Validation accuracy: 0.716160 	Validation recall: 0.988508 	Validation precision: 0.658954 	Validation F2-score: 0.894578
# Epoch: 35 	Validation Loss: 0.890635 	Validation F1-score: 0.787861 	Validation accuracy: 0.718750 	Validation recall: 0.987785 	Validation precision: 0.660369 	Validation F2-score: 0.895189
# Epoch: 36 	Validation Loss: 0.890635 	Validation F1-score: 0.788434 	Validation accuracy: 0.718750 	Validation recall: 0.988064 	Validation precision: 0.661585 	Validation F2-score: 0.895453
# Epoch: 37 	Validation Loss: 0.890635 	Validation F1-score: 0.784920 	Validation accuracy: 0.716160 	Validation recall: 0.987788 	Validation precision: 0.657137 	Validation F2-score: 0.893258
# Epoch: 38 	Validation Loss: 0.890635 	Validation F1-score: 0.782161 	Validation accuracy: 0.716160 	Validation recall: 0.982783 	Validation precision: 0.655778 	Validation F2-score: 0.889295
# Epoch: 39 	Validation Loss: 0.890635 	Validation F1-score: 0.785594 	Validation accuracy: 0.716160 	Validation recall: 0.987816 	Validation precision: 0.657029 	Validation F2-score: 0.893953
# Epoch: 40 	Validation Loss: 0.890635 	Validation F1-score: 0.786942 	Validation accuracy: 0.718750 	Validation recall: 0.988588 	Validation precision: 0.660541 	Validation F2-score: 0.894402

# %%
dict_train_losses={}
dict_train_f1s={}
dict_train_accuracys={}
dict_train_recalls={}
dict_train_precisions={}
dict_train_f2s={}

dict_val_losses={}
dict_val_f1s={}
dict_val_accuracys={}
dict_val_recalls={}
dict_val_precisions={}
dict_val_f2s={}

for i in range(0,40):
    dict_train_losses[i+1]=train_losses[i]
    dict_train_f1s[i+1]=train_f1s[i]
    dict_train_accuracys[i+1]=train_accuracys[i]
    dict_train_recalls[i+1]=train_recalls[i]
    dict_train_precisions[i+1]=train_precisions[i]
    dict_train_f2s[i+1]=train_f2s[i]

    dict_val_losses[i+1]=val_losses[i]
    dict_val_f1s[i+1]=val_f1s[i]
    dict_val_accuracys[i+1]=val_accuracys[i]
    dict_val_recalls[i+1]=val_recalls[i]
    dict_val_precisions[i+1]=val_precisions[i]
    dict_val_f2s[i+1]=val_f2s[i]

sorted_train_losses = sorted(dict_train_losses.items())
sorted_train_f1s = sorted(dict_train_f1s.items())
sorted_train_accuracys = sorted(dict_train_accuracys.items())
sorted_train_recalls = sorted(dict_train_recalls.items())
sorted_train_precisions = sorted(dict_train_precisions.items())
sorted_train_f2s = sorted(dict_train_f2s.items())

sorted_val_losses = sorted(dict_val_losses.items())
sorted_val_f1s = sorted(dict_val_f1s.items())
sorted_val_accuracys = sorted(dict_val_accuracys.items())
sorted_val_recalls = sorted(dict_val_recalls.items())
sorted_val_precisions = sorted(dict_val_precisions.items())
sorted_val_f2s = sorted(dict_val_f2s.items())

epochs, loss_train = zip(*sorted_train_losses)
epochs, f1_train = zip(*sorted_train_f1s)
epochs, acc_train = zip(*sorted_train_accuracys)
epochs, recall_train = zip(*sorted_train_recalls)
epochs, precision_train =zip(*sorted_train_precisions)
epochs, f2_train = zip(*sorted_train_f2s)

epochs, loss_val = zip(*sorted_val_losses)
epochs, f1_val = zip(*sorted_val_f1s)
epochs, acc_val = zip(*sorted_val_accuracys)
epochs, recall_val = zip(*sorted_val_recalls)
epochs, precision_val =zip(*sorted_val_precisions)
epochs, f2_val = zip(*sorted_val_f2s)


fig, axs = plt.subplots(3, 2, figsize=(15, 15))

axs[0,0].plot(epochs, loss_train, 'b',label="Loss sur l'échantillon d'apprentissage", color="blue")
axs[0,0].plot(epochs, loss_val, 'b',label="Loss sur l'échantillon de validation", color="red")
axs[0,0].legend()

axs[0,1].plot(epochs, acc_train, 'b',label="Accuracy sur l'échantillon d'apprentissage", color="blue")
axs[0,1].plot(epochs, acc_val, 'b',label="Accuracy sur l'échantillon de validation", color="red")
axs[0,1].legend()

axs[1,0].plot(epochs, precision_train, 'b',label="Precision sur l'échantillon d'apprentissage", color="blue")
axs[1,0].plot(epochs, precision_val, 'b',label="Precision sur l'échantillon de validation", color="red")
axs[1,0].legend()

axs[1,1].plot(epochs, recall_train, 'b',label="Recall sur l'échantillon d'apprentissage", color="blue")
axs[1,1].plot(epochs, recall_val, 'b',label="Recall sur l'échantillon de validation", color="red")
axs[1,1].legend()

axs[2,0].plot(epochs, f1_train, 'b',label="F1-score sur l'échantillon d'apprentissage", color="blue")
axs[2,0].plot(epochs, f1_val, 'b',label="F1-score sur l'échantillon de validation", color="red")
axs[2,0].legend()

axs[2,1].plot(epochs, f2_train, 'b',label="F2-score sur l'échantillon d'apprentissage", color="blue")
axs[2,1].plot(epochs, f2_val, 'b',label="F2-score sur l'échantillon de validation", color="red")
axs[2,1].legend()

plt.savefig('courbes_loss_resnet18_transfertlearning.png')
plt.show()

# %%
y_true_train, y_pred_train, proba_pred_train=predict(model=resnet18, path_model="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps/trained_resnet18.pth", valid_loader=train_dataloader_augmente, device=None)
y_true_val, y_pred_val, proba_pred_val=predict(model=resnet18, path_model="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps/trained_resnet18.pth", valid_loader=test_dataloader_augmente, device=None)

# %%
print("Loss sur l'échantillon train: {}".format(round(log_loss(y_true_train, proba_pred_train),2)))
print("Accuracy sur l'échantillon train: {}".format(round(accuracy_score(y_true_train, y_pred_train),2)))
print("Recall sur l'échantillon train: {}".format(round(recall_score(y_true_train, y_pred_train),2)))
print("Precision sur l'échantillon train: {}".format(round(precision_score(y_true_train, y_pred_train),2)))
print("F1-score sur l'échantillon train: {}".format(round(f1_score(y_true_train, y_pred_train),2)))
print("F2-score sur l'échantillon train: {} \n".format(round(fbeta_score(y_true_train, y_pred_train, beta=2),2)))

print("Loss sur l'échantillon test: {}".format(round(log_loss(y_true_val, proba_pred_val),2)))
print("Accuracy sur l'échantillon test: {}".format(round(accuracy_score(y_true_val, y_pred_val),2)))
print("Recall sur l'échantillon test: {}".format(round(recall_score(y_true_val, y_pred_val),2)))
print("Precision sur l'échantillon test: {}".format(round(precision_score(y_true_val, y_pred_val),2)))
print("F1-score sur l'échantillon test: {}".format(round(f1_score(y_true_val, y_pred_val),2)))
print("F2-score sur l'échantillon test: {}".format(round(fbeta_score(y_true_val, y_pred_val, beta=2),2)))

FP_rate, TP_rate, thresholds_keras = roc_curve(y_true_val, proba_pred_val)
AUC= auc(FP_rate, TP_rate)
print("AUC: {}".format(round(AUC, 2)))

plt.title('Courbe ROC:  ResNet-18 transfert learning')
plt.plot(FP_rate, TP_rate, label="AUC="+str(round(AUC, 2)))
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0], c=".7"), plt.plot([1, 1], c=".7")
plt.ylabel('Taux de vrais positifs')
plt.xlabel('Taux de faux positifs')
plt.legend(loc=4)
plt.savefig('ROC_resnet18_transfertlearning.png')
plt.show()

prec, rec, thresholds_keras = precision_recall_curve(y_true_val, proba_pred_val)

fig, ax = plt.subplots()
ax.plot(rec, prec)

#add axis labels to plot
ax.set_title('Courbe Precision-Recall: ResNet 18 transfert learning')
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')

#display plot
plt.savefig('prec_recall_resnet18_transfertlearning.png')
plt.show()

r = confusion_matrix(y_true_val, y_pred_val)

labels = ["Vrais négatifs", "Faux Positifs", "Faux négatifs", "Vrais positifs"]
categories = ["0", "1"]
make_confusion_matrix(r,
                      group_names=labels,
                      categories=categories,
                      )
# Out:
# Loss sur l'échantillon train: 0.63
# Accuracy sur l'échantillon train: 0.75
# Recall sur l'échantillon train: 0.97
# Precision sur l'échantillon train: 0.69
# F1-score sur l'échantillon train: 0.8
# F2-score sur l'échantillon train: 0.9
#
# Loss sur l'échantillon test: 0.89
# Accuracy sur l'échantillon test: 0.72
# Recall sur l'échantillon test: 0.99
# Precision sur l'échantillon test: 0.66
# F1-score sur l'échantillon test: 0.79
# F2-score sur l'échantillon test: 0.9
# AUC: 0.86
