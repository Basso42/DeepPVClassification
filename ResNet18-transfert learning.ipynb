# %% [markdown]
# # **ResNet18 - transfert learning**

# %% [markdown]
# Nous utilisons ici une architecture ResNet18 avec poids pré-entrainés pour classer les images satellites. Seules les couches fully-connected du réseau sont ré-entrainées à partir de nos images.

# %% [markdown]
# # Préparation des données

# %% [markdown]
# ## Import et data augmentations

# %%
from  src.dataloader import *
from src.bdappv import *
from src.metrics import *
from src.resnet18 import *
from src.confusion_matrix import make_confusion_matrix
from torch.utils.data import DataLoader, SubsetRandomSampler
import matplotlib.pyplot as plt
from torchvision import transforms, datasets
import torch.nn as nn
import tensorflow as tf
from sklearn.metrics import fbeta_score, make_scorer, f1_score, accuracy_score, recall_score, precision_score, fbeta_score, precision_recall_curve, auc, roc_curve, log_loss, confusion_matrix
import torchvision.models as models
import os
from src.tsne import *
from torch.utils.data import DataLoader
import matplotlib
import torchvision.models as models
from sklearn.manifold import TSNE
import math
import itertools
# Out:
# c:\Users\yanis\anaconda3\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: [WinError 127] La procédure spécifiée est introuvable
#   warn(f"Failed to load image Python extension: {e}")

# %%
dataset=BDAPPVClassification(img_dir="C:/Users/yanis/OneDrive/Documents/Projet Stat/Données/bdappv/google3", size=None)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
mean, std = batch_mean_and_sd(dataloader)
print("Moyenne par channel: {}".format(mean.tolist()))
print("Ecart-type par channel: {}".format(std.tolist()))
# Out:
# Moyenne par channel: [0.346024751663208, 0.35355815291404724, 0.3038492202758789]
# Ecart-type par channel: [0.20496879518032074, 0.18832367658615112, 0.18234187364578247]

# %%
seed = 123
torch.manual_seed(seed)
np.random.seed(seed)

dataset_crop=BDAPPVClassification(img_dir="C:/Users/yanis/OneDrive/Documents/Projet Stat/Données/bdappv/google3",
                                  size=224,
                                  transform=transforms.Compose([transforms.Normalize(mean = [0.346024751663208, 0.35355815291404724, 0.3038492202758789],
                                                                    std= [0.20496879518032074, 0.18832367658615112, 0.18234187364578247])]))
# Define the indices for training and testing sets
n = len(dataset)
train_size = int(0.8 * n)
test_size = n - train_size
train_indices = torch.arange(0, train_size)
test_indices = torch.arange(train_size, n)

# Define the samplers for training and testing sets
train_sampler = SubsetRandomSampler(train_indices)
test_sampler = SubsetRandomSampler(test_indices)

# Define the dataloaders for training and testing sets
train_dataloader_augmente = DataLoader(dataset_crop, batch_size=32, sampler=train_sampler)
test_dataloader_augmente = DataLoader(dataset_crop, batch_size=32, sampler=test_sampler)

print(len(train_dataloader_augmente))
batch = next(iter(train_dataloader_augmente))
print(batch[0].shape)
plt.imshow(batch[0][0].permute(1, 2, 0))
print(batch[1][0])
# Out:
# 716
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([32, 3, 224, 224])
# tensor(0)

# %% [markdown]
# # Import du modèle

# %%
resnet18 = models.resnet18(pretrained=True)

#Furthermore, in feature extracting, we don't need to calculate gradient for any layers except 
# the last layer that we initialize. For this we need to set .requires_grad to False
def set_parameter_requires_grad(model, feature_extracting=True):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False
            
set_parameter_requires_grad(resnet18)


nr_filters = resnet18.fc.in_features  #number of input features of last layer
#On ne met pas de sigmoid dans la dernière couche. C'est composé par la loss BCEWithLogitsLoss qui applique une sigmoid afin de calculer la cross-enthropy
resnet18.fc = nn.Linear(nr_filters, 1)

# %% [markdown]
# # Choix du Learning Rate

# %%
params_to_update = []
for name,param in resnet18.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name)
# Out:
# 	 fc.weight
# 	 fc.bias

# %%
def find_lr(train_loader=train_dataloader_augmente, optimizer=torch.optim.SGD(params_to_update, lr = 0.01, momentum=0.9, weight_decay=1e-4), init_value = 1e-8, final_value=10., beta = 0.98, criterion=nn.BCEWithLogitsLoss()):
    #Adapté de https://sgugger.github.io/how-do-you-find-a-good-learning-rate.html
    num = len(train_loader)-1
    mult = (final_value / init_value) ** (1/num)
    lr = init_value
    optimizer.param_groups[0]['lr'] = lr
    avg_loss = 0.
    best_loss = 0.
    batch_num = 0
    losses = []
    log_lrs = []
    for data, label in train_loader:
        batch_num += 1
        #As before, get theloss for this mini-batch of inputs/outputs
        optimizer.zero_grad()
        output = resnet18(data)
            
        loss = criterion(output,label.unsqueeze(1).float()) #loss sur le batch i.e 1/32*sum...
        #Compute the smoothed loss
        avg_loss = beta * avg_loss + (1-beta) *loss.item()
        smoothed_loss = avg_loss / (1 - beta**batch_num)
        #Stop if the loss is exploding
        if batch_num > 1 and smoothed_loss > 4 * best_loss:
            return log_lrs, losses
        #Record the best loss
        if smoothed_loss < best_loss or batch_num==1:
            best_loss = smoothed_loss
        #Store the values
        losses.append(smoothed_loss)
        log_lrs.append(math.log10(lr))
        #Do the SGD step
        loss.backward()
        optimizer.step()
        #Update the lr for the next step
        lr *= mult
        optimizer.param_groups[0]['lr'] = lr
    return log_lrs, losses

# %%
seed = 123
torch.manual_seed(seed)
np.random.seed(seed)

log_lrs, losses=find_lr(train_loader=train_dataloader_augmente, optimizer=torch.optim.SGD(params_to_update, lr = 0.01, momentum=0.9, weight_decay=1e-4), init_value = 1e-8, final_value=10., beta = 0.98, criterion=nn.BCEWithLogitsLoss())

# %%
lrs=[10**k for k in log_lrs]
fig, ax = plt.subplots()

ax.plot(lrs[10:-5], losses[10:-5], 'b',label="Loss en fonction du learning rate", color="blue")
ax.set_xlabel("Learning rate")
ax.set_ylabel("Loss")
ax.set_xscale('log')
plt.show()

# %% [markdown]
# Le minimum de la loss est atteint pour un learning rate environ égal à 0,01. On remarque que la courbe de loss décroit le plus rapidement vers ce minimum pour un learning rate environ égal à 0,001. Cela semble être un bon choix.

# %% [markdown]
# # Fit et predict

# %%
def sig(x):
    return 1/(1 + np.exp(-x))

def train_model(model, train_loader, valid_loader, criterion, n_epochs, path_save_model, device=None):
    """Pour entrainer le modèle 
    /!\ certains commentaires sont à passer en code pour passer sur GPU
    """
    # number of epochs to train the model

    train_losses= []
    train_f1s=[]
    train_accuracys=[]
    train_recalls=[]
    train_precisions=[]
    train_f2s=[]

    valid_loss_min = np.Inf  # set initial "min" to infinity
    val_losses= []
    val_f1s=[]
    val_accuracys=[]
    val_recalls=[]
    val_precisions=[]
    val_f2s=[]

    # Here we only want to update the gradient for the classifier layer that we initialized.
    params_to_update = []
    for name,param in model.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            print("\t",name)

    optimizer=torch.optim.SGD(params_to_update, lr = 0.001, momentum=0.9, weight_decay=1e-4)
    
    for epoch in range(n_epochs):

        # monitor losses
        train_loss = 0
        train_f1=0
        train_accuracy=0
        train_recall=0
        train_precision=0
        train_f2=0

        valid_loss=0
        valid_f1=0
        valid_accuracy=0
        valid_recall=0
        valid_precision=0
        valid_f2=0

        iter_train=0
        iter_val=0
        ###################
        # train the model #
        ###################
        model.train() # prep model for training

        for data,label in train_loader:
            iter_train+=1

            # Pour utiliser GPU

            # inputs = inputs.to(device)
            # labels = labels.to(device)
            # model.to(device)

            # clear the gradients of all optimized variables
            optimizer.zero_grad()
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            output_detach = output.detach()

            # calculate the loss
            preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
            for i in range(len(output_detach)):
                if sig(output_detach[i])>0.5:
                    preds[i]=1
                else: preds[i]=0

            loss = criterion(output,label.unsqueeze(1).float()) #loss sur le batch i.e 1/32*sum...
            f1 = f1_score(label.numpy(), preds.T.numpy()[0])
            accuracy= accuracy_score(label.numpy(), preds.T.numpy()[0])
            recall= recall_score(label.numpy(), preds.T.numpy()[0])
            precision=precision_score(label.numpy(), preds.T.numpy()[0])
            f2=fbeta_score(label.numpy(), preds.T.numpy()[0], beta=2)

            # backward pass: compute gradient of the loss with respect to model parameters
            loss.backward()
            # perform a single optimization step (parameter update)
            optimizer.step()
            # update running training loss

            #loss.item(): retourne la valeur numérique de la loss transférée au CPU
            #loss.item() retourne la loss moyenne sur le mini-batch, d'où la multiplication
            #par data.size(0)
            train_loss += loss.item() * data.size(0)
            train_f1+=f1
            train_accuracy+=accuracy
            train_recall+=recall
            train_precision+=precision
            train_f2+=f2

        # print training/validation statistics 
        # calculate average loss over an epoch
        train_loss = train_loss / len(train_loader.sampler) 
        train_f1=train_f1/iter_train
        train_accuracy=train_accuracy/iter_train
        train_recall=train_recall/iter_train
        train_precision=train_precision/iter_train
        train_f2=train_f2/iter_train


        train_losses.append(train_loss)
        train_f1s.append(train_f1)
        train_accuracys.append(train_accuracy)
        train_recalls.append(train_recall)
        train_precisions.append(train_precision)
        train_f2s.append(train_f2)

        model.eval()

        for data,label in valid_loader:
            iter_val+=1

            # Pour utiliser GPU

            # inputs = inputs.to(device)
            # labels = labels.to(device)
            # model.to(device)

            with torch.no_grad():
                output = model(data)
                
            output_detach = output.detach()

            # calculate the loss
            preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
            for i in range(len(output_detach)):
                if sig(output_detach[i])>0.5:
                    preds[i]=1
                else: preds[i]=0
            
            loss = criterion(output,label.unsqueeze(1).float())
            f1 = f1_score(label.numpy(), preds.T.numpy()[0])
            accuracy= accuracy_score(label.numpy(), preds.T.numpy()[0])
            recall= recall_score(label.numpy(), preds.T.numpy()[0])
            precision= precision_score(label.numpy(), preds.T.numpy()[0])
            f2=fbeta_score(label.numpy(), preds.T.numpy()[0], beta=2)

            # update running validation loss 
            valid_loss+=loss.item() * data.size(0)
            valid_f1+=f1
            valid_accuracy+=accuracy
            valid_recall+=recall
            valid_precision+=precision
            valid_f2+=f2

        valid_loss=valid_loss/len(valid_loader.sampler)
        valid_f1=valid_f1/iter_val
        valid_accuracy=valid_accuracy/iter_val
        valid_recall=valid_recall/iter_val
        valid_precision=valid_precision/iter_val
        valid_f2=valid_f2/iter_val

        val_losses.append(valid_loss)
        val_f1s.append(valid_f1)
        val_accuracys.append(valid_accuracy)
        val_recalls.append(valid_recall)
        val_precisions.append(valid_precision)
        val_f2s.append(valid_f2)



        print('Epoch: {} \tTraining Loss: {:.6f} \tTraining F1-score: {:.6f} \tTraining accuracy: {:.6f} \tTraining recall: {:.6f} \tTraining precision: {:.6f} \tTraining F2-score: {:.6f} \tValidation Loss: {:.6f} \tValidation F1-score: {:.6f} \tValidation accuracy: {:.6f} \tValidation recall: {:.6f} \tValidation precision: {:.6f} \tValidation F2-score: {:.6f}'.format(
            epoch+1, 
            train_loss,
            train_f1,
            train_accuracy,
            train_recall,
            train_precision,
            train_f2,
            valid_loss,
            valid_f1,
            valid_accuracy,
            valid_recall,
            valid_precision,
            valid_f2
            ))
        
    torch.save(model.state_dict(), os.path.join(path_save_model,"trained_resnet18_autocrop_30epochs.pth"))

    return train_losses, train_f1s, train_accuracys, train_recalls, train_precisions, train_f2s, val_losses, val_f1s, val_accuracys, val_recalls, val_precisions, val_f2s


def eval_model(model, path_model, valid_loader, criterion, n_epochs, device=None):
    """Pour voir les performances du modèle entraîné sur l'échantillon de validation
       /!\ certains commentaires sont à passer en code pour passer sur GPU

    """
    ######################    
    # validate the model #
    ######################
    valid_loss_min = np.Inf  # set initial "min" to infinity
    val_losses= []
    val_f1s=[]
    val_accuracys=[]
    val_recalls=[]
    val_precisions=[]
    val_f2s=[]

    model.load_state_dict(torch.load(path_model))
    model.eval()  # prep model for evaluation

    #model.to(device)

    for epoch in range(n_epochs):
        valid_loss=0
        valid_f1=0
        valid_accuracy=0
        valid_recall=0
        valid_precision=0
        valid_f2=0
        iter=0
        for data,label in valid_loader:

            # Pour utiliser GPU

            # inputs = inputs.to(device)
            # labels = labels.to(device)
            # model.to(device)

            with torch.no_grad():
                output = model(data)
                
            output_detach = output.detach()

            # calculate the loss
            preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
            for i in range(len(output_detach)):
                if sig(output_detach[i])>0.5:
                    preds[i]=1
                else: preds[i]=0
            
            loss = criterion(output,label.unsqueeze(1).float())
            f1 = f1_score(label.numpy(), preds.T.numpy()[0])
            accuracy= accuracy_score(label.numpy(), preds.T.numpy()[0])
            recall= recall_score(label.numpy(), preds.T.numpy()[0])
            precision= precision_score(label.numpy(), preds.T.numpy()[0])
            f2=fbeta_score(label.numpy(), preds.T.numpy()[0], beta=2)

            # update running validation loss 
            valid_loss+=loss.item() * data.size(0)
            valid_f1+=f1
            valid_accuracy+=accuracy
            valid_recall+=recall
            valid_precision+=precision
            valid_f2+=f2
            iter+=1

        valid_loss=valid_loss/len(valid_loader.sampler)
        valid_f1=valid_f1/iter
        valid_accuracy=valid_accuracy/iter
        valid_recall=valid_recall/iter
        valid_precision=valid_precision/iter
        valid_f2=valid_f2/iter

        val_losses.append(valid_loss)
        val_f1s.append(valid_f1)
        val_accuracys.append(valid_accuracy)
        val_recalls.append(valid_recall)
        val_precisions.append(valid_precision)
        val_f2s.append(valid_f2)

        print('Epoch: {} \tValidation Loss: {:.6f} \tValidation F1-score: {:.6f} \tValidation accuracy: {:.6f} \tValidation recall: {:.6f} \tValidation precision: {:.6f} \tValidation F2-score: {:.6f}'.format(
            epoch+1,
            valid_loss,
            valid_f1,
            valid_accuracy,
            valid_recall,
            valid_precision,
            valid_f2
            ))
        
    return val_losses, val_f1s, val_accuracys, val_recalls, val_precisions, val_f2s


def predict(model, path_model, valid_loader, device=None):
    """Pour prédire 0/1 à partir de l'échantillon de validation
       /!\ certains commentaires sont à passer en code pour passer sur GPU

    """
    model.load_state_dict(torch.load(path_model))
    model.eval()

    array_labels=np.array([])
    array_preds=np.array([])
    probas_pred=np.array([])

    for data,label in valid_loader:
        # Pour utiliser GPU

        # inputs = inputs.to(device)
        # labels = labels.to(device)
        # model.to(device)

        with torch.no_grad():
            output = model(data)
        output_detach = output.detach()

        # calculate the loss
        preds=torch.zeros(output_detach.shape[0], output_detach.shape[1])
        probas=torch.zeros(output_detach.shape[0], output_detach.shape[1])

        for i in range(len(output_detach)):
            if sig(output_detach[i])>0.5:
                preds[i]=1
            else: preds[i]=0
            probas[i]=sig(output_detach[i])
        probas_pred=np.append(probas_pred, probas.T.numpy()[0])
        array_preds=np.append(array_preds,preds.T.numpy()[0])
        array_labels=np.append(array_labels, label.numpy())

    return array_labels, array_preds, probas_pred

# %%
seed = 123
torch.manual_seed(seed)
np.random.seed(seed)

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
loss=nn.BCEWithLogitsLoss()
# Train model
train_losses, train_f1s, train_accuracys, train_recalls, train_precisions, train_f2s, val_losses, val_f1s, val_accuracys, val_recalls, val_precisions, val_f2s = train_model(model=resnet18, 
                                                                                 train_loader=train_dataloader_augmente,
                                                                                 valid_loader=test_dataloader_augmente, 
                                                                                 criterion=loss, 
                                                                                 n_epochs=30, 
                                                                                 path_save_model="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps",
                                                                                 device=None)
# Out:
# 	 fc.weight
# 	 fc.bias
# Epoch: 1 	Training Loss: 0.473524 	Training F1-score: 0.790332 	Training accuracy: 0.770457 	Training recall: 0.838948 	Training precision: 0.762217 	Training F2-score: 0.816439 	Validation Loss: 0.424057 	Validation F1-score: 0.812604 	Validation accuracy: 0.798849 	Validation recall: 0.864735 	Validation precision: 0.776892 	Validation F2-score: 0.841420
# Epoch: 2 	Training Loss: 0.437860 	Training F1-score: 0.804982 	Training accuracy: 0.790201 	Training recall: 0.834232 	Training precision: 0.792901 	Training F2-score: 0.820138 	Validation Loss: 0.409318 	Validation F1-score: 0.818828 	Validation accuracy: 0.810191 	Validation recall: 0.850042 	Validation precision: 0.797204 	Validation F2-score: 0.836225
# Epoch: 3 	Training Loss: 0.426040 	Training F1-score: 0.810875 	Training accuracy: 0.798223 	Training recall: 0.834778 	Training precision: 0.803591 	Training F2-score: 0.823023 	Validation Loss: 0.407190 	Validation F1-score: 0.814419 	Validation accuracy: 0.811407 	Validation recall: 0.822578 	Validation precision: 0.815663 	Validation F2-score: 0.818146
# Epoch: 4 	Training Loss: 0.425929 	Training F1-score: 0.812319 	Training accuracy: 0.799735 	Training recall: 0.836646 	Training precision: 0.806112 	Training F2-score: 0.824472 	Validation Loss: 0.411238 	Validation F1-score: 0.820971 	Validation accuracy: 0.808096 	Validation recall: 0.866065 	Validation precision: 0.788292 	Validation F2-score: 0.846162
# Epoch: 5 	Training Loss: 0.422768 	Training F1-score: 0.815335 	Training accuracy: 0.803758 	Training recall: 0.837076 	Training precision: 0.810984 	Training F2-score: 0.826061 	Validation Loss: 0.402533 	Validation F1-score: 0.819376 	Validation accuracy: 0.812117 	Validation recall: 0.840865 	Validation precision: 0.807710 	Validation F2-score: 0.830952
# Epoch: 6 	Training Loss: 0.429502 	Training F1-score: 0.810976 	Training accuracy: 0.798378 	Training recall: 0.834087 	Training precision: 0.805638 	Training F2-score: 0.822435 	Validation Loss: 0.400432 	Validation F1-score: 0.811175 	Validation accuracy: 0.812106 	Validation recall: 0.798782 	Validation precision: 0.834221 	Validation F2-score: 0.802575
# Epoch: 7 	Training Loss: 0.423629 	Training F1-score: 0.811601 	Training accuracy: 0.799497 	Training recall: 0.834532 	Training precision: 0.807536 	Training F2-score: 0.822821 	Validation Loss: 0.400752 	Validation F1-score: 0.824089 	Validation accuracy: 0.816831 	Validation recall: 0.844419 	Validation precision: 0.814001 	Validation F2-score: 0.834905
# Epoch: 8 	Training Loss: 0.427905 	Training F1-score: 0.809109 	Training accuracy: 0.797858 	Training recall: 0.830203 	Training precision: 0.807960 	Training F2-score: 0.819113 	Validation Loss: 0.428293 	Validation F1-score: 0.819803 	Validation accuracy: 0.797796 	Validation recall: 0.904785 	Validation precision: 0.755990 	Validation F2-score: 0.867519
# Epoch: 9 	Training Loss: 0.423517 	Training F1-score: 0.812245 	Training accuracy: 0.802195 	Training recall: 0.831200 	Training precision: 0.808695 	Training F2-score: 0.821622 	Validation Loss: 0.414439 	Validation F1-score: 0.828915 	Validation accuracy: 0.810546 	Validation recall: 0.899638 	Validation precision: 0.775400 	Validation F2-score: 0.868704
# Epoch: 10 	Training Loss: 0.417986 	Training F1-score: 0.815749 	Training accuracy: 0.804140 	Training recall: 0.838396 	Training precision: 0.809489 	Training F2-score: 0.827052 	Validation Loss: 0.403936 	Validation F1-score: 0.823408 	Validation accuracy: 0.814741 	Validation recall: 0.848807 	Validation precision: 0.806691 	Validation F2-score: 0.837458
# Epoch: 11 	Training Loss: 0.418766 	Training F1-score: 0.817939 	Training accuracy: 0.806960 	Training recall: 0.838983 	Training precision: 0.814123 	Training F2-score: 0.828283 	Validation Loss: 0.399177 	Validation F1-score: 0.831260 	Validation accuracy: 0.823639 	Validation recall: 0.863361 	Validation precision: 0.808954 	Validation F2-score: 0.849143
# Epoch: 12 	Training Loss: 0.420130 	Training F1-score: 0.813967 	Training accuracy: 0.802465 	Training recall: 0.836018 	Training precision: 0.808659 	Training F2-score: 0.824951 	Validation Loss: 0.405068 	Validation F1-score: 0.821820 	Validation accuracy: 0.814561 	Validation recall: 0.855287 	Validation precision: 0.797861 	Validation F2-score: 0.840554
# Epoch: 13 	Training Loss: 0.426457 	Training F1-score: 0.814061 	Training accuracy: 0.802945 	Training recall: 0.834596 	Training precision: 0.812746 	Training F2-score: 0.823864 	Validation Loss: 0.399014 	Validation F1-score: 0.827194 	Validation accuracy: 0.821207 	Validation recall: 0.837606 	Validation precision: 0.825769 	Validation F2-score: 0.832311
# Epoch: 14 	Training Loss: 0.419045 	Training F1-score: 0.816149 	Training accuracy: 0.805774 	Training recall: 0.834953 	Training precision: 0.813677 	Training F2-score: 0.825234 	Validation Loss: 0.408406 	Validation F1-score: 0.820421 	Validation accuracy: 0.810732 	Validation recall: 0.853067 	Validation precision: 0.796558 	Validation F2-score: 0.838777
# Epoch: 15 	Training Loss: 0.423852 	Training F1-score: 0.812255 	Training accuracy: 0.801715 	Training recall: 0.832405 	Training precision: 0.808832 	Training F2-score: 0.822016 	Validation Loss: 0.405849 	Validation F1-score: 0.818100 	Validation accuracy: 0.814212 	Validation recall: 0.822705 	Validation precision: 0.824053 	Validation F2-score: 0.819574
# Epoch: 16 	Training Loss: 0.416143 	Training F1-score: 0.820041 	Training accuracy: 0.809337 	Training recall: 0.840036 	Training precision: 0.817069 	Training F2-score: 0.829733 	Validation Loss: 0.402710 	Validation F1-score: 0.821941 	Validation accuracy: 0.814922 	Validation recall: 0.848837 	Validation precision: 0.805651 	Validation F2-score: 0.836674
# Epoch: 17 	Training Loss: 0.420025 	Training F1-score: 0.816400 	Training accuracy: 0.805992 	Training recall: 0.835124 	Training precision: 0.814654 	Training F2-score: 0.825399 	Validation Loss: 0.393698 	Validation F1-score: 0.829991 	Validation accuracy: 0.820655 	Validation recall: 0.868303 	Validation precision: 0.804512 	Validation F2-score: 0.851106
# Epoch: 18 	Training Loss: 0.418819 	Training F1-score: 0.815288 	Training accuracy: 0.804429 	Training recall: 0.835263 	Training precision: 0.812810 	Training F2-score: 0.824884 	Validation Loss: 0.399137 	Validation F1-score: 0.819053 	Validation accuracy: 0.814719 	Validation recall: 0.822721 	Validation precision: 0.825436 	Validation F2-score: 0.820077
# Epoch: 19 	Training Loss: 0.417846 	Training F1-score: 0.816391 	Training accuracy: 0.804838 	Training recall: 0.836750 	Training precision: 0.811474 	Training F2-score: 0.826556 	Validation Loss: 0.406541 	Validation F1-score: 0.816884 	Validation accuracy: 0.814032 	Validation recall: 0.818253 	Validation precision: 0.823950 	Validation F2-score: 0.816668
# Epoch: 20 	Training Loss: 0.421132 	Training F1-score: 0.814694 	Training accuracy: 0.803520 	Training recall: 0.835106 	Training precision: 0.812620 	Training F2-score: 0.824478 	Validation Loss: 0.401401 	Validation F1-score: 0.818381 	Validation accuracy: 0.815445 	Validation recall: 0.825885 	Validation precision: 0.822381 	Validation F2-score: 0.821507
# Epoch: 21 	Training Loss: 0.416221 	Training F1-score: 0.814461 	Training accuracy: 0.802980 	Training recall: 0.834453 	Training precision: 0.810524 	Training F2-score: 0.824253 	Validation Loss: 0.414547 	Validation F1-score: 0.799733 	Validation accuracy: 0.810022 	Validation recall: 0.754642 	Validation precision: 0.863783 	Validation F2-score: 0.770933
# Epoch: 22 	Training Loss: 0.420707 	Training F1-score: 0.815983 	Training accuracy: 0.805100 	Training recall: 0.836096 	Training precision: 0.814085 	Training F2-score: 0.825662 	Validation Loss: 0.398912 	Validation F1-score: 0.828764 	Validation accuracy: 0.822265 	Validation recall: 0.848867 	Validation precision: 0.817406 	Validation F2-score: 0.839695
# Epoch: 23 	Training Loss: 0.415893 	Training F1-score: 0.818591 	Training accuracy: 0.808051 	Training recall: 0.838970 	Training precision: 0.813947 	Training F2-score: 0.828752 	Validation Loss: 0.398400 	Validation F1-score: 0.826246 	Validation accuracy: 0.817174 	Validation recall: 0.854140 	Validation precision: 0.808175 	Validation F2-score: 0.841617
# Epoch: 24 	Training Loss: 0.420868 	Training F1-score: 0.814270 	Training accuracy: 0.803377 	Training recall: 0.835053 	Training precision: 0.811247 	Training F2-score: 0.824337 	Validation Loss: 0.397165 	Validation F1-score: 0.822616 	Validation accuracy: 0.817856 	Validation recall: 0.835940 	Validation precision: 0.817456 	Validation F2-score: 0.829578
# Epoch: 25 	Training Loss: 0.418341 	Training F1-score: 0.817485 	Training accuracy: 0.806988 	Training recall: 0.838240 	Training precision: 0.814384 	Training F2-score: 0.827538 	Validation Loss: 0.397926 	Validation F1-score: 0.816862 	Validation accuracy: 0.814561 	Validation recall: 0.820480 	Validation precision: 0.821318 	Validation F2-score: 0.818023
# Epoch: 26 	Training Loss: 0.414941 	Training F1-score: 0.816366 	Training accuracy: 0.804893 	Training recall: 0.835613 	Training precision: 0.813382 	Training F2-score: 0.825757 	Validation Loss: 0.401854 	Validation F1-score: 0.817272 	Validation accuracy: 0.815620 	Validation recall: 0.816298 	Validation precision: 0.824910 	Validation F2-score: 0.815898
# Epoch: 27 	Training Loss: 0.414309 	Training F1-score: 0.820775 	Training accuracy: 0.809841 	Training recall: 0.839554 	Training precision: 0.817779 	Training F2-score: 0.829930 	Validation Loss: 0.394893 	Validation F1-score: 0.825093 	Validation accuracy: 0.816318 	Validation recall: 0.858983 	Validation precision: 0.801785 	Validation F2-score: 0.843974
# Epoch: 28 	Training Loss: 0.417010 	Training F1-score: 0.818277 	Training accuracy: 0.807492 	Training recall: 0.838741 	Training precision: 0.814086 	Training F2-score: 0.828383 	Validation Loss: 0.404303 	Validation F1-score: 0.815855 	Validation accuracy: 0.814550 	Validation recall: 0.808845 	Validation precision: 0.832234 	Validation F2-score: 0.810602
# Epoch: 29 	Training Loss: 0.419639 	Training F1-score: 0.816417 	Training accuracy: 0.805266 	Training recall: 0.834814 	Training precision: 0.814710 	Training F2-score: 0.825294 	Validation Loss: 0.405191 	Validation F1-score: 0.830167 	Validation accuracy: 0.814043 	Validation recall: 0.893378 	Validation precision: 0.781657 	Validation F2-score: 0.865909
# Epoch: 30 	Training Loss: 0.416955 	Training F1-score: 0.815268 	Training accuracy: 0.804603 	Training recall: 0.833410 	Training precision: 0.812958 	Training F2-score: 0.824095 	Validation Loss: 0.400252 	Validation F1-score: 0.823522 	Validation accuracy: 0.813333 	Validation recall: 0.856065 	Validation precision: 0.799751 	Validation F2-score: 0.841812

# %%
dict_train_losses={}
dict_train_f1s={}
dict_train_accuracys={}
dict_train_recalls={}
dict_train_precisions={}
dict_train_f2s={}

dict_val_losses={}
dict_val_f1s={}
dict_val_accuracys={}
dict_val_recalls={}
dict_val_precisions={}
dict_val_f2s={}

for i in range(0,30):
    dict_train_losses[i+1]=train_losses[i]
    dict_train_f1s[i+1]=train_f1s[i]
    dict_train_accuracys[i+1]=train_accuracys[i]
    dict_train_recalls[i+1]=train_recalls[i]
    dict_train_precisions[i+1]=train_precisions[i]
    dict_train_f2s[i+1]=train_f2s[i]

    dict_val_losses[i+1]=val_losses[i]
    dict_val_f1s[i+1]=val_f1s[i]
    dict_val_accuracys[i+1]=val_accuracys[i]
    dict_val_recalls[i+1]=val_recalls[i]
    dict_val_precisions[i+1]=val_precisions[i]
    dict_val_f2s[i+1]=val_f2s[i]

sorted_train_losses = sorted(dict_train_losses.items())
sorted_train_f1s = sorted(dict_train_f1s.items())
sorted_train_accuracys = sorted(dict_train_accuracys.items())
sorted_train_recalls = sorted(dict_train_recalls.items())
sorted_train_precisions = sorted(dict_train_precisions.items())
sorted_train_f2s = sorted(dict_train_f2s.items())

sorted_val_losses = sorted(dict_val_losses.items())
sorted_val_f1s = sorted(dict_val_f1s.items())
sorted_val_accuracys = sorted(dict_val_accuracys.items())
sorted_val_recalls = sorted(dict_val_recalls.items())
sorted_val_precisions = sorted(dict_val_precisions.items())
sorted_val_f2s = sorted(dict_val_f2s.items())

epochs, loss_train = zip(*sorted_train_losses)
epochs, f1_train = zip(*sorted_train_f1s)
epochs, acc_train = zip(*sorted_train_accuracys)
epochs, recall_train = zip(*sorted_train_recalls)
epochs, precision_train =zip(*sorted_train_precisions)
epochs, f2_train = zip(*sorted_train_f2s)

epochs, loss_val = zip(*sorted_val_losses)
epochs, f1_val = zip(*sorted_val_f1s)
epochs, acc_val = zip(*sorted_val_accuracys)
epochs, recall_val = zip(*sorted_val_recalls)
epochs, precision_val =zip(*sorted_val_precisions)
epochs, f2_val = zip(*sorted_val_f2s)


fig, axs = plt.subplots(3, 2, figsize=(15, 15))

axs[0,0].plot(epochs, loss_train, 'b',label="Loss sur l'échantillon d'apprentissage", color="blue")
axs[0,0].plot(epochs, loss_val, 'b',label="Loss sur l'échantillon de validation", color="red")
axs[0,0].legend()

axs[0,1].plot(epochs, acc_train, 'b',label="Accuracy sur l'échantillon d'apprentissage", color="blue")
axs[0,1].plot(epochs, acc_val, 'b',label="Accuracy sur l'échantillon de validation", color="red")
axs[0,1].legend()

axs[1,0].plot(epochs, precision_train, 'b',label="Precision sur l'échantillon d'apprentissage", color="blue")
axs[1,0].plot(epochs, precision_val, 'b',label="Precision sur l'échantillon de validation", color="red")
axs[1,0].legend()

axs[1,1].plot(epochs, recall_train, 'b',label="Recall sur l'échantillon d'apprentissage", color="blue")
axs[1,1].plot(epochs, recall_val, 'b',label="Recall sur l'échantillon de validation", color="red")
axs[1,1].legend()

axs[2,0].plot(epochs, f1_train, 'b',label="F1-score sur l'échantillon d'apprentissage", color="blue")
axs[2,0].plot(epochs, f1_val, 'b',label="F1-score sur l'échantillon de validation", color="red")
axs[2,0].legend()

axs[2,1].plot(epochs, f2_train, 'b',label="F2-score sur l'échantillon d'apprentissage", color="blue")
axs[2,1].plot(epochs, f2_val, 'b',label="F2-score sur l'échantillon de validation", color="red")
axs[2,1].legend()

plt.savefig('courbes_loss_resnet18_autocrop_30.png')
plt.show()

# %%
seed = 123
torch.manual_seed(seed)
np.random.seed(seed)

y_true_train, y_pred_train, proba_pred_train=predict(model=resnet18, path_model="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps/trained_resnet18_autocrop_30epochs.pth", valid_loader=train_dataloader_augmente, device=None)
y_true_val, y_pred_val, proba_pred_val=predict(model=resnet18, path_model="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps/trained_resnet18_autocrop_30epochs.pth", valid_loader=test_dataloader_augmente, device=None)

# %%
print("Loss sur l'échantillon train: {}".format(round(log_loss(y_true_train, proba_pred_train),2)))
print("Accuracy sur l'échantillon train: {}".format(round(accuracy_score(y_true_train, y_pred_train),2)))
print("Recall sur l'échantillon train: {}".format(round(recall_score(y_true_train, y_pred_train),2)))
print("Precision sur l'échantillon train: {}".format(round(precision_score(y_true_train, y_pred_train),2)))
print("F1-score sur l'échantillon train: {}".format(round(f1_score(y_true_train, y_pred_train),2)))
print("F2-score sur l'échantillon train: {} \n".format(round(fbeta_score(y_true_train, y_pred_train, beta=2),2)))

print("Loss sur l'échantillon test: {}".format(round(log_loss(y_true_val, proba_pred_val),2)))
print("Accuracy sur l'échantillon test: {}".format(round(accuracy_score(y_true_val, y_pred_val),2)))
print("Recall sur l'échantillon test: {}".format(round(recall_score(y_true_val, y_pred_val),2)))
print("Precision sur l'échantillon test: {}".format(round(precision_score(y_true_val, y_pred_val),2)))
print("F1-score sur l'échantillon test: {}".format(round(f1_score(y_true_val, y_pred_val),2)))
print("F2-score sur l'échantillon test: {}".format(round(fbeta_score(y_true_val, y_pred_val, beta=2),2)))

FP_rate, TP_rate, thresholds_keras = roc_curve(y_true_val, proba_pred_val)
AUC= auc(FP_rate, TP_rate)
print("AUC: {}".format(round(AUC, 2)))

plt.title('Courbe ROC:  ResNet-18 transfert learning')
plt.plot(FP_rate, TP_rate, label="AUC="+str(round(AUC, 2)))
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0], c=".7"), plt.plot([1, 1], c=".7")
plt.ylabel('Taux de vrais positifs')
plt.xlabel('Taux de faux positifs')
plt.legend(loc=4)
plt.savefig('ROC_resnet18_transfertlearning_crop_30epochs.png')
plt.show()

prec, rec, thresholds_keras = precision_recall_curve(y_true_val, proba_pred_val)

fig, ax = plt.subplots()
ax.plot(rec, prec)

#add axis labels to plot
ax.set_title('Courbe Precision-Recall: ResNet 18 transfert learning')
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')

#display plot
plt.savefig('prec_recall_resnet18_transfertlearning_crop_30epochs.png')
plt.show()

r = confusion_matrix(y_true_val, y_pred_val)

labels = ["Vrais négatifs", "Faux Positifs", "Faux négatifs", "Vrais positifs"]
categories = ["0", "1"]
make_confusion_matrix(r,
                      group_names=labels,
                      categories=categories,
                      )
# Out:
# Loss sur l'échantillon train: 0.4
# Accuracy sur l'échantillon train: 0.82
# Recall sur l'échantillon train: 0.86
# Precision sur l'échantillon train: 0.8
# F1-score sur l'échantillon train: 0.83
# F2-score sur l'échantillon train: 0.85
#
# Loss sur l'échantillon test: 0.41
# Accuracy sur l'échantillon test: 0.81
# Recall sur l'échantillon test: 0.86
# Precision sur l'échantillon test: 0.79
# F1-score sur l'échantillon test: 0.83
# F2-score sur l'échantillon test: 0.85
# AUC: 0.9

# %% [markdown]
# # Visualisation TSNE

# %%
seed = 123
torch.manual_seed(seed)
np.random.seed(seed)

dataset_tsne=BDAPPVClassification_path(img_dir="C:/Users/yanis/OneDrive/Documents/Projet Stat/Données/bdappv/google3",
                                  size=224,
                                  transform=transforms.Compose([transforms.Normalize(mean = [0.346024751663208, 0.35355815291404724, 0.3038492202758789],
                                                                    std= [0.20496879518032074, 0.18832367658615112, 0.18234187364578247])]))


# Define the samplers for training and testing sets
test_sampler_tsne = SubsetRandomSampler(test_indices)

# Define the dataloaders for training and testing sets
test_dataloader_tsne = DataLoader(dataset_tsne, batch_size=32, sampler=test_sampler_tsne)

# %%
def embedding(data, path_model="C:/Users/yanis/OneDrive/Documents/Projet Stat/statapps/trained_resnet18_autocrop_30epochs.pth"):
    resnet18.load_state_dict(torch.load(path_model))
    resnet18.eval()
    out = resnet18.conv1(data) #pass through CNN
    out= resnet18.bn1(out)
    out=resnet18.relu(out)
    out=resnet18.maxpool(out)
    out=resnet18.layer1(out)
    out=resnet18.layer2(out)
    out=resnet18.layer3(out)
    out=resnet18.layer4(out)
    out=torch.flatten(out, 1)
    return out

# %%
features = None
labels = None
image_paths = None

for data in test_dataloader_tsne:
    inputs=data[0]
    targets=data[1]
    paths=data[2]
    
    output = embedding(inputs)
    current_features = output.detach().numpy()
    if features is not None:
        features = np.concatenate((features, current_features))
    else:
        features = current_features

    if labels is not None:
        labels = np.concatenate((labels, targets))
    else:
        labels = targets
    
    if image_paths is not None:
        image_paths = np.concatenate((image_paths, paths))
    else:
        image_paths = paths

# %%
fig, ax = plt.subplots(1, 3, figsize=(20,7), constrained_layout=True)

for c, per in zip(itertools.count(), [5, 30, 50]):
    tsne = TSNE(n_components=2,
                perplexity=per)
    tsne = tsne.fit_transform(features)
    scatter = ax[c].scatter(tsne[:, 0], tsne[:, 1], c=labels, cmap=matplotlib.colors.ListedColormap(["red", "blue"]), s=0.3)
    ax[c].set_title(f'Perplexity: {per}', fontsize=16)

# %%
tsne = TSNE(n_components=2, perplexity=50).fit_transform(features)
visualize_tsne(tsne, image_paths, labels)
# Out:
# Building the T-SNE plot: 100%|██████████| 5727/5727 [00:56<00:00, 101.02it/s]
